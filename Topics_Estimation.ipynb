# %%
import pickle, os, json

with open('clusters_topics_all.pkl', 'rb') as f:
    clusters = pickle.load(f)
    
with open("AI4AM_topics3.json", "r+") as f:
    topics = json.load(f)
    
with open('optimal_clusters.pkl', 'rb') as f:
    optimal_clusters = pickle.load(f)
    
list_topics = list()
for k,v in  topics.items():
    list_topics.append(f"{k} : {v['description']}")

# %%
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from utils import OPENAI_API_KEY

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0, openai_api_key=OPENAI_API_KEY)

# %%
from langchain_core.prompts import PromptTemplate

topics_estimate = PromptTemplate.from_template("""
You are an expert in analyzing scientific papers.
You have received a list of titles of research and study topics:
###
{list_topics}
###
Your tasks:
Step 1. Rate on a 10-point scale how consistent this list of topics is,
i.e. how well the topics can be grouped into one common theme or cluster.
Where 0 points have absolutely nothing in common, 10 points are almost identical.

Step 2. Give this list a common name or topic title, a summary.

The output should be in JSON format as a dictionary with the following key-value pair:
The key is the short name of these topics. The values is a score from 0 to 10 indicating how consistent this list of topics is.
Example of output:
"Advanced Computational Techniques in Materials and Manufacturing": 7,
....
               """
                                              )

# %%
import numpy as np

optimal_clusters.keys()
# Out:
# dict_keys(['gauss_OpenAI', 'kmeans_OpenAI', 'gauss_HuggingFace', 'kmeans_HuggingFace', 'hdbscan_OpenAI', 'hdbscan_HuggingFace', 'hdbscan_HuggingFace + gauss_HF', 'hdbscan_HuggingFace + kmeans_HF'])

# %% [markdown]
# ### LLM estimation of clustering algorithms and name of clusters

# %%
from langchain_core.output_parsers import JsonOutputParser, SimpleJsonOutputParser

# Summary of topics.
title_sum = topics_estimate | llm | JsonOutputParser()
#title_sum = topics_estimate | llm | SimpleJsonOutputParser()

# %%
def get_topic_list(topics_names, cl_labels, cluster):
    topic_list = list()
    for t, l in zip(topics_names, cl_labels):
        if l == cluster:
            topic_list.append(f"{t}")
    return topic_list

def remove_topic(ltopics, rtopics):
    for t in rtopics:
        if t in ltopics:
            ltopics.remove(t)
    return

def get_outliers(outliers):
    _outliers = [s.split(':') for s in outliers]
    for  i,o in enumerate(_outliers):
        if len(o) !=2:
            _outliers[i] = o[0], " "
    return {k: {"score":10,
                "list": [f"{k}:{v}"]
                } for k,v in _outliers}

def get_answer(model, text):
    pass

# %%
def print_dict(d, indent=0):
    """
    Recursively prints a dictionary, including nested dictionaries, 
    with indentation to represent structure.
    """
    for key, value in d.items():
        print('   ' * indent + str(key) + ": ", end="\n")
        if isinstance(value, dict):
            print()  # Print a newline for nested dictionaries
            print_dict(value, indent + 1)
        else:
            print(" ",str(value))

# %%
clusters_topic = dict()

for  k, v in optimal_clusters.items():
    print("Cluster Algorithm:",k)
    _topics = dict()
    for l in np. unique(v['labels']):
        print("Cluster:", l)
        _list = get_topic_list(list_topics, optimal_clusters[k]['labels'], cluster=l)
        if l != -1:
            answer = title_sum.invoke({"list_topics": _list})
            _k = list(answer.keys())[0]
            _topics[_k] = {"score":answer[_k],
                           "list":_list}
            print(answer, "\n")
            print("\n".join(_list))
        else:
            print("Outlaier Topics:\n", "\n".join(_list))
            _topics.update(get_outliers(_list))
        print(20*'-')
    print(10*'-*-')
    clusters_topic[k] = _topics
# Out:
# Cluster Algorithm: gauss_OpenAI
# Cluster: 0
# {'Quantum Computing and Computational Methods in Quantum Mechanics': 8}
#
# Quantum Computing Techniques : A technique in quantum mechanics that allows for the adiabatic evolution of quantum states, enhancing the performance of quantum algorithms by reducing errors.
# Quantum Computing : A field of study focused on the development and application of quantum computers, which leverage quantum mechanics to perform computations more efficiently than classical computers, including variational quantum algorithms.
# Density Functional Theory (DFT) : A quantum mechanical method used to investigate the electronic structure of many-body systems, particularly atoms, molecules, and the condensed phases.
# Self-Consistent Field (SCF) : A computational method used in quantum chemistry to find the approximate solution of the Schrödinger equation for many-electron systems.
# Quantum Circuit Optimization : The process of improving the efficiency and performance of quantum circuits, often by reducing gate counts and minimizing errors.
# ZX-Calculus : A graphical language used for reasoning about quantum processes, allowing for the manipulation and optimization of quantum circuits.
# Cluster Expansion (CE) : A statistical method used to model the energy of a system based on the arrangement of its constituent atoms, often used in materials science.
# Charge Mixing Optimization : A process in DFT simulations aimed at improving the convergence and stability of electronic structure calculations.
# --------------------
# Cluster: 1
# {'Advanced Computational Techniques in Materials and Manufacturing': 8}
#
# Synthetic Image Generation : The process of creating synthetic images that mimic real experimental conditions for training machine learning models.
# Adaptive Algorithms : Algorithms that adjust their parameters dynamically based on feedback from the environment or data, often used in optimization problems.
# Genetic Algorithm (GA) : An optimization technique inspired by the process of natural selection, used to generate novel structures in the context of materials research.
# Surrogate Models : Models that approximate complex simulations to provide faster responses and data generation, often used in manufacturing and engineering.
# Digital Twins : Virtual representations of physical systems that simulate their behavior in real-time, often used for monitoring and optimization in manufacturing.
# Generative Models : Statistical models that can generate new data points based on learned patterns from existing data, often used in materials design.
# Symbolic Regression : A type of regression analysis that searches for mathematical expressions that best fit a given dataset, often using genetic algorithms or neural networks.
# Simulation Optimization : The process of improving simulation models to enhance their accuracy and performance in predicting real-world outcomes.
# Bayesian Optimization : A machine learning technique used for optimizing complex functions that are expensive to evaluate, often used in hyperparameter tuning.
# --------------------
# Cluster: 2
# {'Surface and Molecular Interactions in Materials Science': 8}
#
# Surface Dynamics : Curves that describe how molecules adhere to surfaces at constant temperature, relevant for materials like metal-organic frameworks (MOFs).
# Molecular Solubility : The ability of a solid substance to dissolve in a solvent, which is significant for understanding material properties and applications.
# Hydrogen Bond Network : The network of hydrogen bonds that connect water molecules, which plays a crucial role in determining the properties of liquid water.
# Semantic Interoperability : The ability of different systems to exchange and make use of information in a meaningful way, particularly in the context of materials data.
# Potential Energy Surfaces (PES) : A multidimensional surface representing the energy of a system as a function of its molecular geometry, crucial for understanding reaction dynamics.
# Diffusion Barriers : Energy barriers that ions must overcome to move through a material, critical in understanding ionic conductivity.
# Surface Energies : The energy associated with the surface of a material, which is crucial for understanding phenomena such as adhesion, wetting, and surface reactions.
# --------------------
# Cluster: 3
# {'Quantum and Advanced Materials Science': 9}
#
# Quantum Materials : Materials that exhibit quantum mechanical properties, which are of interest for their potential applications in advanced technologies such as quantum computing and superconductivity.
# Crystal Structure Determination : The process of identifying the arrangement of atoms within a crystal, often using techniques such as X-ray diffraction.
# Crystallography : The study of crystals and their structures, including the analysis of crystal formation and properties.
# Magnetic Materials : The study of materials that exhibit magnetic properties, including their intrinsic properties and how they can be modeled and simulated.
# Hysteresis Properties : The characteristics of magnetic materials that describe their response to external magnetic fields, including coercive field and energy density product.
# Optical Anisotropy : The property of a material to have different optical characteristics in different directions, which is crucial for applications in light manipulation.
# Materials Informatics : An interdisciplinary field that combines materials science and data science to discover, design, and screen new materials using computational methods.
# 2D Materials : Materials that are one or two atoms thick, which exhibit unique physical and chemical properties.
# Graphene : A single layer of carbon atoms arranged in a two-dimensional honeycomb lattice, known for its exceptional electrical, thermal, and mechanical properties.
# Semiconductors : Materials that have electrical conductivity between that of a conductor and an insulator, crucial for electronic devices and applications.
# Band Gap Directness : A property of semiconductors that describes whether the top of the valence band and the bottom of the conduction band occur at the same or different momentum k-wavevectors.
# Symmetry in Materials : The study of how the symmetry of a material's crystal structure affects its electronic properties, including band gap characteristics.
# X-ray Diffraction : A technique used to study the structure of materials by observing the scattering of X-rays, providing information about the arrangement of atoms in a crystal.
# Strain Profile Analysis : The study of how materials deform under stress, which can be inferred from X-ray diffraction data to understand material properties.
# Catalysis by Clusters : Research focused on the catalytic properties of atomic clusters, which can exhibit unique behaviors compared to bulk materials due to their size and composition.
# Inverse Materials Design : An approach that focuses on predicting material structures based on desired properties, as opposed to the traditional method of predicting properties from known structures.
# Superconductors : Materials that can conduct electricity without resistance below a certain temperature, significant for various technological applications.
# Transition Metal Oxides : A class of materials that exhibit a variety of electronic and magnetic properties, important for applications in energy devices and catalysis.
# Ferroic Properties : Properties related to materials that exhibit spontaneous polarization or magnetization, which can be manipulated by external fields.
# Materials Science : An interdisciplinary field that studies the properties, performance, and applications of materials, including metals, polymers, and ceramics.
# Metallurgy : The science and technology of metals, including their extraction, processing, and properties.
# Point Defects : Imperfections in a crystal lattice, such as vacancies or substitutional defects, which can significantly affect the material's properties.
# Transition Metal Dichalcogenides : A class of materials composed of transition metals and chalcogen elements, known for their layered structure and potential applications in electronics and optoelectronics.
# Topological properties : Characteristics of materials that are related to their geometric and spatial properties, often studied in the context of condensed matter physics and materials science.
# Optoelectronic Properties : Properties related to the interaction between light and electronic materials, crucial for applications in devices like photovoltaics and LEDs.
# --------------------
# Cluster: 4
# {'Machine Learning and Its Subfields': 9}
#
# Deep Learning : A subset of machine learning that uses neural networks with many layers to analyze and interpret complex data, particularly effective for image processing tasks.
# Machine Learning : A subset of artificial intelligence that involves the use of algorithms and statistical models to enable computers to perform tasks without explicit instructions.
# Explainable Artificial Intelligence (XAI) : A subfield of artificial intelligence focused on making the results of machine learning models understandable to humans, often through techniques that explain how models make predictions.
# Active Learning Algorithm (ALA) : A machine learning approach that iteratively selects the most informative data points to improve model performance, particularly in the context of materials design.
# Reinforcement Learning : A type of machine learning where an agent learns to make decisions by receiving rewards or penalties based on its actions.
# Active Learning (AL) : A machine learning approach where the model actively queries for labels on specific data points to improve its performance.
# Large Language Models : Advanced AI models that understand and generate human-like text, which can be applied to interpret and generate materials science data.
# Active Learning : A machine learning approach where the algorithm selectively queries the user to label data points that are most informative for improving the model.
# Multi-modal learning : An approach in machine learning that integrates and processes information from multiple sources or modalities to improve learning outcomes.
# Transferability in Machine Learning : The ability of a machine learning model to generalize its performance to new, unseen data, which is crucial for the applicability of models in real-world scenarios.
# --------------------
# Cluster: 5
# {'Machine Learning Techniques in Computational Chemistry': 9}
#
# Machine Learning in Chemistry : The application of machine learning techniques to predict material properties and enhance computational chemistry methods, including interatomic interaction models.
# Gaussian Approximation Potentials : A type of machine learning interatomic potential that uses Gaussian Process Regression to model atomic interactions, providing a balance between accuracy and computational efficiency.
# Machine Learning Potential (MLP) : A machine learning model used to predict the potential energy surface of a system, allowing for efficient simulations of material properties.
# Physically-Informed Machine Learning : An approach that integrates physical laws and principles into machine learning models to improve their predictive capabilities and interpretability.
# Machine Learning Interatomic Potentials (MLIPs) : A computational technique that uses machine learning to predict interatomic forces, bridging the gap between quantum mechanical accuracy and classical computational efficiency.
# --------------------
# Cluster: 6
# {'Advanced Techniques in Nanotechnology and Quantum Systems': 8}
#
# Neuroscience Applications : The application of advanced computational techniques to understand brain activity and improve diagnostics and neurorehabilitation methods.
# Nanoparticle Imaging : The study of the structural properties and shapes of nanoparticles using advanced imaging techniques, including high resolution transmission electron microscopy.
# 4D Scanning Transmission Electron Microscopy (4D-STEM) : A technique for studying nanoscale materials that combines scanning transmission electron microscopy with electron diffraction patterns to provide local structural imaging.
# Quantum State Tomography : A process used to reconstruct the quantum state of a system based on measurement data, crucial for understanding quantum systems.
# High-Throughput Screening : A method used in materials science to rapidly assess a large number of materials or compounds for specific properties or performance metrics.
# Nanoparticles in Catalysis : The study of nanoparticles and their role in enhancing catalytic processes, often leading to increased reaction rates and selectivity.
# Scanning Transmission Electron Microscopy (STEM) : A high-resolution imaging technique that allows for the observation of materials at the atomic level, including the identification of defects.
# AI-aided discovery in photonics : The use of artificial intelligence techniques to enhance the discovery and development of photonic materials and devices.
# --------------------
# Cluster: 7
# {'Materials Science and Engineering in Energy and Sensing Applications': 8}
#
# Tunnel Magnetoresistive (TMR) Sensors : Devices that measure the change in electric resistance in magnetic materials, used for sensing magnetic fields.
# CO2 Reduction : The process of converting carbon dioxide into useful products, such as hydrocarbons, often using catalysts to facilitate the reaction.
# Electrochemical Sensors : Devices that use electrochemical reactions to detect and measure the concentration of specific ions or molecules in a solution.
# Graphene Oxide : A material derived from graphene that is used in various applications, including sensors, due to its unique electrical and chemical properties.
# Organic Electronics : A field of study focused on the use of organic materials in electronic devices, including organic semiconductors and organic photovoltaics.
# X-ray Photoelectron Spectroscopy (XPS) : A surface-sensitive quantitative spectroscopic technique that can identify the elemental composition and chemical state of materials by measuring the binding energies of core electrons.
# Solid Electrolyte Interphase (SEI) : A layer that forms on the surface of electrodes in batteries, crucial for understanding battery performance and stability.
# Photoinduced Reactions : Chemical reactions that are initiated or accelerated by the absorption of light, particularly relevant in the study of surface dynamics.
# Oxide Electronics : The study and application of electronic devices that utilize oxide materials, often focusing on their unique electrical properties.
# Catalysis : The process of increasing the rate of a chemical reaction by adding a substance known as a catalyst, which is not consumed in the reaction.
# Electrodeposition : A process used to deposit a material onto a substrate through the application of an electric current, often used in creating coatings.
# Fuel Cells : Devices that convert chemical energy from fuels into electricity through electrochemical reactions, often using hydrogen as a fuel source.
# 3D Printing : A manufacturing process that creates three-dimensional objects from digital models, allowing for the production of customized electrochemical sensors.
# Drug Identification : The process of determining the specific type of drug present in a sample, which can be complicated by the presence of cutting agents and overlapping electrochemical signals.
# Additive Manufacturing : A process of creating objects by adding material layer by layer, often used for producing complex structures with precise control over geometry and material distribution.
# Laser-Powder Bed Fusion (L-PBF) : An additive manufacturing technique that uses a laser to selectively fuse powdered material to create complex parts, known for its high accuracy and ability to produce intricate geometries.
# --------------------
# Cluster: 8
# {'Neuroscience and Signal Processing Techniques': 6}
#
# Anomaly Detection in EEG : The identification of unusual patterns or outliers in EEG data, which can indicate potential issues or abnormalities in brain activity.
# Noise Reduction : The process of removing unwanted disturbances from signals, in this case, electron diffraction patterns, to enhance the quality of the data.
# Image Denoising : Techniques used to remove noise from images, improving their clarity and fidelity for better analysis.
# Image Quality Assessment : The evaluation of the quality of images, often in terms of how closely they resemble the original or ideal images, using various metrics and methodologies.
# Data Acquisition and Processing : The methods and technologies used to collect, structure, and analyze data related to materials.
# Clustering Algorithms : Techniques in machine learning used to group similar data points together, such as DBSCAN used in the study.
# Data Analysis : The process of inspecting, cleansing, transforming, and modeling data to discover useful information, inform conclusions, and support decision-making.
# Image Analysis : The process of examining and interpreting images to extract meaningful information, often using computational techniques.
# Principal Component Analysis : A statistical technique used to reduce the dimensionality of data while preserving as much variance as possible, often used in data analysis for identifying patterns.
# Dimensional Analysis : A mathematical technique used to analyze the relationships between different physical quantities by identifying their dimensions and units, often used to derive relationships in engineering and physics.
# Data Curation Strategies : Methods and practices for organizing, maintaining, and ensuring the quality of data, particularly in the context of training datasets for machine learning.
# --------------------
# Cluster: 9
# {'Machine Learning Techniques in Data Analysis': 8}
#
# Generative Adversarial Networks (GANs) : A class of machine learning frameworks where two neural networks, a generator and a discriminator, compete against each other to generate new data instances that resemble the training data.
# Graph Neural Networks : A type of neural network designed to process data structured as graphs, useful for predicting properties of materials based on their atomic structure.
# Convolutional Neural Networks : A class of deep learning algorithms used for analyzing visual imagery, particularly effective in extracting features from data such as X-ray diffraction patterns.
# Neural Networks : A computational approach that mimics the way human brains operate, used here to generate potential energy surfaces for modeling reactions.
# Graph Neural Networks (GNNs) : A type of neural network designed to work directly with graph-structured data, useful for modeling complex relationships in materials science.
# Artificial Neural Networks : Computational models inspired by the human brain, used in machine learning to recognize patterns and make predictions.
# --------------------
# Cluster: 10
# {'Computational Methods in Material Science and Molecular Analysis': 8}
#
# Statistical Mechanics and Thermodynamics : A branch of theoretical physics that uses statistical methods to explain the behavior of systems with a large number of particles, particularly at finite temperatures, and includes the study of thermodynamic potentials and phase behavior.
# Automated Crystal Structure Solution : A hybrid approach combining computational methods and experimental techniques to identify crystal structures efficiently.
# Molecular Dynamics : A computer simulation method for analyzing the physical movements of atoms and molecules, allowing for the study of the time-dependent behavior of a molecular system.
# Vibrational Spectroscopy : A technique used to study the vibrational modes of molecules, providing insights into molecular structure and interactions, particularly in the context of hydrogen bonding in water.
# Computational Materials Science : The use of computational methods and simulations to study and predict the properties and behaviors of materials.
# Micromagnetic Simulations : Computational techniques used to model the magnetic behavior of materials at the nanoscale.
# Raman Spectroscopy : A spectroscopic technique used to observe vibrational, rotational, and other low-frequency modes in a system, often employed in material characterization.
# Finite-Element Simulations : A numerical method for solving complex engineering problems by breaking down structures into smaller, manageable elements.
# Kinetic Monte Carlo (KMC) : A computational method used to simulate the time evolution of a system by considering the probabilities of different events occurring.
# First Principles Calculations : Computational methods that use fundamental physical laws to predict the properties of materials without empirical parameters.
# --------------------
# Cluster: 11
# {'Materials for Energy Storage and Structural Applications': 6}
#
# Metal-Organic Frameworks (MOFs) : Porous materials composed of metal ions coordinated to organic ligands, used in sensing applications for their ability to selectively interact with different ions.
# Fusion Structural Materials : Materials specifically designed to withstand the extreme conditions in fusion reactors, including high radiation doses.
# High-Entropy Alloys : A novel class of materials composed of multiple principal elements, known for their unique properties such as strength, ductility, and corrosion resistance.
# Sodium-ion batteries (NIBs) : A type of rechargeable battery that uses sodium ions as the charge carriers, considered a sustainable alternative to lithium-ion batteries.
# Polyanionic materials (PAM) : A class of materials that can be used as cathodes in sodium-ion batteries, characterized by their polyanionic structure.
# Freestanding Oxide Membranes : Thin films of oxide materials that can function independently, offering unique properties for various applications.
# --------------------
# -*--*--*--*--*--*--*--*--*--*-
# Cluster Algorithm: kmeans_OpenAI
# Cluster: 0
# {'Image and Data Processing Techniques in Materials Science': 8}
#
# Image Denoising : Techniques used to remove noise from images, improving their clarity and fidelity for better analysis.
# Image Quality Assessment : The evaluation of the quality of images, often in terms of how closely they resemble the original or ideal images, using various metrics and methodologies.
# Semantic Interoperability : The ability of different systems to exchange and make use of information in a meaningful way, particularly in the context of materials data.
# Data Acquisition and Processing : The methods and technologies used to collect, structure, and analyze data related to materials.
# Data Analysis : The process of inspecting, cleansing, transforming, and modeling data to discover useful information, inform conclusions, and support decision-making.
# Image Analysis : The process of examining and interpreting images to extract meaningful information, often using computational techniques.
# Principal Component Analysis : A statistical technique used to reduce the dimensionality of data while preserving as much variance as possible, often used in data analysis for identifying patterns.
# Data Curation Strategies : Methods and practices for organizing, maintaining, and ensuring the quality of data, particularly in the context of training datasets for machine learning.
# --------------------
# Cluster: 1
# {'Materials Science and Engineering': 8}
#
# Surface Dynamics : Curves that describe how molecules adhere to surfaces at constant temperature, relevant for materials like metal-organic frameworks (MOFs).
# Molecular Solubility : The ability of a solid substance to dissolve in a solvent, which is significant for understanding material properties and applications.
# Hysteresis Properties : The characteristics of magnetic materials that describe their response to external magnetic fields, including coercive field and energy density product.
# Tunnel Magnetoresistive (TMR) Sensors : Devices that measure the change in electric resistance in magnetic materials, used for sensing magnetic fields.
# Hydrogen Bond Network : The network of hydrogen bonds that connect water molecules, which plays a crucial role in determining the properties of liquid water.
# Optical Anisotropy : The property of a material to have different optical characteristics in different directions, which is crucial for applications in light manipulation.
# Fusion Structural Materials : Materials specifically designed to withstand the extreme conditions in fusion reactors, including high radiation doses.
# 2D Materials : Materials that are one or two atoms thick, which exhibit unique physical and chemical properties.
# Graphene : A single layer of carbon atoms arranged in a two-dimensional honeycomb lattice, known for its exceptional electrical, thermal, and mechanical properties.
# Semiconductors : Materials that have electrical conductivity between that of a conductor and an insulator, crucial for electronic devices and applications.
# Band Gap Directness : A property of semiconductors that describes whether the top of the valence band and the bottom of the conduction band occur at the same or different momentum k-wavevectors.
# Symmetry in Materials : The study of how the symmetry of a material's crystal structure affects its electronic properties, including band gap characteristics.
# Solid Electrolyte Interphase (SEI) : A layer that forms on the surface of electrodes in batteries, crucial for understanding battery performance and stability.
# High-Entropy Alloys : A novel class of materials composed of multiple principal elements, known for their unique properties such as strength, ductility, and corrosion resistance.
# Sodium-ion batteries (NIBs) : A type of rechargeable battery that uses sodium ions as the charge carriers, considered a sustainable alternative to lithium-ion batteries.
# Polyanionic materials (PAM) : A class of materials that can be used as cathodes in sodium-ion batteries, characterized by their polyanionic structure.
# Diffusion Barriers : Energy barriers that ions must overcome to move through a material, critical in understanding ionic conductivity.
# Superconductors : Materials that can conduct electricity without resistance below a certain temperature, significant for various technological applications.
# Ferroic Properties : Properties related to materials that exhibit spontaneous polarization or magnetization, which can be manipulated by external fields.
# Point Defects : Imperfections in a crystal lattice, such as vacancies or substitutional defects, which can significantly affect the material's properties.
# Surface Energies : The energy associated with the surface of a material, which is crucial for understanding phenomena such as adhesion, wetting, and surface reactions.
# Topological properties : Characteristics of materials that are related to their geometric and spatial properties, often studied in the context of condensed matter physics and materials science.
# --------------------
# Cluster: 2
# {'Advanced Computational Techniques in Materials Science and Machine Learning': 8}
#
# Synthetic Image Generation : The process of creating synthetic images that mimic real experimental conditions for training machine learning models.
# Generative Adversarial Networks (GANs) : A class of machine learning frameworks where two neural networks, a generator and a discriminator, compete against each other to generate new data instances that resemble the training data.
# Graph Neural Networks : A type of neural network designed to process data structured as graphs, useful for predicting properties of materials based on their atomic structure.
# Convolutional Neural Networks : A class of deep learning algorithms used for analyzing visual imagery, particularly effective in extracting features from data such as X-ray diffraction patterns.
# Genetic Algorithm (GA) : An optimization technique inspired by the process of natural selection, used to generate novel structures in the context of materials research.
# Neural Networks : A computational approach that mimics the way human brains operate, used here to generate potential energy surfaces for modeling reactions.
# Surrogate Models : Models that approximate complex simulations to provide faster responses and data generation, often used in manufacturing and engineering.
# Graph Neural Networks (GNNs) : A type of neural network designed to work directly with graph-structured data, useful for modeling complex relationships in materials science.
# Generative Models : Statistical models that can generate new data points based on learned patterns from existing data, often used in materials design.
# Symbolic Regression : A type of regression analysis that searches for mathematical expressions that best fit a given dataset, often using genetic algorithms or neural networks.
# Artificial Neural Networks : Computational models inspired by the human brain, used in machine learning to recognize patterns and make predictions.
# --------------------
# Cluster: 3
# {'Machine Learning Techniques in Computational Chemistry': 9}
#
# Machine Learning in Chemistry : The application of machine learning techniques to predict material properties and enhance computational chemistry methods, including interatomic interaction models.
# Gaussian Approximation Potentials : A type of machine learning interatomic potential that uses Gaussian Process Regression to model atomic interactions, providing a balance between accuracy and computational efficiency.
# Potential Energy Surfaces (PES) : A multidimensional surface representing the energy of a system as a function of its molecular geometry, crucial for understanding reaction dynamics.
# Machine Learning Potential (MLP) : A machine learning model used to predict the potential energy surface of a system, allowing for efficient simulations of material properties.
# Cluster Expansion (CE) : A statistical method used to model the energy of a system based on the arrangement of its constituent atoms, often used in materials science.
# Machine Learning Interatomic Potentials (MLIPs) : A computational technique that uses machine learning to predict interatomic forces, bridging the gap between quantum mechanical accuracy and classical computational efficiency.
# --------------------
# Cluster: 4
# {'Nanostructure Characterization and Analysis Techniques': 8}
#
# Nanoparticle Imaging : The study of the structural properties and shapes of nanoparticles using advanced imaging techniques, including high resolution transmission electron microscopy.
# Crystal Structure Determination : The process of identifying the arrangement of atoms within a crystal, often using techniques such as X-ray diffraction.
# Crystallography : The study of crystals and their structures, including the analysis of crystal formation and properties.
# Automated Crystal Structure Solution : A hybrid approach combining computational methods and experimental techniques to identify crystal structures efficiently.
# Vibrational Spectroscopy : A technique used to study the vibrational modes of molecules, providing insights into molecular structure and interactions, particularly in the context of hydrogen bonding in water.
# 4D Scanning Transmission Electron Microscopy (4D-STEM) : A technique for studying nanoscale materials that combines scanning transmission electron microscopy with electron diffraction patterns to provide local structural imaging.
# Noise Reduction : The process of removing unwanted disturbances from signals, in this case, electron diffraction patterns, to enhance the quality of the data.
# Quantum State Tomography : A process used to reconstruct the quantum state of a system based on measurement data, crucial for understanding quantum systems.
# Raman Spectroscopy : A spectroscopic technique used to observe vibrational, rotational, and other low-frequency modes in a system, often employed in material characterization.
# High-Throughput Screening : A method used in materials science to rapidly assess a large number of materials or compounds for specific properties or performance metrics.
# X-ray Diffraction : A technique used to study the structure of materials by observing the scattering of X-rays, providing information about the arrangement of atoms in a crystal.
# Strain Profile Analysis : The study of how materials deform under stress, which can be inferred from X-ray diffraction data to understand material properties.
# X-ray Photoelectron Spectroscopy (XPS) : A surface-sensitive quantitative spectroscopic technique that can identify the elemental composition and chemical state of materials by measuring the binding energies of core electrons.
# Drug Identification : The process of determining the specific type of drug present in a sample, which can be complicated by the presence of cutting agents and overlapping electrochemical signals.
# Scanning Transmission Electron Microscopy (STEM) : A high-resolution imaging technique that allows for the observation of materials at the atomic level, including the identification of defects.
# --------------------
# Cluster: 5
# {'Neuroscience and Machine Learning Applications': 8}
#
# Neuroscience Applications : The application of advanced computational techniques to understand brain activity and improve diagnostics and neurorehabilitation methods.
# Deep Learning : A subset of machine learning that uses neural networks with many layers to analyze and interpret complex data, particularly effective for image processing tasks.
# Anomaly Detection in EEG : The identification of unusual patterns or outliers in EEG data, which can indicate potential issues or abnormalities in brain activity.
# Machine Learning : A subset of artificial intelligence that involves the use of algorithms and statistical models to enable computers to perform tasks without explicit instructions.
# Clustering Algorithms : Techniques in machine learning used to group similar data points together, such as DBSCAN used in the study.
# Explainable Artificial Intelligence (XAI) : A subfield of artificial intelligence focused on making the results of machine learning models understandable to humans, often through techniques that explain how models make predictions.
# Adaptive Algorithms : Algorithms that adjust their parameters dynamically based on feedback from the environment or data, often used in optimization problems.
# Active Learning Algorithm (ALA) : A machine learning approach that iteratively selects the most informative data points to improve model performance, particularly in the context of materials design.
# Reinforcement Learning : A type of machine learning where an agent learns to make decisions by receiving rewards or penalties based on its actions.
# Active Learning (AL) : A machine learning approach where the model actively queries for labels on specific data points to improve its performance.
# Large Language Models : Advanced AI models that understand and generate human-like text, which can be applied to interpret and generate materials science data.
# Physically-Informed Machine Learning : An approach that integrates physical laws and principles into machine learning models to improve their predictive capabilities and interpretability.
# Active Learning : A machine learning approach where the algorithm selectively queries the user to label data points that are most informative for improving the model.
# Bayesian Optimization : A machine learning technique used for optimizing complex functions that are expensive to evaluate, often used in hyperparameter tuning.
# AI-aided discovery in photonics : The use of artificial intelligence techniques to enhance the discovery and development of photonic materials and devices.
# Multi-modal learning : An approach in machine learning that integrates and processes information from multiple sources or modalities to improve learning outcomes.
# Transferability in Machine Learning : The ability of a machine learning model to generalize its performance to new, unseen data, which is crucial for the applicability of models in real-world scenarios.
# --------------------
# Cluster: 6
# {'Catalytic Processes and Energy Conversion': 8}
#
# CO2 Reduction : The process of converting carbon dioxide into useful products, such as hydrocarbons, often using catalysts to facilitate the reaction.
# Nanoparticles in Catalysis : The study of nanoparticles and their role in enhancing catalytic processes, often leading to increased reaction rates and selectivity.
# Catalysis by Clusters : Research focused on the catalytic properties of atomic clusters, which can exhibit unique behaviors compared to bulk materials due to their size and composition.
# Photoinduced Reactions : Chemical reactions that are initiated or accelerated by the absorption of light, particularly relevant in the study of surface dynamics.
# Catalysis : The process of increasing the rate of a chemical reaction by adding a substance known as a catalyst, which is not consumed in the reaction.
# Fuel Cells : Devices that convert chemical energy from fuels into electricity through electrochemical reactions, often using hydrogen as a fuel source.
# --------------------
# Cluster: 7
# {'Quantum Computing and Related Techniques': 9}
#
# Quantum Computing Techniques : A technique in quantum mechanics that allows for the adiabatic evolution of quantum states, enhancing the performance of quantum algorithms by reducing errors.
# Quantum Materials : Materials that exhibit quantum mechanical properties, which are of interest for their potential applications in advanced technologies such as quantum computing and superconductivity.
# Quantum Computing : A field of study focused on the development and application of quantum computers, which leverage quantum mechanics to perform computations more efficiently than classical computers, including variational quantum algorithms.
# Quantum Circuit Optimization : The process of improving the efficiency and performance of quantum circuits, often by reducing gate counts and minimizing errors.
# ZX-Calculus : A graphical language used for reasoning about quantum processes, allowing for the manipulation and optimization of quantum circuits.
# --------------------
# Cluster: 8
# {'Magnetic and Computational Materials Science': 9}
#
# Magnetic Materials : The study of materials that exhibit magnetic properties, including their intrinsic properties and how they can be modeled and simulated.
# Computational Materials Science : The use of computational methods and simulations to study and predict the properties and behaviors of materials.
# Micromagnetic Simulations : Computational techniques used to model the magnetic behavior of materials at the nanoscale.
# Materials Informatics : An interdisciplinary field that combines materials science and data science to discover, design, and screen new materials using computational methods.
# Inverse Materials Design : An approach that focuses on predicting material structures based on desired properties, as opposed to the traditional method of predicting properties from known structures.
# Materials Science : An interdisciplinary field that studies the properties, performance, and applications of materials, including metals, polymers, and ceramics.
# Metallurgy : The science and technology of metals, including their extraction, processing, and properties.
# First Principles Calculations : Computational methods that use fundamental physical laws to predict the properties of materials without empirical parameters.
# --------------------
# Cluster: 9
# {'Computational Methods in Physics and Engineering': 8}
#
# Statistical Mechanics and Thermodynamics : A branch of theoretical physics that uses statistical methods to explain the behavior of systems with a large number of particles, particularly at finite temperatures, and includes the study of thermodynamic potentials and phase behavior.
# Molecular Dynamics : A computer simulation method for analyzing the physical movements of atoms and molecules, allowing for the study of the time-dependent behavior of a molecular system.
# Density Functional Theory (DFT) : A quantum mechanical method used to investigate the electronic structure of many-body systems, particularly atoms, molecules, and the condensed phases.
# Self-Consistent Field (SCF) : A computational method used in quantum chemistry to find the approximate solution of the Schrödinger equation for many-electron systems.
# Digital Twins : Virtual representations of physical systems that simulate their behavior in real-time, often used for monitoring and optimization in manufacturing.
# Finite-Element Simulations : A numerical method for solving complex engineering problems by breaking down structures into smaller, manageable elements.
# Kinetic Monte Carlo (KMC) : A computational method used to simulate the time evolution of a system by considering the probabilities of different events occurring.
# Dimensional Analysis : A mathematical technique used to analyze the relationships between different physical quantities by identifying their dimensions and units, often used to derive relationships in engineering and physics.
# Simulation Optimization : The process of improving simulation models to enhance their accuracy and performance in predicting real-world outcomes.
# Charge Mixing Optimization : A process in DFT simulations aimed at improving the convergence and stability of electronic structure calculations.
# --------------------
# Cluster: 10
# {'Electrochemical and Electronic Materials for Sensing and Energy Applications': 8}
#
# Electrochemical Sensors : Devices that use electrochemical reactions to detect and measure the concentration of specific ions or molecules in a solution.
# Graphene Oxide : A material derived from graphene that is used in various applications, including sensors, due to its unique electrical and chemical properties.
# Metal-Organic Frameworks (MOFs) : Porous materials composed of metal ions coordinated to organic ligands, used in sensing applications for their ability to selectively interact with different ions.
# Organic Electronics : A field of study focused on the use of organic materials in electronic devices, including organic semiconductors and organic photovoltaics.
# Transition Metal Oxides : A class of materials that exhibit a variety of electronic and magnetic properties, important for applications in energy devices and catalysis.
# Freestanding Oxide Membranes : Thin films of oxide materials that can function independently, offering unique properties for various applications.
# Oxide Electronics : The study and application of electronic devices that utilize oxide materials, often focusing on their unique electrical properties.
# Transition Metal Dichalcogenides : A class of materials composed of transition metals and chalcogen elements, known for their layered structure and potential applications in electronics and optoelectronics.
# Optoelectronic Properties : Properties related to the interaction between light and electronic materials, crucial for applications in devices like photovoltaics and LEDs.
# --------------------
# Cluster: 11
# {'Electrochemical and Additive Manufacturing Techniques': 8}
#
# Electrodeposition : A process used to deposit a material onto a substrate through the application of an electric current, often used in creating coatings.
# 3D Printing : A manufacturing process that creates three-dimensional objects from digital models, allowing for the production of customized electrochemical sensors.
# Additive Manufacturing : A process of creating objects by adding material layer by layer, often used for producing complex structures with precise control over geometry and material distribution.
# Laser-Powder Bed Fusion (L-PBF) : An additive manufacturing technique that uses a laser to selectively fuse powdered material to create complex parts, known for its high accuracy and ability to produce intricate geometries.
# --------------------
# -*--*--*--*--*--*--*--*--*--*-
# Cluster Algorithm: gauss_HuggingFace
# Cluster: 0
# {'Nanotechnology and Advanced Manufacturing Techniques': 8}
#
# Nanoparticle Imaging : The study of the structural properties and shapes of nanoparticles using advanced imaging techniques, including high resolution transmission electron microscopy.
# 4D Scanning Transmission Electron Microscopy (4D-STEM) : A technique for studying nanoscale materials that combines scanning transmission electron microscopy with electron diffraction patterns to provide local structural imaging.
# Graphene : A single layer of carbon atoms arranged in a two-dimensional honeycomb lattice, known for its exceptional electrical, thermal, and mechanical properties.
# Self-Consistent Field (SCF) : A computational method used in quantum chemistry to find the approximate solution of the Schrödinger equation for many-electron systems.
# X-ray Photoelectron Spectroscopy (XPS) : A surface-sensitive quantitative spectroscopic technique that can identify the elemental composition and chemical state of materials by measuring the binding energies of core electrons.
# Photoinduced Reactions : Chemical reactions that are initiated or accelerated by the absorption of light, particularly relevant in the study of surface dynamics.
# 3D Printing : A manufacturing process that creates three-dimensional objects from digital models, allowing for the production of customized electrochemical sensors.
# Scanning Transmission Electron Microscopy (STEM) : A high-resolution imaging technique that allows for the observation of materials at the atomic level, including the identification of defects.
# Additive Manufacturing : A process of creating objects by adding material layer by layer, often used for producing complex structures with precise control over geometry and material distribution.
# Laser-Powder Bed Fusion (L-PBF) : An additive manufacturing technique that uses a laser to selectively fuse powdered material to create complex parts, known for its high accuracy and ability to produce intricate geometries.
# --------------------
# Cluster: 1
# {'Statistical Mechanics and Computational Methods in Materials Science': 8}
#
# Statistical Mechanics and Thermodynamics : A branch of theoretical physics that uses statistical methods to explain the behavior of systems with a large number of particles, particularly at finite temperatures, and includes the study of thermodynamic potentials and phase behavior.
# Surface Dynamics : Curves that describe how molecules adhere to surfaces at constant temperature, relevant for materials like metal-organic frameworks (MOFs).
# Automated Crystal Structure Solution : A hybrid approach combining computational methods and experimental techniques to identify crystal structures efficiently.
# Molecular Dynamics : A computer simulation method for analyzing the physical movements of atoms and molecules, allowing for the study of the time-dependent behavior of a molecular system.
# Vibrational Spectroscopy : A technique used to study the vibrational modes of molecules, providing insights into molecular structure and interactions, particularly in the context of hydrogen bonding in water.
# Computational Materials Science : The use of computational methods and simulations to study and predict the properties and behaviors of materials.
# Micromagnetic Simulations : Computational techniques used to model the magnetic behavior of materials at the nanoscale.
# Quantum State Tomography : A process used to reconstruct the quantum state of a system based on measurement data, crucial for understanding quantum systems.
# Raman Spectroscopy : A spectroscopic technique used to observe vibrational, rotational, and other low-frequency modes in a system, often employed in material characterization.
# Density Functional Theory (DFT) : A quantum mechanical method used to investigate the electronic structure of many-body systems, particularly atoms, molecules, and the condensed phases.
# Potential Energy Surfaces (PES) : A multidimensional surface representing the energy of a system as a function of its molecular geometry, crucial for understanding reaction dynamics.
# ...
# Generative Adversarial Networks (GANs) : A class of machine learning frameworks where two neural networks, a generator and a discriminator, compete against each other to generate new data instances that resemble the training data.
# Machine Learning : A subset of artificial intelligence that involves the use of algorithms and statistical models to enable computers to perform tasks without explicit instructions.
# Explainable Artificial Intelligence (XAI) : A subfield of artificial intelligence focused on making the results of machine learning models understandable to humans, often through techniques that explain how models make predictions.
# Active Learning Algorithm (ALA) : A machine learning approach that iteratively selects the most informative data points to improve model performance, particularly in the context of materials design.
# Reinforcement Learning : A type of machine learning where an agent learns to make decisions by receiving rewards or penalties based on its actions.
# Active Learning (AL) : A machine learning approach where the model actively queries for labels on specific data points to improve its performance.
# Symbolic Regression : A type of regression analysis that searches for mathematical expressions that best fit a given dataset, often using genetic algorithms or neural networks.
# Physically-Informed Machine Learning : An approach that integrates physical laws and principles into machine learning models to improve their predictive capabilities and interpretability.
# Artificial Neural Networks : Computational models inspired by the human brain, used in machine learning to recognize patterns and make predictions.
# Active Learning : A machine learning approach where the algorithm selectively queries the user to label data points that are most informative for improving the model.
# Multi-modal learning : An approach in machine learning that integrates and processes information from multiple sources or modalities to improve learning outcomes.
# Transferability in Machine Learning : The ability of a machine learning model to generalize its performance to new, unseen data, which is crucial for the applicability of models in real-world scenarios.
# --------------------
# Cluster: 3
# {'Statistical Mechanics and Machine Learning in Materials Science': 8}
#
# Statistical Mechanics and Thermodynamics : A branch of theoretical physics that uses statistical methods to explain the behavior of systems with a large number of particles, particularly at finite temperatures, and includes the study of thermodynamic potentials and phase behavior.
# Machine Learning in Chemistry : The application of machine learning techniques to predict material properties and enhance computational chemistry methods, including interatomic interaction models.
# Neuroscience Applications : The application of advanced computational techniques to understand brain activity and improve diagnostics and neurorehabilitation methods.
# Vibrational Spectroscopy : A technique used to study the vibrational modes of molecules, providing insights into molecular structure and interactions, particularly in the context of hydrogen bonding in water.
# Computational Materials Science : The use of computational methods and simulations to study and predict the properties and behaviors of materials.
# Semantic Interoperability : The ability of different systems to exchange and make use of information in a meaningful way, particularly in the context of materials data.
# Gaussian Approximation Potentials : A type of machine learning interatomic potential that uses Gaussian Process Regression to model atomic interactions, providing a balance between accuracy and computational efficiency.
# Machine Learning Potential (MLP) : A machine learning model used to predict the potential energy surface of a system, allowing for efficient simulations of material properties.
# Machine Learning Interatomic Potentials (MLIPs) : A computational technique that uses machine learning to predict interatomic forces, bridging the gap between quantum mechanical accuracy and classical computational efficiency.
# --------------------
# Cluster: 4
# {'Materials Informatics and Computational Techniques': 9}
#
# Materials Informatics : An interdisciplinary field that combines materials science and data science to discover, design, and screen new materials using computational methods.
# Graph Neural Networks : A type of neural network designed to process data structured as graphs, useful for predicting properties of materials based on their atomic structure.
# Genetic Algorithm (GA) : An optimization technique inspired by the process of natural selection, used to generate novel structures in the context of materials research.
# Graph Neural Networks (GNNs) : A type of neural network designed to work directly with graph-structured data, useful for modeling complex relationships in materials science.
# Cluster Expansion (CE) : A statistical method used to model the energy of a system based on the arrangement of its constituent atoms, often used in materials science.
# Large Language Models : Advanced AI models that understand and generate human-like text, which can be applied to interpret and generate materials science data.
# --------------------
# Cluster: 5
# {'Advanced Computational Techniques in Materials Science': 8}
#
# Automated Crystal Structure Solution : A hybrid approach combining computational methods and experimental techniques to identify crystal structures efficiently.
# Data Acquisition and Processing : The methods and technologies used to collect, structure, and analyze data related to materials.
# Clustering Algorithms : Techniques in machine learning used to group similar data points together, such as DBSCAN used in the study.
# Data Analysis : The process of inspecting, cleansing, transforming, and modeling data to discover useful information, inform conclusions, and support decision-making.
# Adaptive Algorithms : Algorithms that adjust their parameters dynamically based on feedback from the environment or data, often used in optimization problems.
# High-Throughput Screening : A method used in materials science to rapidly assess a large number of materials or compounds for specific properties or performance metrics.
# Neural Networks : A computational approach that mimics the way human brains operate, used here to generate potential energy surfaces for modeling reactions.
# Surrogate Models : Models that approximate complex simulations to provide faster responses and data generation, often used in manufacturing and engineering.
# Digital Twins : Virtual representations of physical systems that simulate their behavior in real-time, often used for monitoring and optimization in manufacturing.
# Finite-Element Simulations : A numerical method for solving complex engineering problems by breaking down structures into smaller, manageable elements.
# Inverse Materials Design : An approach that focuses on predicting material structures based on desired properties, as opposed to the traditional method of predicting properties from known structures.
# Generative Models : Statistical models that can generate new data points based on learned patterns from existing data, often used in materials design.
# Principal Component Analysis : A statistical technique used to reduce the dimensionality of data while preserving as much variance as possible, often used in data analysis for identifying patterns.
# Dimensional Analysis : A mathematical technique used to analyze the relationships between different physical quantities by identifying their dimensions and units, often used to derive relationships in engineering and physics.
# Simulation Optimization : The process of improving simulation models to enhance their accuracy and performance in predicting real-world outcomes.
# Bayesian Optimization : A machine learning technique used for optimizing complex functions that are expensive to evaluate, often used in hyperparameter tuning.
# Data Curation Strategies : Methods and practices for organizing, maintaining, and ensuring the quality of data, particularly in the context of training datasets for machine learning.
# --------------------
# Cluster: 6
# {'Quantum Computing and Simulation Techniques': 9}
#
# Quantum Computing Techniques : A technique in quantum mechanics that allows for the adiabatic evolution of quantum states, enhancing the performance of quantum algorithms by reducing errors.
# Quantum Computing : A field of study focused on the development and application of quantum computers, which leverage quantum mechanics to perform computations more efficiently than classical computers, including variational quantum algorithms.
# Molecular Dynamics : A computer simulation method for analyzing the physical movements of atoms and molecules, allowing for the study of the time-dependent behavior of a molecular system.
# Quantum State Tomography : A process used to reconstruct the quantum state of a system based on measurement data, crucial for understanding quantum systems.
# Density Functional Theory (DFT) : A quantum mechanical method used to investigate the electronic structure of many-body systems, particularly atoms, molecules, and the condensed phases.
# Self-Consistent Field (SCF) : A computational method used in quantum chemistry to find the approximate solution of the Schrödinger equation for many-electron systems.
# Quantum Circuit Optimization : The process of improving the efficiency and performance of quantum circuits, often by reducing gate counts and minimizing errors.
# ZX-Calculus : A graphical language used for reasoning about quantum processes, allowing for the manipulation and optimization of quantum circuits.
# Kinetic Monte Carlo (KMC) : A computational method used to simulate the time evolution of a system by considering the probabilities of different events occurring.
# --------------------
# Cluster: 7
# {'Quantum and Functional Materials': 8}
#
# Quantum Materials : Materials that exhibit quantum mechanical properties, which are of interest for their potential applications in advanced technologies such as quantum computing and superconductivity.
# Hysteresis Properties : The characteristics of magnetic materials that describe their response to external magnetic fields, including coercive field and energy density product.
# Organic Electronics : A field of study focused on the use of organic materials in electronic devices, including organic semiconductors and organic photovoltaics.
# Transition Metal Oxides : A class of materials that exhibit a variety of electronic and magnetic properties, important for applications in energy devices and catalysis.
# Ferroic Properties : Properties related to materials that exhibit spontaneous polarization or magnetization, which can be manipulated by external fields.
# Optoelectronic Properties : Properties related to the interaction between light and electronic materials, crucial for applications in devices like photovoltaics and LEDs.
# --------------------
# Cluster: 8
# {'Materials and Technologies for Energy Conversion and Storage': 8}
#
# Tunnel Magnetoresistive (TMR) Sensors : Devices that measure the change in electric resistance in magnetic materials, used for sensing magnetic fields.
# CO2 Reduction : The process of converting carbon dioxide into useful products, such as hydrocarbons, often using catalysts to facilitate the reaction.
# Electrochemical Sensors : Devices that use electrochemical reactions to detect and measure the concentration of specific ions or molecules in a solution.
# Metal-Organic Frameworks (MOFs) : Porous materials composed of metal ions coordinated to organic ligands, used in sensing applications for their ability to selectively interact with different ions.
# Semiconductors : Materials that have electrical conductivity between that of a conductor and an insulator, crucial for electronic devices and applications.
# Solid Electrolyte Interphase (SEI) : A layer that forms on the surface of electrodes in batteries, crucial for understanding battery performance and stability.
# Sodium-ion batteries (NIBs) : A type of rechargeable battery that uses sodium ions as the charge carriers, considered a sustainable alternative to lithium-ion batteries.
# Polyanionic materials (PAM) : A class of materials that can be used as cathodes in sodium-ion batteries, characterized by their polyanionic structure.
# Diffusion Barriers : Energy barriers that ions must overcome to move through a material, critical in understanding ionic conductivity.
# Fuel Cells : Devices that convert chemical energy from fuels into electricity through electrochemical reactions, often using hydrogen as a fuel source.
# Transition Metal Dichalcogenides : A class of materials composed of transition metals and chalcogen elements, known for their layered structure and potential applications in electronics and optoelectronics.
# --------------------
# Cluster: 9
# {'Materials Science and Properties': 7}
#
# Molecular Solubility : The ability of a solid substance to dissolve in a solvent, which is significant for understanding material properties and applications.
# Hydrogen Bond Network : The network of hydrogen bonds that connect water molecules, which plays a crucial role in determining the properties of liquid water.
# Graphene Oxide : A material derived from graphene that is used in various applications, including sensors, due to its unique electrical and chemical properties.
# Freestanding Oxide Membranes : Thin films of oxide materials that can function independently, offering unique properties for various applications.
# --------------------
# Cluster: 10
# {'Materials Science and Engineering': 8}
#
# Crystallography : The study of crystals and their structures, including the analysis of crystal formation and properties.
# Magnetic Materials : The study of materials that exhibit magnetic properties, including their intrinsic properties and how they can be modeled and simulated.
# 2D Materials : Materials that are one or two atoms thick, which exhibit unique physical and chemical properties.
# Symmetry in Materials : The study of how the symmetry of a material's crystal structure affects its electronic properties, including band gap characteristics.
# High-Entropy Alloys : A novel class of materials composed of multiple principal elements, known for their unique properties such as strength, ductility, and corrosion resistance.
# Catalysis by Clusters : Research focused on the catalytic properties of atomic clusters, which can exhibit unique behaviors compared to bulk materials due to their size and composition.
# Oxide Electronics : The study and application of electronic devices that utilize oxide materials, often focusing on their unique electrical properties.
# Materials Science : An interdisciplinary field that studies the properties, performance, and applications of materials, including metals, polymers, and ceramics.
# Metallurgy : The science and technology of metals, including their extraction, processing, and properties.
# Topological properties : Characteristics of materials that are related to their geometric and spatial properties, often studied in the context of condensed matter physics and materials science.
# --------------------
# Cluster: 11
# {'Image Processing Techniques for Machine Learning': 8}
#
# Synthetic Image Generation : The process of creating synthetic images that mimic real experimental conditions for training machine learning models.
# Image Denoising : Techniques used to remove noise from images, improving their clarity and fidelity for better analysis.
# Image Quality Assessment : The evaluation of the quality of images, often in terms of how closely they resemble the original or ideal images, using various metrics and methodologies.
# Image Analysis : The process of examining and interpreting images to extract meaningful information, often using computational techniques.
# --------------------
# -*--*--*--*--*--*--*--*--*--*-

# %%
_km_HF = {k:[s.split(":")[0] for s in  v["list"]] for k,v in sorted(clusters_topic['kmeans_HuggingFace'].items(),
                                       key=lambda item: len(item[1]['list']), reverse=True)}
print_dict(_km_HF)
# Out:
# Machine Learning and Deep Learning Techniques:
#   ['Deep Learning ', 'Generative Adversarial Networks (GANs) ', 'Machine Learning ', 'Explainable Artificial Intelligence (XAI) ', 'Graph Neural Networks ', 'Convolutional Neural Networks ', 'Active Learning Algorithm (ALA) ', 'Reinforcement Learning ', 'Graph Neural Networks (GNNs) ', 'Active Learning (AL) ', 'Symbolic Regression ', 'Physically-Informed Machine Learning ', 'Artificial Neural Networks ', 'Active Learning ', 'Bayesian Optimization ', 'Multi-modal learning ', 'Transferability in Machine Learning ']
# Advanced Computational Techniques in Materials Science and Neuroscience:
#   ['Machine Learning in Chemistry ', 'Neuroscience Applications ', 'Automated Crystal Structure Solution ', 'Molecular Dynamics ', 'Micromagnetic Simulations ', 'Gaussian Approximation Potentials ', 'Digital Twins ', 'Finite-Element Simulations ', 'Machine Learning Potential (MLP) ', 'Inverse Materials Design ', 'First Principles Calculations ', 'Simulation Optimization ', 'Machine Learning Interatomic Potentials (MLIPs) ', 'Charge Mixing Optimization ']
# Materials Science and Characterization Techniques:
#   ['Statistical Mechanics and Thermodynamics ', 'Nanoparticle Imaging ', 'Vibrational Spectroscopy ', '4D Scanning Transmission Electron Microscopy (4D-STEM) ', 'Raman Spectroscopy ', 'High-Throughput Screening ', 'Organic Electronics ', 'X-ray Photoelectron Spectroscopy (XPS) ', 'Potential Energy Surfaces (PES) ', 'Photoinduced Reactions ', 'Scanning Transmission Electron Microscopy (STEM) ', 'Laser-Powder Bed Fusion (L-PBF) ', 'Surface Energies ', 'AI-aided discovery in photonics ']
# Materials Data Science and Interoperability:
#   ['Semantic Interoperability ', 'Data Acquisition and Processing ', 'Clustering Algorithms ', 'Data Analysis ', 'Adaptive Algorithms ', 'Surrogate Models ', 'Large Language Models ', 'Generative Models ', 'Principal Component Analysis ', 'Data Curation Strategies ']
# Quantum Computing and Related Techniques:
#   ['Quantum Computing Techniques ', 'Quantum Computing ', 'Crystal Structure Determination ', 'Quantum State Tomography ', 'Density Functional Theory (DFT) ', 'Self-Consistent Field (SCF) ', 'X-ray Diffraction ', 'Quantum Circuit Optimization ', 'ZX-Calculus ']
# Materials Science and Energy Storage Technologies:
#   ['Surface Dynamics ', 'CO2 Reduction ', 'Electrochemical Sensors ', 'Metal-Organic Frameworks (MOFs) ', 'Solid Electrolyte Interphase (SEI) ', 'Sodium-ion batteries (NIBs) ', 'Polyanionic materials (PAM) ', 'Fuel Cells ', 'Transition Metal Dichalcogenides ']
# Materials Science and Engineering:
#   ['Crystallography ', 'Computational Materials Science ', 'Materials Informatics ', 'Oxide Electronics ', 'Materials Science ', 'Metallurgy ', 'Topological properties ']
# Computational Methods in Materials Science:
#   ['Genetic Algorithm (GA) ', 'Neural Networks ', 'Cluster Expansion (CE) ', 'Kinetic Monte Carlo (KMC) ', 'Electrodeposition ', 'Dimensional Analysis ']
# Magnetic and Optical Properties of Materials:
#   ['Anomaly Detection in EEG ', 'Magnetic Materials ', 'Hysteresis Properties ', 'Tunnel Magnetoresistive (TMR) Sensors ', 'Optical Anisotropy ', 'Ferroic Properties ']
# Image Processing Techniques for Machine Learning:
#   ['Synthetic Image Generation ', 'Image Denoising ', 'Image Quality Assessment ', 'Image Analysis ']

# %%
with open("AI4AM_topics_clusters.json", "w+") as f:
    json.dump(clusters_topic, f)

# %% [markdown]
# #### Estimate a quality of clustering

# %%
for k,v in clusters_topic.items():
    print(k, 'mean score:', np.mean([s['score'] for _,s in v.items()]), 'N clusters:', len(v))
# Out:
# gauss_OpenAI mean score: 7.916666666666667 N clusters: 12
# kmeans_OpenAI mean score: 8.25 N clusters: 12
# gauss_HuggingFace mean score: 8.083333333333334 N clusters: 12
# kmeans_HuggingFace mean score: 8.0 N clusters: 10
# hdbscan_OpenAI mean score: 9.835820895522389 N clusters: 67
# hdbscan_HuggingFace mean score: 9.555555555555555 N clusters: 9
# hdbscan_HuggingFace + gauss_HF mean score: 8.894736842105264 N clusters: 19
# hdbscan_HuggingFace + kmeans_HF mean score: 8.894736842105264 N clusters: 19

# %%
def extended_clustering_quality_metric(consensus_scores, num_clusters, k_opt, alpha=1, beta=1):
    """
    Calculate the extended quality of clustering based on consensus scores, number of clusters, 
    and deviation from the optimal number of clusters.

    Parameters:
    - consensus_scores (list or np.ndarray): Consistency scores of clusters (0-10 scale).
    - num_clusters (int): Number of clusters.
    - k_opt (int): Optimal number of clusters.
    - alpha (float): Penalization factor for number of clusters (default=1).
    - beta (float): Penalization factor for deviation from optimal clusters (default=1).

    Returns:
    - float: Extended quality metric score.
    """
    # Average consensus score
    avg_consensus = np.mean(consensus_scores)
    
    # Deviation penalty
    deviation_penalty = 1 + beta * abs(num_clusters - k_opt)
    
    # Calculate quality metric
    quality = avg_consensus / (num_clusters ** alpha * deviation_penalty)
    
    return quality

# %%
for k,v in clusters_topic.items():
    print(k, ':', extended_clustering_quality_metric(np.mean([s['score'] for _,s in v.items()]), 
                                                     len(v), 12, beta=2))
# Out:
# gauss_OpenAI : 0.6597222222222222
# kmeans_OpenAI : 0.6875
# gauss_HuggingFace : 0.6736111111111112
# kmeans_HuggingFace : 0.16
# hdbscan_OpenAI : 0.0013225522247576158
# hdbscan_HuggingFace : 0.15167548500881833
# hdbscan_HuggingFace + gauss_HF : 0.031209602954755312
# hdbscan_HuggingFace + kmeans_HF : 0.031209602954755312

# %% [markdown]
# ### LLM estimation of clustering, name of clusters and re-clustering to increaase quality.

# %%
from langchain_core.prompts import PromptTemplate

topics_estimate = PromptTemplate.from_template("""
You are an expert in analyzing scientific papers.
You have received a list of titles of research and study topics:
###
{list_topics}
###
Your tasks:
Step 1. Rate on a scale of 1 to 10 how consistent this list of topics is,
i.e. how well the topics can be grouped into one common theme or cluster.
Where 0s have absolutely nothing in common, 10s are nearly identical.

Step 2. If the score from step 1 is below 8, 
exclude topics from the list that you think are not consistent for the list. 
If there are no such topics, or the score is above 7, do not exclude anything.

Step 3. Give this list a general name or topic title, summary name of the cluster.

The output should be in JSON format as a dictionary with the following key-value pair:
The key is the summary name. The value is a dictionary 'score' is a score from 0 to 10 indicating how consistent this list of topics is,
and 'excluded' a list of excluded topics.

Example of output:
"Advanced Computational Techniques in Materials and Manufacturing": ("score": 8,
"excluded": []),
'Advanced Computational Techniques in Quantum and Neuroscience Applications':("score": 7,
"excluded": ["Synthetic Image Generation : The process of creating synthetic images that mimic real experimental conditions for training machine learning models."]),
'Magnetic and Optical Properties of Materials': ("score": 6, 
"excluded": ["Anomaly Detection in EEG : The identification of unusual patterns or outliers in EEG data, which can indicate potential issues or abnormalities in brain activity."]),
...
               """
                                              )

# %%
title_sum = topics_estimate | ChatOpenAI(model="gpt-4o", temperature=0, openai_api_key=OPENAI_API_KEY) | JsonOutputParser()

# %%
clusters_topic = dict()

for  k, v in optimal_clusters.items():
    print("Cluster Algorithm:",k)
    _topics = dict()
    _outliers = list()
    for l in np. unique(v["labels"]):
        print("Cluster:", l)
        _list = get_topic_list(list_topics, optimal_clusters[k]['labels'], cluster=l)
        if l != -1:
            answer = title_sum.invoke({"list_topics": _list})
            try:
                _k = list(answer.keys())[0]
            except:
                answer = title_sum.invoke({"list_topics": _list})
                _k = list(answer.keys())[0]
            _outliers += answer[_k]["excluded"]
            remove_topic(_list, answer[_k]["excluded"])
            _topics[_k] = {"score":answer[_k]["score"],
                           "list":_list}
            print(answer, "\n")
            print("\n".join(_list))
        else:
            print("Outlaier Topics:\n", "\n".join(_list))
            _topics.update(get_outliers(_list))
        print(20*'-')
    _topics.update(get_outliers(_outliers))
    print(10*'-*-')
    clusters_topic[k] = _topics
# Out:
# Cluster Algorithm: gauss_OpenAI
# Cluster: 0
# {'Quantum Computing and Quantum Chemistry Techniques': {'score': 8, 'excluded': []}}
#
# Quantum Computing Techniques : A technique in quantum mechanics that allows for the adiabatic evolution of quantum states, enhancing the performance of quantum algorithms by reducing errors.
# Quantum Computing : A field of study focused on the development and application of quantum computers, which leverage quantum mechanics to perform computations more efficiently than classical computers, including variational quantum algorithms.
# Density Functional Theory (DFT) : A quantum mechanical method used to investigate the electronic structure of many-body systems, particularly atoms, molecules, and the condensed phases.
# Self-Consistent Field (SCF) : A computational method used in quantum chemistry to find the approximate solution of the Schrödinger equation for many-electron systems.
# Quantum Circuit Optimization : The process of improving the efficiency and performance of quantum circuits, often by reducing gate counts and minimizing errors.
# ZX-Calculus : A graphical language used for reasoning about quantum processes, allowing for the manipulation and optimization of quantum circuits.
# Cluster Expansion (CE) : A statistical method used to model the energy of a system based on the arrangement of its constituent atoms, often used in materials science.
# Charge Mixing Optimization : A process in DFT simulations aimed at improving the convergence and stability of electronic structure calculations.
# --------------------
# Cluster: 1
# {'Advanced Computational Techniques in Optimization and Simulation': {'score': 9, 'excluded': []}}
#
# Synthetic Image Generation : The process of creating synthetic images that mimic real experimental conditions for training machine learning models.
# Adaptive Algorithms : Algorithms that adjust their parameters dynamically based on feedback from the environment or data, often used in optimization problems.
# Genetic Algorithm (GA) : An optimization technique inspired by the process of natural selection, used to generate novel structures in the context of materials research.
# Surrogate Models : Models that approximate complex simulations to provide faster responses and data generation, often used in manufacturing and engineering.
# Digital Twins : Virtual representations of physical systems that simulate their behavior in real-time, often used for monitoring and optimization in manufacturing.
# Generative Models : Statistical models that can generate new data points based on learned patterns from existing data, often used in materials design.
# Symbolic Regression : A type of regression analysis that searches for mathematical expressions that best fit a given dataset, often using genetic algorithms or neural networks.
# Simulation Optimization : The process of improving simulation models to enhance their accuracy and performance in predicting real-world outcomes.
# Bayesian Optimization : A machine learning technique used for optimizing complex functions that are expensive to evaluate, often used in hyperparameter tuning.
# --------------------
# Cluster: 2
# {'Surface and Molecular Interactions in Materials Science': {'score': 6, 'excluded': ['Semantic Interoperability : The ability of different systems to exchange and make use of information in a meaningful way, particularly in the context of materials data.']}}
#
# Surface Dynamics : Curves that describe how molecules adhere to surfaces at constant temperature, relevant for materials like metal-organic frameworks (MOFs).
# Molecular Solubility : The ability of a solid substance to dissolve in a solvent, which is significant for understanding material properties and applications.
# Hydrogen Bond Network : The network of hydrogen bonds that connect water molecules, which plays a crucial role in determining the properties of liquid water.
# Potential Energy Surfaces (PES) : A multidimensional surface representing the energy of a system as a function of its molecular geometry, crucial for understanding reaction dynamics.
# Diffusion Barriers : Energy barriers that ions must overcome to move through a material, critical in understanding ionic conductivity.
# Surface Energies : The energy associated with the surface of a material, which is crucial for understanding phenomena such as adhesion, wetting, and surface reactions.
# --------------------
# Cluster: 3
# {'Advanced Materials Science and Properties': {'score': 9, 'excluded': []}}
#
# Quantum Materials : Materials that exhibit quantum mechanical properties, which are of interest for their potential applications in advanced technologies such as quantum computing and superconductivity.
# Crystal Structure Determination : The process of identifying the arrangement of atoms within a crystal, often using techniques such as X-ray diffraction.
# Crystallography : The study of crystals and their structures, including the analysis of crystal formation and properties.
# Magnetic Materials : The study of materials that exhibit magnetic properties, including their intrinsic properties and how they can be modeled and simulated.
# Hysteresis Properties : The characteristics of magnetic materials that describe their response to external magnetic fields, including coercive field and energy density product.
# Optical Anisotropy : The property of a material to have different optical characteristics in different directions, which is crucial for applications in light manipulation.
# Materials Informatics : An interdisciplinary field that combines materials science and data science to discover, design, and screen new materials using computational methods.
# 2D Materials : Materials that are one or two atoms thick, which exhibit unique physical and chemical properties.
# Graphene : A single layer of carbon atoms arranged in a two-dimensional honeycomb lattice, known for its exceptional electrical, thermal, and mechanical properties.
# Semiconductors : Materials that have electrical conductivity between that of a conductor and an insulator, crucial for electronic devices and applications.
# Band Gap Directness : A property of semiconductors that describes whether the top of the valence band and the bottom of the conduction band occur at the same or different momentum k-wavevectors.
# Symmetry in Materials : The study of how the symmetry of a material's crystal structure affects its electronic properties, including band gap characteristics.
# X-ray Diffraction : A technique used to study the structure of materials by observing the scattering of X-rays, providing information about the arrangement of atoms in a crystal.
# Strain Profile Analysis : The study of how materials deform under stress, which can be inferred from X-ray diffraction data to understand material properties.
# Catalysis by Clusters : Research focused on the catalytic properties of atomic clusters, which can exhibit unique behaviors compared to bulk materials due to their size and composition.
# Inverse Materials Design : An approach that focuses on predicting material structures based on desired properties, as opposed to the traditional method of predicting properties from known structures.
# Superconductors : Materials that can conduct electricity without resistance below a certain temperature, significant for various technological applications.
# Transition Metal Oxides : A class of materials that exhibit a variety of electronic and magnetic properties, important for applications in energy devices and catalysis.
# Ferroic Properties : Properties related to materials that exhibit spontaneous polarization or magnetization, which can be manipulated by external fields.
# Materials Science : An interdisciplinary field that studies the properties, performance, and applications of materials, including metals, polymers, and ceramics.
# Metallurgy : The science and technology of metals, including their extraction, processing, and properties.
# Point Defects : Imperfections in a crystal lattice, such as vacancies or substitutional defects, which can significantly affect the material's properties.
# Transition Metal Dichalcogenides : A class of materials composed of transition metals and chalcogen elements, known for their layered structure and potential applications in electronics and optoelectronics.
# Topological properties : Characteristics of materials that are related to their geometric and spatial properties, often studied in the context of condensed matter physics and materials science.
# Optoelectronic Properties : Properties related to the interaction between light and electronic materials, crucial for applications in devices like photovoltaics and LEDs.
# --------------------
# Cluster: 4
# {'Advanced Machine Learning Techniques': {'score': 9, 'excluded': []}}
#
# Deep Learning : A subset of machine learning that uses neural networks with many layers to analyze and interpret complex data, particularly effective for image processing tasks.
# Machine Learning : A subset of artificial intelligence that involves the use of algorithms and statistical models to enable computers to perform tasks without explicit instructions.
# Explainable Artificial Intelligence (XAI) : A subfield of artificial intelligence focused on making the results of machine learning models understandable to humans, often through techniques that explain how models make predictions.
# Active Learning Algorithm (ALA) : A machine learning approach that iteratively selects the most informative data points to improve model performance, particularly in the context of materials design.
# Reinforcement Learning : A type of machine learning where an agent learns to make decisions by receiving rewards or penalties based on its actions.
# Active Learning (AL) : A machine learning approach where the model actively queries for labels on specific data points to improve its performance.
# Large Language Models : Advanced AI models that understand and generate human-like text, which can be applied to interpret and generate materials science data.
# Active Learning : A machine learning approach where the algorithm selectively queries the user to label data points that are most informative for improving the model.
# Multi-modal learning : An approach in machine learning that integrates and processes information from multiple sources or modalities to improve learning outcomes.
# Transferability in Machine Learning : The ability of a machine learning model to generalize its performance to new, unseen data, which is crucial for the applicability of models in real-world scenarios.
# --------------------
# Cluster: 5
# {'Machine Learning in Computational Chemistry': {'score': 9, 'excluded': []}}
#
# Machine Learning in Chemistry : The application of machine learning techniques to predict material properties and enhance computational chemistry methods, including interatomic interaction models.
# Gaussian Approximation Potentials : A type of machine learning interatomic potential that uses Gaussian Process Regression to model atomic interactions, providing a balance between accuracy and computational efficiency.
# Machine Learning Potential (MLP) : A machine learning model used to predict the potential energy surface of a system, allowing for efficient simulations of material properties.
# Physically-Informed Machine Learning : An approach that integrates physical laws and principles into machine learning models to improve their predictive capabilities and interpretability.
# Machine Learning Interatomic Potentials (MLIPs) : A computational technique that uses machine learning to predict interatomic forces, bridging the gap between quantum mechanical accuracy and classical computational efficiency.
# --------------------
# Cluster: 6
# {'Advanced Imaging and Computational Techniques in Material and Quantum Sciences': {'score': 6, 'excluded': ['Neuroscience Applications : The application of advanced computational techniques to understand brain activity and improve diagnostics and neurorehabilitation methods.', 'AI-aided discovery in photonics : The use of artificial intelligence techniques to enhance the discovery and development of photonic materials and devices.']}}
#
# Nanoparticle Imaging : The study of the structural properties and shapes of nanoparticles using advanced imaging techniques, including high resolution transmission electron microscopy.
# 4D Scanning Transmission Electron Microscopy (4D-STEM) : A technique for studying nanoscale materials that combines scanning transmission electron microscopy with electron diffraction patterns to provide local structural imaging.
# Quantum State Tomography : A process used to reconstruct the quantum state of a system based on measurement data, crucial for understanding quantum systems.
# High-Throughput Screening : A method used in materials science to rapidly assess a large number of materials or compounds for specific properties or performance metrics.
# Nanoparticles in Catalysis : The study of nanoparticles and their role in enhancing catalytic processes, often leading to increased reaction rates and selectivity.
# Scanning Transmission Electron Microscopy (STEM) : A high-resolution imaging technique that allows for the observation of materials at the atomic level, including the identification of defects.
# --------------------
# Cluster: 7
# {'Advanced Materials and Sensor Technologies': {'score': 6, 'excluded': ['3D Printing : A manufacturing process that creates three-dimensional objects from digital models, allowing for the production of customized electrochemical sensors.', 'Additive Manufacturing : A process of creating objects by adding material layer by layer, often used for producing complex structures with precise control over geometry and material distribution.', 'Laser-Powder Bed Fusion (L-PBF) : An additive manufacturing technique that uses a laser to selectively fuse powdered material to create complex parts, known for its high accuracy and ability to produce intricate geometries.']}}
#
# Tunnel Magnetoresistive (TMR) Sensors : Devices that measure the change in electric resistance in magnetic materials, used for sensing magnetic fields.
# CO2 Reduction : The process of converting carbon dioxide into useful products, such as hydrocarbons, often using catalysts to facilitate the reaction.
# Electrochemical Sensors : Devices that use electrochemical reactions to detect and measure the concentration of specific ions or molecules in a solution.
# Graphene Oxide : A material derived from graphene that is used in various applications, including sensors, due to its unique electrical and chemical properties.
# Organic Electronics : A field of study focused on the use of organic materials in electronic devices, including organic semiconductors and organic photovoltaics.
# X-ray Photoelectron Spectroscopy (XPS) : A surface-sensitive quantitative spectroscopic technique that can identify the elemental composition and chemical state of materials by measuring the binding energies of core electrons.
# Solid Electrolyte Interphase (SEI) : A layer that forms on the surface of electrodes in batteries, crucial for understanding battery performance and stability.
# Photoinduced Reactions : Chemical reactions that are initiated or accelerated by the absorption of light, particularly relevant in the study of surface dynamics.
# Oxide Electronics : The study and application of electronic devices that utilize oxide materials, often focusing on their unique electrical properties.
# Catalysis : The process of increasing the rate of a chemical reaction by adding a substance known as a catalyst, which is not consumed in the reaction.
# Electrodeposition : A process used to deposit a material onto a substrate through the application of an electric current, often used in creating coatings.
# Fuel Cells : Devices that convert chemical energy from fuels into electricity through electrochemical reactions, often using hydrogen as a fuel source.
# Drug Identification : The process of determining the specific type of drug present in a sample, which can be complicated by the presence of cutting agents and overlapping electrochemical signals.
# --------------------
# Cluster: 8
# {'Data Analysis and Processing Techniques': {'score': 7, 'excluded': ['Anomaly Detection in EEG : The identification of unusual patterns or outliers in EEG data, which can indicate potential issues or abnormalities in brain activity.', 'Dimensional Analysis : A mathematical technique used to analyze the relationships between different physical quantities by identifying their dimensions and units, often used to derive relationships in engineering and physics.']}}
#
# Noise Reduction : The process of removing unwanted disturbances from signals, in this case, electron diffraction patterns, to enhance the quality of the data.
# Image Denoising : Techniques used to remove noise from images, improving their clarity and fidelity for better analysis.
# Image Quality Assessment : The evaluation of the quality of images, often in terms of how closely they resemble the original or ideal images, using various metrics and methodologies.
# Data Acquisition and Processing : The methods and technologies used to collect, structure, and analyze data related to materials.
# Clustering Algorithms : Techniques in machine learning used to group similar data points together, such as DBSCAN used in the study.
# Data Analysis : The process of inspecting, cleansing, transforming, and modeling data to discover useful information, inform conclusions, and support decision-making.
# Image Analysis : The process of examining and interpreting images to extract meaningful information, often using computational techniques.
# Principal Component Analysis : A statistical technique used to reduce the dimensionality of data while preserving as much variance as possible, often used in data analysis for identifying patterns.
# Data Curation Strategies : Methods and practices for organizing, maintaining, and ensuring the quality of data, particularly in the context of training datasets for machine learning.
# --------------------
# Cluster: 9
# {'Neural Network Applications in Data Analysis and Modeling': {'score': 9, 'excluded': []}}
#
# Generative Adversarial Networks (GANs) : A class of machine learning frameworks where two neural networks, a generator and a discriminator, compete against each other to generate new data instances that resemble the training data.
# Graph Neural Networks : A type of neural network designed to process data structured as graphs, useful for predicting properties of materials based on their atomic structure.
# Convolutional Neural Networks : A class of deep learning algorithms used for analyzing visual imagery, particularly effective in extracting features from data such as X-ray diffraction patterns.
# Neural Networks : A computational approach that mimics the way human brains operate, used here to generate potential energy surfaces for modeling reactions.
# Graph Neural Networks (GNNs) : A type of neural network designed to work directly with graph-structured data, useful for modeling complex relationships in materials science.
# Artificial Neural Networks : Computational models inspired by the human brain, used in machine learning to recognize patterns and make predictions.
# --------------------
# Cluster: 10
# {'Computational and Theoretical Methods in Physical Sciences': {'score': 9, 'excluded': []}}
#
# Statistical Mechanics and Thermodynamics : A branch of theoretical physics that uses statistical methods to explain the behavior of systems with a large number of particles, particularly at finite temperatures, and includes the study of thermodynamic potentials and phase behavior.
# Automated Crystal Structure Solution : A hybrid approach combining computational methods and experimental techniques to identify crystal structures efficiently.
# Molecular Dynamics : A computer simulation method for analyzing the physical movements of atoms and molecules, allowing for the study of the time-dependent behavior of a molecular system.
# Vibrational Spectroscopy : A technique used to study the vibrational modes of molecules, providing insights into molecular structure and interactions, particularly in the context of hydrogen bonding in water.
# Computational Materials Science : The use of computational methods and simulations to study and predict the properties and behaviors of materials.
# Micromagnetic Simulations : Computational techniques used to model the magnetic behavior of materials at the nanoscale.
# Raman Spectroscopy : A spectroscopic technique used to observe vibrational, rotational, and other low-frequency modes in a system, often employed in material characterization.
# Finite-Element Simulations : A numerical method for solving complex engineering problems by breaking down structures into smaller, manageable elements.
# Kinetic Monte Carlo (KMC) : A computational method used to simulate the time evolution of a system by considering the probabilities of different events occurring.
# First Principles Calculations : Computational methods that use fundamental physical laws to predict the properties of materials without empirical parameters.
# --------------------
# Cluster: 11
# {'Advanced Materials for Energy and Structural Applications': {'score': 7, 'excluded': []}}
#
# Metal-Organic Frameworks (MOFs) : Porous materials composed of metal ions coordinated to organic ligands, used in sensing applications for their ability to selectively interact with different ions.
# Fusion Structural Materials : Materials specifically designed to withstand the extreme conditions in fusion reactors, including high radiation doses.
# High-Entropy Alloys : A novel class of materials composed of multiple principal elements, known for their unique properties such as strength, ductility, and corrosion resistance.
# Sodium-ion batteries (NIBs) : A type of rechargeable battery that uses sodium ions as the charge carriers, considered a sustainable alternative to lithium-ion batteries.
# Polyanionic materials (PAM) : A class of materials that can be used as cathodes in sodium-ion batteries, characterized by their polyanionic structure.
# Freestanding Oxide Membranes : Thin films of oxide materials that can function independently, offering unique properties for various applications.
# --------------------
# -*--*--*--*--*--*--*--*--*--*-
# Cluster Algorithm: kmeans_OpenAI
# Cluster: 0
# {'Data and Image Processing Techniques': {'score': 8, 'excluded': []}}
#
# Image Denoising : Techniques used to remove noise from images, improving their clarity and fidelity for better analysis.
# Image Quality Assessment : The evaluation of the quality of images, often in terms of how closely they resemble the original or ideal images, using various metrics and methodologies.
# Semantic Interoperability : The ability of different systems to exchange and make use of information in a meaningful way, particularly in the context of materials data.
# Data Acquisition and Processing : The methods and technologies used to collect, structure, and analyze data related to materials.
# Data Analysis : The process of inspecting, cleansing, transforming, and modeling data to discover useful information, inform conclusions, and support decision-making.
# Image Analysis : The process of examining and interpreting images to extract meaningful information, often using computational techniques.
# Principal Component Analysis : A statistical technique used to reduce the dimensionality of data while preserving as much variance as possible, often used in data analysis for identifying patterns.
# Data Curation Strategies : Methods and practices for organizing, maintaining, and ensuring the quality of data, particularly in the context of training datasets for machine learning.
# --------------------
# Cluster: 1
# {'Advanced Materials and Their Properties': {'score': 8, 'excluded': []}}
#
# Surface Dynamics : Curves that describe how molecules adhere to surfaces at constant temperature, relevant for materials like metal-organic frameworks (MOFs).
# Molecular Solubility : The ability of a solid substance to dissolve in a solvent, which is significant for understanding material properties and applications.
# Hysteresis Properties : The characteristics of magnetic materials that describe their response to external magnetic fields, including coercive field and energy density product.
# Tunnel Magnetoresistive (TMR) Sensors : Devices that measure the change in electric resistance in magnetic materials, used for sensing magnetic fields.
# Hydrogen Bond Network : The network of hydrogen bonds that connect water molecules, which plays a crucial role in determining the properties of liquid water.
# Optical Anisotropy : The property of a material to have different optical characteristics in different directions, which is crucial for applications in light manipulation.
# Fusion Structural Materials : Materials specifically designed to withstand the extreme conditions in fusion reactors, including high radiation doses.
# 2D Materials : Materials that are one or two atoms thick, which exhibit unique physical and chemical properties.
# Graphene : A single layer of carbon atoms arranged in a two-dimensional honeycomb lattice, known for its exceptional electrical, thermal, and mechanical properties.
# Semiconductors : Materials that have electrical conductivity between that of a conductor and an insulator, crucial for electronic devices and applications.
# Band Gap Directness : A property of semiconductors that describes whether the top of the valence band and the bottom of the conduction band occur at the same or different momentum k-wavevectors.
# Symmetry in Materials : The study of how the symmetry of a material's crystal structure affects its electronic properties, including band gap characteristics.
# Solid Electrolyte Interphase (SEI) : A layer that forms on the surface of electrodes in batteries, crucial for understanding battery performance and stability.
# High-Entropy Alloys : A novel class of materials composed of multiple principal elements, known for their unique properties such as strength, ductility, and corrosion resistance.
# Sodium-ion batteries (NIBs) : A type of rechargeable battery that uses sodium ions as the charge carriers, considered a sustainable alternative to lithium-ion batteries.
# Polyanionic materials (PAM) : A class of materials that can be used as cathodes in sodium-ion batteries, characterized by their polyanionic structure.
# Diffusion Barriers : Energy barriers that ions must overcome to move through a material, critical in understanding ionic conductivity.
# Superconductors : Materials that can conduct electricity without resistance below a certain temperature, significant for various technological applications.
# Ferroic Properties : Properties related to materials that exhibit spontaneous polarization or magnetization, which can be manipulated by external fields.
# Point Defects : Imperfections in a crystal lattice, such as vacancies or substitutional defects, which can significantly affect the material's properties.
# Surface Energies : The energy associated with the surface of a material, which is crucial for understanding phenomena such as adhesion, wetting, and surface reactions.
# Topological properties : Characteristics of materials that are related to their geometric and spatial properties, often studied in the context of condensed matter physics and materials science.
# --------------------
# Cluster: 2
# {'Advanced Computational Techniques in Materials Science and Machine Learning': {'score': 9, 'excluded': []}}
#
# Synthetic Image Generation : The process of creating synthetic images that mimic real experimental conditions for training machine learning models.
# Generative Adversarial Networks (GANs) : A class of machine learning frameworks where two neural networks, a generator and a discriminator, compete against each other to generate new data instances that resemble the training data.
# Graph Neural Networks : A type of neural network designed to process data structured as graphs, useful for predicting properties of materials based on their atomic structure.
# Convolutional Neural Networks : A class of deep learning algorithms used for analyzing visual imagery, particularly effective in extracting features from data such as X-ray diffraction patterns.
# Genetic Algorithm (GA) : An optimization technique inspired by the process of natural selection, used to generate novel structures in the context of materials research.
# Neural Networks : A computational approach that mimics the way human brains operate, used here to generate potential energy surfaces for modeling reactions.
# Surrogate Models : Models that approximate complex simulations to provide faster responses and data generation, often used in manufacturing and engineering.
# Graph Neural Networks (GNNs) : A type of neural network designed to work directly with graph-structured data, useful for modeling complex relationships in materials science.
# Generative Models : Statistical models that can generate new data points based on learned patterns from existing data, often used in materials design.
# Symbolic Regression : A type of regression analysis that searches for mathematical expressions that best fit a given dataset, often using genetic algorithms or neural networks.
# Artificial Neural Networks : Computational models inspired by the human brain, used in machine learning to recognize patterns and make predictions.
# --------------------
# Cluster: 3
# {'Machine Learning Applications in Computational Chemistry and Materials Science': {'score': 9, 'excluded': []}}
#
# Machine Learning in Chemistry : The application of machine learning techniques to predict material properties and enhance computational chemistry methods, including interatomic interaction models.
# Gaussian Approximation Potentials : A type of machine learning interatomic potential that uses Gaussian Process Regression to model atomic interactions, providing a balance between accuracy and computational efficiency.
# Potential Energy Surfaces (PES) : A multidimensional surface representing the energy of a system as a function of its molecular geometry, crucial for understanding reaction dynamics.
# Machine Learning Potential (MLP) : A machine learning model used to predict the potential energy surface of a system, allowing for efficient simulations of material properties.
# Cluster Expansion (CE) : A statistical method used to model the energy of a system based on the arrangement of its constituent atoms, often used in materials science.
# Machine Learning Interatomic Potentials (MLIPs) : A computational technique that uses machine learning to predict interatomic forces, bridging the gap between quantum mechanical accuracy and classical computational efficiency.
# --------------------
# Cluster: 4
# {'Advanced Techniques in Material Characterization and Analysis': {'score': 8, 'excluded': []}}
#
# Nanoparticle Imaging : The study of the structural properties and shapes of nanoparticles using advanced imaging techniques, including high resolution transmission electron microscopy.
# Crystal Structure Determination : The process of identifying the arrangement of atoms within a crystal, often using techniques such as X-ray diffraction.
# Crystallography : The study of crystals and their structures, including the analysis of crystal formation and properties.
# Automated Crystal Structure Solution : A hybrid approach combining computational methods and experimental techniques to identify crystal structures efficiently.
# Vibrational Spectroscopy : A technique used to study the vibrational modes of molecules, providing insights into molecular structure and interactions, particularly in the context of hydrogen bonding in water.
# 4D Scanning Transmission Electron Microscopy (4D-STEM) : A technique for studying nanoscale materials that combines scanning transmission electron microscopy with electron diffraction patterns to provide local structural imaging.
# Noise Reduction : The process of removing unwanted disturbances from signals, in this case, electron diffraction patterns, to enhance the quality of the data.
# Quantum State Tomography : A process used to reconstruct the quantum state of a system based on measurement data, crucial for understanding quantum systems.
# Raman Spectroscopy : A spectroscopic technique used to observe vibrational, rotational, and other low-frequency modes in a system, often employed in material characterization.
# High-Throughput Screening : A method used in materials science to rapidly assess a large number of materials or compounds for specific properties or performance metrics.
# X-ray Diffraction : A technique used to study the structure of materials by observing the scattering of X-rays, providing information about the arrangement of atoms in a crystal.
# Strain Profile Analysis : The study of how materials deform under stress, which can be inferred from X-ray diffraction data to understand material properties.
# X-ray Photoelectron Spectroscopy (XPS) : A surface-sensitive quantitative spectroscopic technique that can identify the elemental composition and chemical state of materials by measuring the binding energies of core electrons.
# Drug Identification : The process of determining the specific type of drug present in a sample, which can be complicated by the presence of cutting agents and overlapping electrochemical signals.
# Scanning Transmission Electron Microscopy (STEM) : A high-resolution imaging technique that allows for the observation of materials at the atomic level, including the identification of defects.
# --------------------
# Cluster: 5
# {'Advanced Computational Techniques in Machine Learning and AI': {'score': 8, 'excluded': []}}
#
# Neuroscience Applications : The application of advanced computational techniques to understand brain activity and improve diagnostics and neurorehabilitation methods.
# Deep Learning : A subset of machine learning that uses neural networks with many layers to analyze and interpret complex data, particularly effective for image processing tasks.
# Anomaly Detection in EEG : The identification of unusual patterns or outliers in EEG data, which can indicate potential issues or abnormalities in brain activity.
# Machine Learning : A subset of artificial intelligence that involves the use of algorithms and statistical models to enable computers to perform tasks without explicit instructions.
# Clustering Algorithms : Techniques in machine learning used to group similar data points together, such as DBSCAN used in the study.
# Explainable Artificial Intelligence (XAI) : A subfield of artificial intelligence focused on making the results of machine learning models understandable to humans, often through techniques that explain how models make predictions.
# Adaptive Algorithms : Algorithms that adjust their parameters dynamically based on feedback from the environment or data, often used in optimization problems.
# Active Learning Algorithm (ALA) : A machine learning approach that iteratively selects the most informative data points to improve model performance, particularly in the context of materials design.
# Reinforcement Learning : A type of machine learning where an agent learns to make decisions by receiving rewards or penalties based on its actions.
# Active Learning (AL) : A machine learning approach where the model actively queries for labels on specific data points to improve its performance.
# Large Language Models : Advanced AI models that understand and generate human-like text, which can be applied to interpret and generate materials science data.
# Physically-Informed Machine Learning : An approach that integrates physical laws and principles into machine learning models to improve their predictive capabilities and interpretability.
# Active Learning : A machine learning approach where the algorithm selectively queries the user to label data points that are most informative for improving the model.
# Bayesian Optimization : A machine learning technique used for optimizing complex functions that are expensive to evaluate, often used in hyperparameter tuning.
# AI-aided discovery in photonics : The use of artificial intelligence techniques to enhance the discovery and development of photonic materials and devices.
# Multi-modal learning : An approach in machine learning that integrates and processes information from multiple sources or modalities to improve learning outcomes.
# Transferability in Machine Learning : The ability of a machine learning model to generalize its performance to new, unseen data, which is crucial for the applicability of models in real-world scenarios.
# --------------------
# Cluster: 6
# {'Catalysis and Energy Conversion': {'score': 8, 'excluded': []}}
#
# CO2 Reduction : The process of converting carbon dioxide into useful products, such as hydrocarbons, often using catalysts to facilitate the reaction.
# Nanoparticles in Catalysis : The study of nanoparticles and their role in enhancing catalytic processes, often leading to increased reaction rates and selectivity.
# Catalysis by Clusters : Research focused on the catalytic properties of atomic clusters, which can exhibit unique behaviors compared to bulk materials due to their size and composition.
# Photoinduced Reactions : Chemical reactions that are initiated or accelerated by the absorption of light, particularly relevant in the study of surface dynamics.
# Catalysis : The process of increasing the rate of a chemical reaction by adding a substance known as a catalyst, which is not consumed in the reaction.
# Fuel Cells : Devices that convert chemical energy from fuels into electricity through electrochemical reactions, often using hydrogen as a fuel source.
# --------------------
# Cluster: 7
# {'Quantum Computing and Quantum Materials': {'score': 9, 'excluded': []}}
#
# Quantum Computing Techniques : A technique in quantum mechanics that allows for the adiabatic evolution of quantum states, enhancing the performance of quantum algorithms by reducing errors.
# Quantum Materials : Materials that exhibit quantum mechanical properties, which are of interest for their potential applications in advanced technologies such as quantum computing and superconductivity.
# Quantum Computing : A field of study focused on the development and application of quantum computers, which leverage quantum mechanics to perform computations more efficiently than classical computers, including variational quantum algorithms.
# Quantum Circuit Optimization : The process of improving the efficiency and performance of quantum circuits, often by reducing gate counts and minimizing errors.
# ZX-Calculus : A graphical language used for reasoning about quantum processes, allowing for the manipulation and optimization of quantum circuits.
# --------------------
# Cluster: 8
# {'Advanced Computational Techniques in Materials Science': {'score': 9, 'excluded': []}}
#
# Magnetic Materials : The study of materials that exhibit magnetic properties, including their intrinsic properties and how they can be modeled and simulated.
# Computational Materials Science : The use of computational methods and simulations to study and predict the properties and behaviors of materials.
# Micromagnetic Simulations : Computational techniques used to model the magnetic behavior of materials at the nanoscale.
# Materials Informatics : An interdisciplinary field that combines materials science and data science to discover, design, and screen new materials using computational methods.
# Inverse Materials Design : An approach that focuses on predicting material structures based on desired properties, as opposed to the traditional method of predicting properties from known structures.
# Materials Science : An interdisciplinary field that studies the properties, performance, and applications of materials, including metals, polymers, and ceramics.
# Metallurgy : The science and technology of metals, including their extraction, processing, and properties.
# First Principles Calculations : Computational methods that use fundamental physical laws to predict the properties of materials without empirical parameters.
# --------------------
# Cluster: 9
# {'Computational and Theoretical Methods in Physics and Engineering': {'score': 7, 'excluded': ['Digital Twins : Virtual representations of physical systems that simulate their behavior in real-time, often used for monitoring and optimization in manufacturing.']}}
#
# Statistical Mechanics and Thermodynamics : A branch of theoretical physics that uses statistical methods to explain the behavior of systems with a large number of particles, particularly at finite temperatures, and includes the study of thermodynamic potentials and phase behavior.
# Molecular Dynamics : A computer simulation method for analyzing the physical movements of atoms and molecules, allowing for the study of the time-dependent behavior of a molecular system.
# Density Functional Theory (DFT) : A quantum mechanical method used to investigate the electronic structure of many-body systems, particularly atoms, molecules, and the condensed phases.
# Self-Consistent Field (SCF) : A computational method used in quantum chemistry to find the approximate solution of the Schrödinger equation for many-electron systems.
# Finite-Element Simulations : A numerical method for solving complex engineering problems by breaking down structures into smaller, manageable elements.
# Kinetic Monte Carlo (KMC) : A computational method used to simulate the time evolution of a system by considering the probabilities of different events occurring.
# Dimensional Analysis : A mathematical technique used to analyze the relationships between different physical quantities by identifying their dimensions and units, often used to derive relationships in engineering and physics.
# Simulation Optimization : The process of improving simulation models to enhance their accuracy and performance in predicting real-world outcomes.
# Charge Mixing Optimization : A process in DFT simulations aimed at improving the convergence and stability of electronic structure calculations.
# --------------------
# Cluster: 10
# {'Advanced Materials and Electronics': {'score': 8, 'excluded': []}}
#
# Electrochemical Sensors : Devices that use electrochemical reactions to detect and measure the concentration of specific ions or molecules in a solution.
# Graphene Oxide : A material derived from graphene that is used in various applications, including sensors, due to its unique electrical and chemical properties.
# Metal-Organic Frameworks (MOFs) : Porous materials composed of metal ions coordinated to organic ligands, used in sensing applications for their ability to selectively interact with different ions.
# Organic Electronics : A field of study focused on the use of organic materials in electronic devices, including organic semiconductors and organic photovoltaics.
# Transition Metal Oxides : A class of materials that exhibit a variety of electronic and magnetic properties, important for applications in energy devices and catalysis.
# Freestanding Oxide Membranes : Thin films of oxide materials that can function independently, offering unique properties for various applications.
# Oxide Electronics : The study and application of electronic devices that utilize oxide materials, often focusing on their unique electrical properties.
# Transition Metal Dichalcogenides : A class of materials composed of transition metals and chalcogen elements, known for their layered structure and potential applications in electronics and optoelectronics.
# Optoelectronic Properties : Properties related to the interaction between light and electronic materials, crucial for applications in devices like photovoltaics and LEDs.
# --------------------
# Cluster: 11
# {'Advanced Manufacturing Techniques for Material Deposition and Fabrication': {'score': 8, 'excluded': []}}
#
# Electrodeposition : A process used to deposit a material onto a substrate through the application of an electric current, often used in creating coatings.
# 3D Printing : A manufacturing process that creates three-dimensional objects from digital models, allowing for the production of customized electrochemical sensors.
# Additive Manufacturing : A process of creating objects by adding material layer by layer, often used for producing complex structures with precise control over geometry and material distribution.
# Laser-Powder Bed Fusion (L-PBF) : An additive manufacturing technique that uses a laser to selectively fuse powdered material to create complex parts, known for its high accuracy and ability to produce intricate geometries.
# --------------------
# -*--*--*--*--*--*--*--*--*--*-
# Cluster Algorithm: gauss_HuggingFace
# Cluster: 0
# {'Advanced Imaging and Manufacturing Techniques in Material Science': {'score': 6, 'excluded': ['Graphene : A single layer of carbon atoms arranged in a two-dimensional honeycomb lattice, known for its exceptional electrical, thermal, and mechanical properties.', 'Self-Consistent Field (SCF) : A computational method used in quantum chemistry to find the approximate solution of the Schrödinger equation for many-electron systems.', 'Photoinduced Reactions : Chemical reactions that are initiated or accelerated by the absorption of light, particularly relevant in the study of surface dynamics.']}}
#
# Nanoparticle Imaging : The study of the structural properties and shapes of nanoparticles using advanced imaging techniques, including high resolution transmission electron microscopy.
# 4D Scanning Transmission Electron Microscopy (4D-STEM) : A technique for studying nanoscale materials that combines scanning transmission electron microscopy with electron diffraction patterns to provide local structural imaging.
# X-ray Photoelectron Spectroscopy (XPS) : A surface-sensitive quantitative spectroscopic technique that can identify the elemental composition and chemical state of materials by measuring the binding energies of core electrons.
# 3D Printing : A manufacturing process that creates three-dimensional objects from digital models, allowing for the production of customized electrochemical sensors.
# Scanning Transmission Electron Microscopy (STEM) : A high-resolution imaging technique that allows for the observation of materials at the atomic level, including the identification of defects.
# Additive Manufacturing : A process of creating objects by adding material layer by layer, often used for producing complex structures with precise control over geometry and material distribution.
# Laser-Powder Bed Fusion (L-PBF) : An additive manufacturing technique that uses a laser to selectively fuse powdered material to create complex parts, known for its high accuracy and ability to produce intricate geometries.
# --------------------
# Cluster: 1
# {'Computational and Theoretical Methods in Materials Science and Physics': {'score': 9, 'excluded': []}}
#
# Statistical Mechanics and Thermodynamics : A branch of theoretical physics that uses statistical methods to explain the behavior of systems with a large number of particles, particularly at finite temperatures, and includes the study of thermodynamic potentials and phase behavior.
# Surface Dynamics : Curves that describe how molecules adhere to surfaces at constant temperature, relevant for materials like metal-organic frameworks (MOFs).
# Automated Crystal Structure Solution : A hybrid approach combining computational methods and experimental techniques to identify crystal structures efficiently.
# Molecular Dynamics : A computer simulation method for analyzing the physical movements of atoms and molecules, allowing for the study of the time-dependent behavior of a molecular system.
# Vibrational Spectroscopy : A technique used to study the vibrational modes of molecules, providing insights into molecular structure and interactions, particularly in the context of hydrogen bonding in water.
# Computational Materials Science : The use of computational methods and simulations to study and predict the properties and behaviors of materials.
# Micromagnetic Simulations : Computational techniques used to model the magnetic behavior of materials at the nanoscale.
# ...
# Machine Learning : A subset of artificial intelligence that involves the use of algorithms and statistical models to enable computers to perform tasks without explicit instructions.
# Explainable Artificial Intelligence (XAI) : A subfield of artificial intelligence focused on making the results of machine learning models understandable to humans, often through techniques that explain how models make predictions.
# Active Learning Algorithm (ALA) : A machine learning approach that iteratively selects the most informative data points to improve model performance, particularly in the context of materials design.
# Reinforcement Learning : A type of machine learning where an agent learns to make decisions by receiving rewards or penalties based on its actions.
# Active Learning (AL) : A machine learning approach where the model actively queries for labels on specific data points to improve its performance.
# Symbolic Regression : A type of regression analysis that searches for mathematical expressions that best fit a given dataset, often using genetic algorithms or neural networks.
# Physically-Informed Machine Learning : An approach that integrates physical laws and principles into machine learning models to improve their predictive capabilities and interpretability.
# Artificial Neural Networks : Computational models inspired by the human brain, used in machine learning to recognize patterns and make predictions.
# Active Learning : A machine learning approach where the algorithm selectively queries the user to label data points that are most informative for improving the model.
# Multi-modal learning : An approach in machine learning that integrates and processes information from multiple sources or modalities to improve learning outcomes.
# Transferability in Machine Learning : The ability of a machine learning model to generalize its performance to new, unseen data, which is crucial for the applicability of models in real-world scenarios.
# --------------------
# Cluster: 3
# {'Advanced Computational Techniques in Materials Science and Chemistry': {'score': 7, 'excluded': ['Statistical Mechanics and Thermodynamics : A branch of theoretical physics that uses statistical methods to explain the behavior of systems with a large number of particles, particularly at finite temperatures, and includes the study of thermodynamic potentials and phase behavior.', 'Neuroscience Applications : The application of advanced computational techniques to understand brain activity and improve diagnostics and neurorehabilitation methods.', 'Vibrational Spectroscopy : A technique used to study the vibrational modes of molecules, providing insights into molecular structure and interactions, particularly in the context of hydrogen bonding in water.']}}
#
# Machine Learning in Chemistry : The application of machine learning techniques to predict material properties and enhance computational chemistry methods, including interatomic interaction models.
# Computational Materials Science : The use of computational methods and simulations to study and predict the properties and behaviors of materials.
# Semantic Interoperability : The ability of different systems to exchange and make use of information in a meaningful way, particularly in the context of materials data.
# Gaussian Approximation Potentials : A type of machine learning interatomic potential that uses Gaussian Process Regression to model atomic interactions, providing a balance between accuracy and computational efficiency.
# Machine Learning Potential (MLP) : A machine learning model used to predict the potential energy surface of a system, allowing for efficient simulations of material properties.
# Machine Learning Interatomic Potentials (MLIPs) : A computational technique that uses machine learning to predict interatomic forces, bridging the gap between quantum mechanical accuracy and classical computational efficiency.
# --------------------
# Cluster: 4
# {'Advanced Computational Techniques in Materials Science': {'score': 9, 'excluded': []}}
#
# Materials Informatics : An interdisciplinary field that combines materials science and data science to discover, design, and screen new materials using computational methods.
# Graph Neural Networks : A type of neural network designed to process data structured as graphs, useful for predicting properties of materials based on their atomic structure.
# Genetic Algorithm (GA) : An optimization technique inspired by the process of natural selection, used to generate novel structures in the context of materials research.
# Graph Neural Networks (GNNs) : A type of neural network designed to work directly with graph-structured data, useful for modeling complex relationships in materials science.
# Cluster Expansion (CE) : A statistical method used to model the energy of a system based on the arrangement of its constituent atoms, often used in materials science.
# Large Language Models : Advanced AI models that understand and generate human-like text, which can be applied to interpret and generate materials science data.
# --------------------
# Cluster: 5
# {'Advanced Computational Techniques in Materials Science and Engineering': {'score': 9, 'excluded': []}}
#
# Automated Crystal Structure Solution : A hybrid approach combining computational methods and experimental techniques to identify crystal structures efficiently.
# Data Acquisition and Processing : The methods and technologies used to collect, structure, and analyze data related to materials.
# Clustering Algorithms : Techniques in machine learning used to group similar data points together, such as DBSCAN used in the study.
# Data Analysis : The process of inspecting, cleansing, transforming, and modeling data to discover useful information, inform conclusions, and support decision-making.
# Adaptive Algorithms : Algorithms that adjust their parameters dynamically based on feedback from the environment or data, often used in optimization problems.
# High-Throughput Screening : A method used in materials science to rapidly assess a large number of materials or compounds for specific properties or performance metrics.
# Neural Networks : A computational approach that mimics the way human brains operate, used here to generate potential energy surfaces for modeling reactions.
# Surrogate Models : Models that approximate complex simulations to provide faster responses and data generation, often used in manufacturing and engineering.
# Digital Twins : Virtual representations of physical systems that simulate their behavior in real-time, often used for monitoring and optimization in manufacturing.
# Finite-Element Simulations : A numerical method for solving complex engineering problems by breaking down structures into smaller, manageable elements.
# Inverse Materials Design : An approach that focuses on predicting material structures based on desired properties, as opposed to the traditional method of predicting properties from known structures.
# Generative Models : Statistical models that can generate new data points based on learned patterns from existing data, often used in materials design.
# Principal Component Analysis : A statistical technique used to reduce the dimensionality of data while preserving as much variance as possible, often used in data analysis for identifying patterns.
# Dimensional Analysis : A mathematical technique used to analyze the relationships between different physical quantities by identifying their dimensions and units, often used to derive relationships in engineering and physics.
# Simulation Optimization : The process of improving simulation models to enhance their accuracy and performance in predicting real-world outcomes.
# Bayesian Optimization : A machine learning technique used for optimizing complex functions that are expensive to evaluate, often used in hyperparameter tuning.
# Data Curation Strategies : Methods and practices for organizing, maintaining, and ensuring the quality of data, particularly in the context of training datasets for machine learning.
# --------------------
# Cluster: 6
# {'Advanced Quantum Computing and Simulation Techniques': {'score': 8, 'excluded': []}}
#
# Quantum Computing Techniques : A technique in quantum mechanics that allows for the adiabatic evolution of quantum states, enhancing the performance of quantum algorithms by reducing errors.
# Quantum Computing : A field of study focused on the development and application of quantum computers, which leverage quantum mechanics to perform computations more efficiently than classical computers, including variational quantum algorithms.
# Molecular Dynamics : A computer simulation method for analyzing the physical movements of atoms and molecules, allowing for the study of the time-dependent behavior of a molecular system.
# Quantum State Tomography : A process used to reconstruct the quantum state of a system based on measurement data, crucial for understanding quantum systems.
# Density Functional Theory (DFT) : A quantum mechanical method used to investigate the electronic structure of many-body systems, particularly atoms, molecules, and the condensed phases.
# Self-Consistent Field (SCF) : A computational method used in quantum chemistry to find the approximate solution of the Schrödinger equation for many-electron systems.
# Quantum Circuit Optimization : The process of improving the efficiency and performance of quantum circuits, often by reducing gate counts and minimizing errors.
# ZX-Calculus : A graphical language used for reasoning about quantum processes, allowing for the manipulation and optimization of quantum circuits.
# Kinetic Monte Carlo (KMC) : A computational method used to simulate the time evolution of a system by considering the probabilities of different events occurring.
# --------------------
# Cluster: 7
# {'Advanced Materials and Their Properties': {'score': 8, 'excluded': []}}
#
# Quantum Materials : Materials that exhibit quantum mechanical properties, which are of interest for their potential applications in advanced technologies such as quantum computing and superconductivity.
# Hysteresis Properties : The characteristics of magnetic materials that describe their response to external magnetic fields, including coercive field and energy density product.
# Organic Electronics : A field of study focused on the use of organic materials in electronic devices, including organic semiconductors and organic photovoltaics.
# Transition Metal Oxides : A class of materials that exhibit a variety of electronic and magnetic properties, important for applications in energy devices and catalysis.
# Ferroic Properties : Properties related to materials that exhibit spontaneous polarization or magnetization, which can be manipulated by external fields.
# Optoelectronic Properties : Properties related to the interaction between light and electronic materials, crucial for applications in devices like photovoltaics and LEDs.
# --------------------
# Cluster: 8
# {'Advanced Materials and Energy Technologies': {'score': 7, 'excluded': ['CO2 Reduction : The process of converting carbon dioxide into useful products, such as hydrocarbons, often using catalysts to facilitate the reaction.']}}
#
# Tunnel Magnetoresistive (TMR) Sensors : Devices that measure the change in electric resistance in magnetic materials, used for sensing magnetic fields.
# Electrochemical Sensors : Devices that use electrochemical reactions to detect and measure the concentration of specific ions or molecules in a solution.
# Metal-Organic Frameworks (MOFs) : Porous materials composed of metal ions coordinated to organic ligands, used in sensing applications for their ability to selectively interact with different ions.
# Semiconductors : Materials that have electrical conductivity between that of a conductor and an insulator, crucial for electronic devices and applications.
# Solid Electrolyte Interphase (SEI) : A layer that forms on the surface of electrodes in batteries, crucial for understanding battery performance and stability.
# Sodium-ion batteries (NIBs) : A type of rechargeable battery that uses sodium ions as the charge carriers, considered a sustainable alternative to lithium-ion batteries.
# Polyanionic materials (PAM) : A class of materials that can be used as cathodes in sodium-ion batteries, characterized by their polyanionic structure.
# Diffusion Barriers : Energy barriers that ions must overcome to move through a material, critical in understanding ionic conductivity.
# Fuel Cells : Devices that convert chemical energy from fuels into electricity through electrochemical reactions, often using hydrogen as a fuel source.
# Transition Metal Dichalcogenides : A class of materials composed of transition metals and chalcogen elements, known for their layered structure and potential applications in electronics and optoelectronics.
# --------------------
# Cluster: 9
# {'Properties and Applications of Advanced Materials': {'score': 6, 'excluded': ['Hydrogen Bond Network : The network of hydrogen bonds that connect water molecules, which plays a crucial role in determining the properties of liquid water.']}}
#
# Molecular Solubility : The ability of a solid substance to dissolve in a solvent, which is significant for understanding material properties and applications.
# Graphene Oxide : A material derived from graphene that is used in various applications, including sensors, due to its unique electrical and chemical properties.
# Freestanding Oxide Membranes : Thin films of oxide materials that can function independently, offering unique properties for various applications.
# --------------------
# Cluster: 10
# {'Advanced Materials and Their Properties': {'score': 9, 'excluded': []}}
#
# Crystallography : The study of crystals and their structures, including the analysis of crystal formation and properties.
# Magnetic Materials : The study of materials that exhibit magnetic properties, including their intrinsic properties and how they can be modeled and simulated.
# 2D Materials : Materials that are one or two atoms thick, which exhibit unique physical and chemical properties.
# Symmetry in Materials : The study of how the symmetry of a material's crystal structure affects its electronic properties, including band gap characteristics.
# High-Entropy Alloys : A novel class of materials composed of multiple principal elements, known for their unique properties such as strength, ductility, and corrosion resistance.
# Catalysis by Clusters : Research focused on the catalytic properties of atomic clusters, which can exhibit unique behaviors compared to bulk materials due to their size and composition.
# Oxide Electronics : The study and application of electronic devices that utilize oxide materials, often focusing on their unique electrical properties.
# Materials Science : An interdisciplinary field that studies the properties, performance, and applications of materials, including metals, polymers, and ceramics.
# Metallurgy : The science and technology of metals, including their extraction, processing, and properties.
# Topological properties : Characteristics of materials that are related to their geometric and spatial properties, often studied in the context of condensed matter physics and materials science.
# --------------------
# Cluster: 11
# {'Image Processing and Analysis Techniques': {'score': 9, 'excluded': []}}
#
# Synthetic Image Generation : The process of creating synthetic images that mimic real experimental conditions for training machine learning models.
# Image Denoising : Techniques used to remove noise from images, improving their clarity and fidelity for better analysis.
# Image Quality Assessment : The evaluation of the quality of images, often in terms of how closely they resemble the original or ideal images, using various metrics and methodologies.
# Image Analysis : The process of examining and interpreting images to extract meaningful information, often using computational techniques.
# --------------------
# -*--*--*--*--*--*--*--*--*--*-

# %%
_km_HF = {k:[s.split(":")[0] for s in  v["list"]] for k,v in sorted(clusters_topic['kmeans_HuggingFace'].items(),
                                       key=lambda item: len(item[1]['list']), reverse=True)}
print('Number of clusters:',len( _km_HF))
print_dict(_km_HF)
# Out:
# Number of clusters: 18
# Advanced Machine Learning Techniques:
#   ['Deep Learning ', 'Generative Adversarial Networks (GANs) ', 'Machine Learning ', 'Explainable Artificial Intelligence (XAI) ', 'Graph Neural Networks ', 'Convolutional Neural Networks ', 'Active Learning Algorithm (ALA) ', 'Reinforcement Learning ', 'Graph Neural Networks (GNNs) ', 'Active Learning (AL) ', 'Symbolic Regression ', 'Physically-Informed Machine Learning ', 'Artificial Neural Networks ', 'Active Learning ', 'Bayesian Optimization ', 'Multi-modal learning ', 'Transferability in Machine Learning ']
# Advanced Materials and Catalysis:
#   ['Hydrogen Bond Network ', 'Noise Reduction ', 'Fusion Structural Materials ', '2D Materials ', 'Graphene ', 'Band Gap Directness ', 'Symmetry in Materials ', 'Strain Profile Analysis ', 'High-Entropy Alloys ', 'Nanoparticles in Catalysis ', 'Catalysis by Clusters ', 'Diffusion Barriers ', 'Catalysis ', '3D Printing ', 'Point Defects ', 'Additive Manufacturing ']
# Advanced Computational Techniques in Materials Science and Engineering:
#   ['Machine Learning in Chemistry ', 'Neuroscience Applications ', 'Automated Crystal Structure Solution ', 'Molecular Dynamics ', 'Micromagnetic Simulations ', 'Gaussian Approximation Potentials ', 'Digital Twins ', 'Finite-Element Simulations ', 'Machine Learning Potential (MLP) ', 'Inverse Materials Design ', 'First Principles Calculations ', 'Simulation Optimization ', 'Machine Learning Interatomic Potentials (MLIPs) ', 'Charge Mixing Optimization ']
# Advanced Techniques in Materials Science and Nanotechnology:
#   ['Statistical Mechanics and Thermodynamics ', 'Nanoparticle Imaging ', 'Vibrational Spectroscopy ', '4D Scanning Transmission Electron Microscopy (4D-STEM) ', 'Raman Spectroscopy ', 'High-Throughput Screening ', 'X-ray Photoelectron Spectroscopy (XPS) ', 'Potential Energy Surfaces (PES) ', 'Photoinduced Reactions ', 'Scanning Transmission Electron Microscopy (STEM) ', 'Laser-Powder Bed Fusion (L-PBF) ', 'Surface Energies ']
# Data-Driven Approaches in Materials Science:
#   ['Semantic Interoperability ', 'Data Acquisition and Processing ', 'Clustering Algorithms ', 'Data Analysis ', 'Adaptive Algorithms ', 'Surrogate Models ', 'Large Language Models ', 'Generative Models ', 'Principal Component Analysis ', 'Data Curation Strategies ']
# Quantum Computing and Quantum Mechanics Techniques:
#   ['Quantum Computing Techniques ', 'Quantum Computing ', 'Crystal Structure Determination ', 'Quantum State Tomography ', 'Density Functional Theory (DFT) ', 'Self-Consistent Field (SCF) ', 'X-ray Diffraction ', 'Quantum Circuit Optimization ', 'ZX-Calculus ']
# Advanced Materials and Electrochemical Applications:
#   ['Surface Dynamics ', 'CO2 Reduction ', 'Electrochemical Sensors ', 'Metal-Organic Frameworks (MOFs) ', 'Solid Electrolyte Interphase (SEI) ', 'Sodium-ion batteries (NIBs) ', 'Polyanionic materials (PAM) ', 'Fuel Cells ', 'Transition Metal Dichalcogenides ']
# Advanced Materials and Their Properties:
#   ['Molecular Solubility ', 'Quantum Materials ', 'Graphene Oxide ', 'Semiconductors ', 'Superconductors ', 'Transition Metal Oxides ', 'Freestanding Oxide Membranes ', 'Optoelectronic Properties ']
# Advanced Materials Science and Engineering:
#   ['Crystallography ', 'Computational Materials Science ', 'Materials Informatics ', 'Oxide Electronics ', 'Materials Science ', 'Metallurgy ', 'Topological properties ']
# Magnetic and Optical Properties of Materials:
#   ['Magnetic Materials ', 'Hysteresis Properties ', 'Tunnel Magnetoresistive (TMR) Sensors ', 'Optical Anisotropy ', 'Ferroic Properties ']
# Advanced Computational and Analytical Techniques in Materials Science:
#   ['Genetic Algorithm (GA) ', 'Neural Networks ', 'Cluster Expansion (CE) ', 'Kinetic Monte Carlo (KMC) ']
# Image Processing and Analysis Techniques:
#   ['Synthetic Image Generation ', 'Image Denoising ', 'Image Quality Assessment ', 'Image Analysis ']
# Electrodeposition :
#   ['Electrodeposition ']
# Dimensional Analysis :
#   ['Dimensional Analysis ']
# Drug Identification :
#   ['Drug Identification ']
# Anomaly Detection in EEG :
#   ['Anomaly Detection in EEG ']
# AI-aided discovery in photonics :
#   ['AI-aided discovery in photonics ']
# Organic Electronics :
#   ['Organic Electronics ']

# %%
with open("AI4AM_topics_clusters2.json", "w+") as f:
    json.dump(clusters_topic, f)

# %% [markdown]
# #### Estimate a quality of clustering

# %%
for k,v in clusters_topic.items():
    print(k, 'mean score:', np.mean([s['score'] for _,s in v.items()]), 'N clusters:', len(v))
# Out:
# gauss_OpenAI mean score: 8.7 N clusters: 20
# kmeans_OpenAI mean score: 8.384615384615385 N clusters: 13
# gauss_HuggingFace mean score: 8.947368421052632 N clusters: 19
# kmeans_HuggingFace mean score: 8.61111111111111 N clusters: 18
# hdbscan_OpenAI mean score: 9.814285714285715 N clusters: 70
# hdbscan_HuggingFace mean score: 9.545454545454545 N clusters: 11
# hdbscan_HuggingFace + gauss_HF mean score: 9.153846153846153 N clusters: 26
# hdbscan_HuggingFace + kmeans_HF mean score: 9.16 N clusters: 25

# %%
for k,v in clusters_topic.items():
    print(k, ':', extended_clustering_quality_metric(np.mean([s['score'] for _,s in v.items()]), 
                                                     len(v), 12, beta=1))
# Out:
# gauss_OpenAI : 0.04833333333333333
# kmeans_OpenAI : 0.32248520710059175
# gauss_HuggingFace : 0.05886426592797784
# kmeans_HuggingFace : 0.068342151675485
# hdbscan_OpenAI : 0.0023763403666551366
# hdbscan_HuggingFace : 0.43388429752066116
# hdbscan_HuggingFace + gauss_HF : 0.023471400394477315
# hdbscan_HuggingFace + kmeans_HF : 0.02617142857142857

# %% [markdown]
# ### Compare with direct LLM clusterring methods, not use embeddings.

# %%
import networkx as nx

# Load 
file_path = "graph_AI4AM_topics_v1.gexf"  
graph = nx.read_gexf(file_path)

# Convert the graph into a dictionary
graph_dict = {
    "nodes": {n: data for n, data in graph.nodes(data=True)},
    "edges": [
        {"source": u, "target": v, **data} for u, v, data in graph.edges(data=True)
    ],
}

# %%
topics_nodes = [k for k,v in topics_dict["nodes"].items() if v["description"] != "pdf doc"]

topics_clusters = {e["source"]: [] for e in topics_dict["edges"] if e["source"] in topics_nodes}

for  k in topics_clusters.keys():
    topics_clusters[k] = [e["target"] for e in topics_dict["edges"] if e["source"] == k and e['target'] in topics_nodes]
    

llm_clusters = {k:v for k,v in topics_clusters.items()  if len(v) > 0}

llm_clusters = {k:v for k,v in sorted(llm_clusters.items()  , key=lambda item: len(item[1]), reverse=True)}

# %%
print('Number of clusters:',len(llm_clusters))
print_dict(llm_clusters)
# Out:
# Number of clusters: 24
# Machine Learning and Data Science:
#   ['Machine Learning in Chemistry', 'Machine Learning', 'Generative Adversarial Networks (GANs)', 'Deep Learning', 'Active Learning (AL)', 'Active Learning Algorithm (ALA)', 'Transferability in Machine Learning', 'Data Analysis', 'Data Acquisition and Processing', 'Data Curation Strategies', 'Synthetic Image Generation', 'Explainable Artificial Intelligence (XAI)', 'Adaptive Algorithms', 'Graph Neural Networks', 'Convolutional Neural Networks', 'Neural Networks', 'Graph Neural Networks (GNNs)', 'Machine Learning Interatomic Potentials (MLIPs)', 'Active Learning', 'Bayesian Optimization', 'Physically-Informed Machine Learning', 'Multi-modal learning', 'Large Language Models', 'Artificial Neural Networks', 'Genetic Algorithm (GA)', 'Reinforcement Learning', 'Generative Models']
# Computational Methods and Simulations:
#   ['Molecular Dynamics', 'Density Functional Theory (DFT)', 'First Principles Calculations', 'Kinetic Monte Carlo (KMC)', 'Finite-Element Simulations', 'Gaussian Approximation Potentials', 'Machine Learning Potential (MLP)', 'Surrogate Models', 'Simulation Optimization', 'Computational Materials Science', 'Self-Consistent Field (SCF)', 'Cluster Expansion (CE)', 'Charge Mixing Optimization', 'Potential Energy Surfaces (PES)', 'Dimensional Analysis']
# Materials Characterization Techniques:
#   ['X-ray Diffraction', 'Raman Spectroscopy', 'Vibrational Spectroscopy', 'X-ray Photoelectron Spectroscopy (XPS)', 'Scanning Transmission Electron Microscopy (STEM)', '4D Scanning Transmission Electron Microscopy (4D-STEM)', 'Image Analysis', 'Image Quality Assessment', 'Image Denoising', 'Noise Reduction', 'Crystal Structure Determination', 'Crystallography', 'Automated Crystal Structure Solution', 'Strain Profile Analysis']
# Electrochemical and Energy Materials:
#   ['Electrochemical Sensors', 'Sodium-ion batteries (NIBs)', 'Polyanionic materials (PAM)', 'Fuel Cells', 'Solid Electrolyte Interphase (SEI)', 'Organic Electronics', 'Fusion Structural Materials', 'Superconductors', 'Transition Metal Oxides', 'Electrodeposition']
# Nanotechnology and Nanomaterials:
#   ['Nanoparticle Imaging', 'Nanoparticles in Catalysis', 'Catalysis by Clusters', 'Metal-Organic Frameworks (MOFs)', 'Graphene Oxide', '2D Materials', 'Transition Metal Dichalcogenides', 'Graphene']
# Quantum Computing and Quantum Materials:
#   ['Quantum Computing', 'Quantum Computing Techniques', 'Quantum Materials', 'Quantum State Tomography', 'Quantum Circuit Optimization', 'ZX-Calculus']
# Materials Informatics and Design:
#   ['Materials Informatics', 'Inverse Materials Design', 'High-Throughput Screening', 'Clustering Algorithms', 'Principal Component Analysis', 'Symbolic Regression']
# Magnetic Materials and Properties:
#   ['Magnetic Materials', 'Hysteresis Properties', 'Tunnel Magnetoresistive (TMR) Sensors', 'Micromagnetic Simulations', 'Ferroic Properties']
# Chemical Reactions and Catalysis:
#   ['Catalysis', 'CO2 Reduction', 'Photoinduced Reactions', 'Nanoparticles in Catalysis', 'Drug Identification']
# Advanced Manufacturing Techniques:
#   ['3D Printing', 'Additive Manufacturing', 'Laser-Powder Bed Fusion (L-PBF)', 'Digital Twins']
# Optoelectronics and Photonics:
#   ['Optoelectronic Properties', 'AI-aided discovery in photonics', 'Optical Anisotropy']
# Semiconductors and Band Gap Properties:
#   ['Semiconductors', 'Band Gap Directness', 'Symmetry in Materials']
# Surface Science and Dynamics:
#   ['Surface Dynamics', 'Surface Energies']
# Neuroscience and Brain Activity:
#   ['Neuroscience Applications', 'Anomaly Detection in EEG']
# Oxide Materials and Electronics:
#   ['Freestanding Oxide Membranes', 'Oxide Electronics']
# Solubility and Hydrogen Bonding:
#   ['Molecular Solubility', 'Hydrogen Bond Network']
# Statistical Mechanics and Thermodynamics:
#   ['Statistical Mechanics and Thermodynamics']
# High-Entropy Alloys:
#   ['High-Entropy Alloys']
# Point Defects:
#   ['Point Defects']
# Diffusion and Ionic Conductivity:
#   ['Diffusion Barriers']
# Topological Properties:
#   ['Topological properties']
# Materials Science:
#   ['Materials Science']
# Metallurgy:
#   ['Metallurgy']
# Data Interoperability in Materials Science:
#   ['Semantic Interoperability']

# %% [markdown]
# - I consider that LLM clustering  is better than k-means clustering or any  other clustering  methods applied to embbedings of toopics.
