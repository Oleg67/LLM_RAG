# %%
import os, json
#from langchain.chains import AnalyzeDocumentChain
from langchain_openai import ChatOpenAI

from utils import OPENAI_API_KEY

os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

# %%
from contextual_rag import ContextualRAG

# %%
# Example usage
rag = ContextualRAG()
    
# Process PDF files
chunks, chunk_metadata = rag.upload_files("./data")
# Out:
# Using device: cuda
# Loading embedding model: BAAI/bge-base-en-v1.5
# Loading PDF files from ./data
# Loaded 20 documents
# Created 127 text chunks from 2 documents

# %%
   
# Make Vector DB
rag.make_db(chunks, chunk_metadata)
    
# Generate chunk embeddings and token IDs
#chunk_embeddings, token_ids_list = rag.get_chunk_emb(chunks)
# Out:
# Creating vector databases...
# Extracting keywords from chunks...
# Extracting keywords: 100%|██████████████████| 127/127 [00:00<00:00, 2739.22it/s]
# Extracted 778 unique keywords across 127 chunks
# Generating token-level embeddings...
# Generating chunk embeddings: 100%|████████████| 127/127 [00:06<00:00, 18.43it/s]
# Generated token embeddings for 127 chunks
# Generated token IDs for 127 chunks
# Token embedding shape: torch.Size([213, 768]) and Type: <class 'torch.Tensor'>
# Generating full chunk embeddings...
# Generated 127 chunk embeddings using mean pooling
# Generating keyword embeddings...
# Generating keyword embeddings: 100%|██████████| 127/127 [00:04<00:00, 27.76it/s]
# Generated embeddings for 3394 keyword-context-document pairs
# Average 4.39 contexts per keyword
# Generating keyword-based chunk embeddings...
# Generating chunk embeddings: 100%|████████████| 127/127 [00:04<00:00, 25.96it/s]
# Generated embeddings for 127 chunks
# Found keywords in 127 chunks
# Average 26.91 keywords per chunk with keywords
# Creating keyword embedding database...
# Creating chunk embedding database...
# Creating keyword-based chunk embedding database...
# Creating vector database for efficient similarity search...
# Vector databases created with 3394 keyword embeddings, 127 chunk embeddings, and 127 keyword-chunk embeddings.

# %%
keyword_stats = rag.get_all_unique_keywords()
    

    
# Print a summary
print(f"Total unique keywords: {len(keyword_stats)}")
# Out:
# Total unique keywords: 778
#
# Top 10 keywords by document coverage:
# 'properties': 2 documents, 30 total occurrences
# 'defects': 2 documents, 109 total occurrences
# 'machine': 2 documents, 36 total occurrences
# 'machine learning': 2 documents, 36 total occurrences
# 'expensive': 2 documents, 3 total occurrences
# 'neto': 2 documents, 4 total occurrences
# 'materials': 2 documents, 64 total occurrences
# 'andrey ustyuzhanin': 2 documents, 2 total occurrences
# 'castro': 2 documents, 4 total occurrences
# 'characteristics': 2 documents, 2 total occurrences
# Total unique keywords: 778

# %%
    
# Save the system
rag.save(".data/context_rag_system_v2")
# Out:
# Saving model to .data/context_rag_system_v2...
# Model saved successfully to .data/context_rag_system_v2
# - Saved 3394 keyword embeddings
# - Saved 127 chunk embeddings
# - Saved 127 keyword-chunk embeddings
# - Saved vectorizer: True
# - Embedding model name: Not specified

# %%
query = "What is machine learning?"
results = rag.process_query(
        query, 
        top_k=5, 
        keyword_weight=0.3,  # Emphasize keyword matches
        chunk_weight=0.3,     # But also consider whole-chunk similarity
        keyword_chunk_weight=0.4,
    )
# Out:
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results

# %%
    
print("\nHybrid Query Results:")
for i, result in enumerate(results):
    print(f"\nResult {i+1} Score: {result['score']:.4f}: Original_score: {result['original_score']:.4f}")
    print(f"Document ID: {result.get('doc_id', '')}")
    print(f"Type of searching: {result.get('result_type', '')}")
    print(f"Keyword: {result.get('keyword','')}")
    print(f"Text: {result['text'][:200]}...")
# Out:
# Hybrid Query Results:
#
# Result 1 Score: 0.2761: Original_score: 0.6903
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: development of machine learning methods together have led toan exploding growth of in-silico material exploration in the areasof 2D materials, catalysts, batteries, photovoltaics, etc.
# 14–18.
# Still, g...
#
# Result 2 Score: 0.2697: Original_score: 0.6742
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: engage/chemrxiv/article-details/63b7181c1f24031e9a1789e0 .
# 28. Ward, L. et al. Matminer: An open source toolkit for materials data mining.
# Comput. Mater. Sci. 152,6 0 –69 (2018).
# 29. Breiman, L. Rando...
#
# Result 3 Score: 0.2691: Original_score: 0.6728
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 4 Score: 0.2104: Original_score: 0.7014
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: machine learning
# Text: [CLS] article open sparse representation for machine learning the properties of defects in 2d materials nikita kazeev1, 2, 6, abdalaziz rashid al - maeeni3, 6, ignat romanov3, maxim faleev4, ruslan lu...
#
# Result 5 Score: 0.1946: Original_score: 0.6488
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: development of machine learning methods together have led toan exploding growth of in-silico material exploration in the areasof 2D materials, catalysts, batteries, photovoltaics, etc.
# 14–18.
# Still, g...

# %%
results
# Out:
# [{'id': 'kw_chunk_72',
#   'score': 0.276121997833252,
#   'original_score': 0.6903049945831299,
#   'result_type': 'keyword_chunk',
#   'text': 'development of machine learning methods together have led toan exploding growth of in-silico material exploration in the areasof 2D materials, catalysts, batteries, photovoltaics, etc.\n14–18.\nStill, great dif ﬁculties arise when trying to apply machine\nlearning to predict properties of defects, which may be due to the\nlack of defect datasets and the challenge in the prediction ofquantum states. Also, there is a great deal of uncertainty when themachine learning of “black box ”nature encounters the nonlinear\nquantum properties in defects. Due to these reasons, there have\nbeen few studies of machine learning applied to defects in solids.The reported studies mainly focus on the prediction of the key\n1Institute for Functional Intelligent Materials, National University of Singapore, 117544 Singapore, Singapore.2Innopolis University, Universitetskaya St 1, Innopolis, Republic of',
#   'keyword': None,
#   'doc_id': 's41699-023-00369-1.pdf',
#   'chunk_id': 72,
#   'metadata': ChunkMetadata(doc_id='s41699-023-00369-1.pdf', page_num=0, chunk_index=6)},
#  {'id': 'kw_chunk_56',
#   'score': 0.2696678876876831,
#   'original_score': 0.6741697192192078,
#   'result_type': 'keyword_chunk',
#   'text': 'engage/chemrxiv/article-details/63b7181c1f24031e9a1789e0 .\n28. Ward, L. et al. Matminer: An open source toolkit for materials data mining.\nComput. Mater. Sci. 152,6 0 –69 (2018).\n29. Breiman, L. Random forests. Mach. Learn. 45,5–32 (2001).\n30. Manzoor, A. et al. Machine learning based methodology to predict point defect\nenergies in multi-principal element alloys. Front. Mater. 8https://\nwww.frontiersin.org/article/10.3389/fmats.2021.673574 (2021).\n31. Ostadhossein, A. et al. Reaxff reactive force- ﬁeld study of molybdenum disul ﬁde\n(MoS\n2).J. Phys. Chem. Lett. 8, 631 –640 (2017).\n32. Patra, T. K. et al. Defect dynamics in 2-d MoS 2probed by using machine learning,\natomistic simulations, and high-resolution microscopy. ACS Nano 12, 8006 –8016\n(2018).\n33. Banik, S. et al. Learning with delayed rewards –A case study on inverse defect\ndesign in 2d materials. ACS Appl. Mater. Interfaces 13, 36455 –36464 (2021).',
#   'keyword': None,
#   'doc_id': 's41524-023-01062-z.pdf',
#   'chunk_id': 56,
#   'metadata': ChunkMetadata(doc_id='s41524-023-01062-z.pdf', page_num=8, chunk_index=56)},
#  {'id': 'kw_chunk_59',
#   'score': 0.2691183567047119,
#   'original_score': 0.6727958917617798,
#   'result_type': 'keyword_chunk',
#   'text': 'processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).\n44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source\npython library for materials analysis. Comput. Mater. Sci. 68, 314 –319 (2013).\n45. Lam Pham, T. et al. Machine learning reveals orbital interaction in materials. Sci.\nTechnol. Adv. Mater. 18, 756 –765 (2017).\n46. Choudhary, K., DeCost, B. & Tavazza, F. Machine learning with force- ﬁeld-inspired\ndescriptors for materials: Fast screening and mapping energy landscape. Phys.\nRev. Mater. 2, 083801 (2018).Table 4. Matminer feature groups used for a defect con ﬁguration\ndescription.\nFeatures Description\nDensity Structure density, volume per atom, maximum\npacking fraction and maximum packing ef ﬁciency\nStructural\nComplexity43Shannon information entropy of a structure\nXRD Powder\nPattern44Powder diffraction of a structure\nOrbital Field\nMatrix45Representation based on the valence shell electronsof neighboring atoms\nJarvisCFID',
#   'keyword': None,
#   'doc_id': 's41524-023-01062-z.pdf',
#   'chunk_id': 59,
#   'metadata': ChunkMetadata(doc_id='s41524-023-01062-z.pdf', page_num=8, chunk_index=59)},
#  {'id': 'kw_1576',
#   'score': 0.2104155421257019,
#   'original_score': 0.7013851404190063,
#   'result_type': 'keyword',
#   'text': '[CLS] article open sparse representation for machine learning the properties of defects in 2d materials nikita kazeev1, 2, 6, abdalaziz rashid al - maeeni3, 6, ignat romanov3, maxim faleev4, ruslan lukin4, alexander tormasov4, a. h. castro neto1, 5, kostya s. [UNK], pengru [UNK] andrey ustyuzhanin1, [UNK] two - dimensional materials offer a promising platform for the next generation of ( opt',
#   'keyword': 'machine learning',
#   'doc_id': 's41524-023-01062-z.pdf',
#   'chunk_id': 59,
#   'metadata': ChunkMetadata(doc_id='s41524-023-01062-z.pdf', page_num=8, chunk_index=59)},
#  {'id': 'chunk_72',
#   'score': 0.19463977217674255,
#   'original_score': 0.6487992405891418,
#   'result_type': 'chunk',
#   'text': 'development of machine learning methods together have led toan exploding growth of in-silico material exploration in the areasof 2D materials, catalysts, batteries, photovoltaics, etc.\n14–18.\nStill, great dif ﬁculties arise when trying to apply machine\nlearning to predict properties of defects, which may be due to the\nlack of defect datasets and the challenge in the prediction ofquantum states. Also, there is a great deal of uncertainty when themachine learning of “black box ”nature encounters the nonlinear\nquantum properties in defects. Due to these reasons, there have\nbeen few studies of machine learning applied to defects in solids.The reported studies mainly focus on the prediction of the key\n1Institute for Functional Intelligent Materials, National University of Singapore, 117544 Singapore, Singapore.2Innopolis University, Universitetskaya St 1, Innopolis, Republic of',
#   'keyword': None,
#   'doc_id': 's41699-023-00369-1.pdf',
#   'chunk_id': 72,
#   'metadata': ChunkMetadata(doc_id='s41699-023-00369-1.pdf', page_num=0, chunk_index=6)}]

# %%
def query_searching(query):
    # Example query - search across all documents
    
    results = rag.process_query(
        query, 
        top_k=5, 
        keyword_weight=0.3,  # Emphasize keyword matches
        chunk_weight=0.3,     # But also consider whole-chunk similarity
        keyword_chunk_weight=0.4,
    )
    
    print(f"\nHybrid Query Results: \n ***  {query}")
    for i, result in enumerate(results):
        print(f"\nResult {i+1} Score: {result['score']:.4f}: Original_score: {result['original_score']:.4f}")
        print(f"Document ID: {result.get('doc_id', '')}")
        print(f"Type of searching: {result.get('result_type', '')}")
        print(f"Keyword: {result.get('keyword','')}")
        print(f"Text: {result['text'][:200]}... \n\n")

# %%
import pandas as pd

df_ground_true = pd.read_csv("../data/data_rag/QA_ai4mat_2articles.csv")

questions = df_ground_true['question'].values.tolist()
answers = df_ground_true['answer'].values.tolist()

# %%
for q in questions:
    #print("****",q)
    query_searching(q)
    #print(8*".-.", "\n")
# Out:
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Which materials are in the dataset?
#
# Result 1 Score: 0.3180: Original_score: 0.7951
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: within hours, such computations are not scalable. The propertiesof each new defect has to be calculated from scratch. The state-of-the-art research paradigm integrated of high throughput simula-
# tions...
#
#
#
# Result 2 Score: 0.3165: Original_score: 0.7913
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
#
#
# Result 3 Score: 0.3158: Original_score: 0.7896
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: materials are notoriously dif ﬁcult to model. Thus, it is very tempting to apply machine learning methods to such systems.
# Unfortunately, there is only a handful of machine learning-friendly material ...
#
#
#
# Result 4 Score: 0.2418: Original_score: 0.8060
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: dataset
# Text: [CLS] computationally ef ﬁcient, and thus allows to probe dynamics on a larger time scale. however, it is not as precise as dft, and doesn ’ t offer a way to predict the electronic properties. the pap...
#
#
#
# Result 5 Score: 0.2351: Original_score: 0.7838
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How many structures are there in the dataset?
#
# Result 1 Score: 0.2906: Original_score: 0.7266
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: defect properties, the structure of the datasets should be carefully
# designed. Our datasets are established in two groups, including
# one structured and the other dispersive (Fig. 1b). The structured
# d...
#
#
#
# Result 2 Score: 0.2861: Original_score: 0.7152
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: aspects of variables, i.e. the 2D material hosts, the defectcomponents, and the defect con ﬁgurations (Fig. 1a). There are
# hundreds of existing 2D materials and even more are expected tobe synthesized...
#
#
#
# Result 3 Score: 0.2825: Original_score: 0.7061
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: Fig. 3. We used pymatgen35toﬁnd the con ﬁgurations, taking
# into account symmetry. The high-density dataset contains asample of randomly generated substitution and vacancy defects
# for all the materials...
#
#
#
# Result 4 Score: 0.2213: Original_score: 0.7376
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: many structures
# Text: ##efects is in ﬁnite. these three variables together contribute to a vast defect space for 2d materials, which is impractical for thorough experimental or even computational investigations. considerin...
#
#
#
# Result 5 Score: 0.2170: Original_score: 0.7233
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: defect properties, the structure of the datasets should be carefully
# designed. Our datasets are established in two groups, including
# one structured and the other dispersive (Fig. 1b). The structured
# d...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How to obtain the dataset?
#
# Result 1 Score: 0.2589: Original_score: 0.6471
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
#
# Result 2 Score: 0.2579: Original_score: 0.6448
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: defect properties, the structure of the datasets should be carefully
# designed. Our datasets are established in two groups, including
# one structured and the other dispersive (Fig. 1b). The structured
# d...
#
#
#
# Result 3 Score: 0.2536: Original_score: 0.6340
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: combined test dataset. Error indicates the standard deviation of the results obtained from 12 experiments with the same datasets and model parameter s, but
# different random initialization. Bold font i...
#
#
#
# Result 4 Score: 0.1995: Original_score: 0.6651
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: dataset
# Text: [CLS] a gpu, and costs 7. 5 cpu core - minutes per structure and 1860 core - hours for the whole 2dmd dataset. model con ﬁgurations are listed in supplementary discussion 1. quantum oscillations predi...
#
#
#
# Result 5 Score: 0.1925: Original_score: 0.6418
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * What is the dataset license?
#
# Result 1 Score: 0.2646: Original_score: 0.6615
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: regulation or exceeds the permitted use, you will need to obtain permission directlyfrom the copyright holder. To view a copy of this license, visit http://
# creativecommons.org/licenses/by/4.0/ .
# © Th...
#
#
#
# Result 2 Score: 0.2610: Original_score: 0.6525
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: indicated otherwise in a credit line to the material. If material is not included in thearticle ’s Creative Commons license and your intended use is not permitted by statutory
# regulation or exceeds th...
#
#
#
# Result 3 Score: 0.2560: Original_score: 0.6399
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: combined test dataset. Error indicates the standard deviation of the results obtained from 12 experiments with the same datasets and model parameter s, but
# different random initialization. Bold font i...
#
#
#
# Result 4 Score: 0.1983: Original_score: 0.6610
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: dataset
# Text: [CLS] computationally ef ﬁcient, and thus allows to probe dynamics on a larger time scale. however, it is not as precise as dft, and doesn ’ t offer a way to predict the electronic properties. the pap...
#
#
#
# Result 5 Score: 0.1949: Original_score: 0.6496
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: regulation or exceeds the permitted use, you will need to obtain permission directlyfrom the copyright holder. To view a copy of this license, visit http://
# creativecommons.org/licenses/by/4.0/ .
# © Th...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * What is the data format?
#
# Result 1 Score: 0.2463: Original_score: 0.6158
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
#
#
# Result 2 Score: 0.2453: Original_score: 0.6133
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
#
# Result 3 Score: 0.2427: Original_score: 0.6067
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: indicated otherwise in a credit line to the material. If material is not included in thearticle ’s Creative Commons license and your intended use is not permitted by statutory
# regulation or exceeds th...
#
#
#
# Result 4 Score: 0.1878: Original_score: 0.6259
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
#
# Result 5 Score: 0.1859: Original_score: 0.6195
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: data
# Text: [CLS] data availability the datasets analyzed during this study are available at https : / / research. constructor. tech / p / 2d - defects - prediction. code availability code used to calculate the r...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How to read the dataset?
#
# Result 1 Score: 0.2665: Original_score: 0.6661
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: combined test dataset. Error indicates the standard deviation of the results obtained from 12 experiments with the same datasets and model parameter s, but
# different random initialization. Bold font i...
#
#
#
# Result 2 Score: 0.2636: Original_score: 0.6591
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: defect properties, the structure of the datasets should be carefully
# designed. Our datasets are established in two groups, including
# one structured and the other dispersive (Fig. 1b). The structured
# d...
#
#
#
# Result 3 Score: 0.2567: Original_score: 0.6419
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
#
# Result 4 Score: 0.2034: Original_score: 0.6780
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: dataset
# Text: [CLS] computationally ef ﬁcient, and thus allows to probe dynamics on a larger time scale. however, it is not as precise as dft, and doesn ’ t offer a way to predict the electronic properties. the pap...
#
#
#
# Result 5 Score: 0.1968: Original_score: 0.6561
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: combined test dataset. Error indicates the standard deviation of the results obtained from 12 experiments with the same datasets and model parameter s, but
# different random initialization. Bold font i...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How to browse the dataset?
#
# Result 1 Score: 0.2618: Original_score: 0.6544
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
#
# Result 2 Score: 0.2564: Original_score: 0.6409
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: defect properties, the structure of the datasets should be carefully
# designed. Our datasets are established in two groups, including
# one structured and the other dispersive (Fig. 1b). The structured
# d...
#
#
#
# Result 3 Score: 0.2499: Original_score: 0.6248
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: small subspace of the whole defect space. The other group of
# dispersive datasets aims to spread data in the large defect space.This is done here by calculating the properties of a wide
# concentration r...
#
#
#
# Result 4 Score: 0.1980: Original_score: 0.6600
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: browse
# Text: can of course relax to a low spin state during the ionic and electronic relaxations ). currently, we are focusing on basic properties of defects at thelevel of single - particle physics and did not in...
#
#
#
# Result 5 Score: 0.1935: Original_score: 0.6451
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 5 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Can I work with the dataset without Python?
#
# Result 1 Score: 0.2627: Original_score: 0.6568
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: combined test dataset. Error indicates the standard deviation of the results obtained from 12 experiments with the same datasets and model parameter s, but
# different random initialization. Bold font i...
#
#
#
# Result 2 Score: 0.2596: Original_score: 0.6489
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: defect properties, the structure of the datasets should be carefully
# designed. Our datasets are established in two groups, including
# one structured and the other dispersive (Fig. 1b). The structured
# d...
#
#
#
# Result 3 Score: 0.2574: Original_score: 0.6436
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
#
#
# Result 4 Score: 0.2020: Original_score: 0.6734
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: dataset without
# Text: [CLS] computationally ef ﬁcient, and thus allows to probe dynamics on a larger time scale. however, it is not as precise as dft, and doesn ’ t offer a way to predict the electronic properties. the pap...
#
#
#
# Result 5 Score: 0.1954: Original_score: 0.6514
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How to obtain the raw VASP files?
#
# Result 1 Score: 0.2476: Original_score: 0.6190
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: regulation or exceeds the permitted use, you will need to obtain permission directlyfrom the copyright holder. To view a copy of this license, visit http://
# creativecommons.org/licenses/by/4.0/ .
# © Th...
#
#
#
# Result 2 Score: 0.2467: Original_score: 0.6167
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: Table 1 continued
# Type Defect site Count Variation range Structure
# Mo S S Energy (eV) HOMO (meV) LUMO (meV)
# V4 vac Se 15 0.197 129 25
# V5 vac Se Se 743 0.430 245 73
# V6 vac vac Se 1415 2.282 203 236
# S1 ...
#
#
#
# Result 3 Score: 0.2421: Original_score: 0.6053
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
#
# Result 4 Score: 0.1900: Original_score: 0.6332
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: Table 1 continued
# Type Defect site Count Variation range Structure
# Mo S S Energy (eV) HOMO (meV) LUMO (meV)
# V4 vac Se 15 0.197 129 25
# V5 vac Se Se 743 0.430 245 73
# V6 vac vac Se 1415 2.282 203 236
# S1 ...
#
#
#
# Result 5 Score: 0.1875: Original_score: 0.6251
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: files
# Text: ##3 0. 430 245 73 v6 vac vac se 1415 2. 282 203 236 s1 w 1 s2 w vac 15 0. 042 15 24 s3 w vac vac 743 0. 193 108 394 s4 w se 15 0. 028 < 10 < 10 s5 w se se 743 0. 079 < 10 < 10 p. huang et al. 4 npj 2d...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * What were the settings used for the DFT computations?
#
# Result 1 Score: 0.2882: Original_score: 0.7204
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: 38. Kresse, G. & Furthmüller, J. Ef ﬁcient iterative schemes for ab initio total-energy
# calculations using a plane-wave basis set. Phys. Rev. B 54, 11169 (1996).
# 39. Kresse, G. & Furthmüller, J. Ef ﬁc...
#
#
#
# Result 2 Score: 0.2814: Original_score: 0.7035
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: computationally ef ﬁcient, and thus allows to probe dynamics on a
# larger time scale. However, it is not as precise as DFT, and doesn ’t
# offer a way to predict the electronic properties.
# The paper is s...
#
#
#
# Result 3 Score: 0.2801: Original_score: 0.7002
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
#
#
# Result 4 Score: 0.2229: Original_score: 0.7431
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: dft computations
# Text: [CLS] computationally ef ﬁcient, and thus allows to probe dynamics on a larger time scale. however, it is not as precise as dft, and doesn ’ t offer a way to predict the electronic properties. the pap...
#
#
#
# Result 5 Score: 0.2174: Original_score: 0.7246
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: 38. Kresse, G. & Furthmüller, J. Ef ﬁcient iterative schemes for ab initio total-energy
# calculations using a plane-wave basis set. Phys. Rev. B 54, 11169 (1996).
# 39. Kresse, G. & Furthmüller, J. Ef ﬁc...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How well the DFT calculations correspond to experiment?
#
# Result 1 Score: 0.3071: Original_score: 0.7678
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: 38. Kresse, G. & Furthmüller, J. Ef ﬁcient iterative schemes for ab initio total-energy
# calculations using a plane-wave basis set. Phys. Rev. B 54, 11169 (1996).
# 39. Kresse, G. & Furthmüller, J. Ef ﬁc...
#
#
#
# Result 2 Score: 0.3055: Original_score: 0.7637
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
#
#
# Result 3 Score: 0.3043: Original_score: 0.7608
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: computationally ef ﬁcient, and thus allows to probe dynamics on a
# larger time scale. However, it is not as precise as DFT, and doesn ’t
# offer a way to predict the electronic properties.
# The paper is s...
#
#
#
# Result 4 Score: 0.2325: Original_score: 0.7750
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: dft calculations
# Text: [CLS] computationally ef ﬁcient, and thus allows to probe dynamics on a larger time scale. however, it is not as precise as dft, and doesn ’ t offer a way to predict the electronic properties. the pap...
#
#
#
# Result 5 Score: 0.2305: Original_score: 0.7683
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: 38. Kresse, G. & Furthmüller, J. Ef ﬁcient iterative schemes for ab initio total-energy
# calculations using a plane-wave basis set. Phys. Rev. B 54, 11169 (1996).
# 39. Kresse, G. & Furthmüller, J. Ef ﬁc...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How to cite the dataset?
#
# Result 1 Score: 0.2689: Original_score: 0.6722
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: indicated otherwise in a credit line to the material. If material is not included in thearticle ’s Creative Commons license and your intended use is not permitted by statutory
# regulation or exceeds th...
#
#
#
# Result 2 Score: 0.2630: Original_score: 0.6576
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: combined test dataset. Error indicates the standard deviation of the results obtained from 12 experiments with the same datasets and model parameter s, but
# different random initialization. Bold font i...
#
#
#
# Result 3 Score: 0.2618: Original_score: 0.6546
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: graphs. Published at the International Conference on Learning Representations(ICLR) 2020. Preprint at https://arXiv.org/abs/2003.03123 (2020).
# 18. Shuaibi, M. et al. Rotation invariant graph neural ne...
#
#
#
# Result 4 Score: 0.2062: Original_score: 0.6874
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: indicated otherwise in a credit line to the material. If material is not included in thearticle ’s Creative Commons license and your intended use is not permitted by statutory
# regulation or exceeds th...
#
#
#
# Result 5 Score: 0.2047: Original_score: 0.6825
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: cite
# Text: ##tions. open access this article is licensed under a creative commons attribution 4. 0 international license, which permits use, sharing, adaptation, distribution and reproduction in any medium or fo...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * What was the procedure for SRGNN quality evaluation?
#
# Result 1 Score: 0.2734: Original_score: 0.6835
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
#
#
# Result 2 Score: 0.2716: Original_score: 0.6790
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
#
#
# Result 3 Score: 0.2673: Original_score: 0.6682
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: Aggregate performance
# We split the dataset into 3 parts: train (60%), validation (20%), and
# test (20%). The split is random and strati ﬁed with the respect to
# each base material. For each model, we us...
#
#
#
# Result 4 Score: 0.2072: Original_score: 0.6906
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: [CLS] natural encoding of the locality of interactions. in the recent open catalyst benchmark5, gnns solidly outperform the physics - based descriptors. therefore, in this section, we only focus on gn...
#
#
#
# Result 5 Score: 0.1960: Original_score: 0.6534
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How is SRGNN different from the baselines?
#
# Result 1 Score: 0.2770: Original_score: 0.6925
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: h-BN High 244 ± 24 227 ± 6 233 ± 4 208±3 260 ± 14
# MoS 2 Low 187 ± 180 46 ± 42 30 ± 2 26.7 ± 0.8 5.7±0.2
# WSe 2 Low 236 ± 224 64 ± 46 32 ± 5 18.3 ± 0.6 8.1±0.6
# Sparse (MEGNet) is our representation impl...
#
#
#
# Result 2 Score: 0.2741: Original_score: 0.6852
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
#
#
# Result 3 Score: 0.2715: Original_score: 0.6786
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
#
#
# Result 4 Score: 0.2070: Original_score: 0.6898
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn different
# Text: . catboost uses matminer featurizers. all the models were trained on the same dataset, containi ng strati ﬁed samples of all the parts of 2dmd dataset. the dataset splitting strategy is described in d...
#
#
#
# Result 5 Score: 0.2056: Original_score: 0.6854
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: h-BN High 244 ± 24 227 ± 6 233 ± 4 208±3 260 ± 14
# MoS 2 Low 187 ± 180 46 ± 42 30 ± 2 26.7 ± 0.8 5.7±0.2
# WSe 2 Low 236 ± 224 64 ± 46 32 ± 5 18.3 ± 0.6 8.1±0.6
# Sparse (MEGNet) is our representation impl...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * What are the limitations of SRGNN?
#
# Result 1 Score: 0.2771: Original_score: 0.6928
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
#
#
# Result 2 Score: 0.2770: Original_score: 0.6926
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: information due to considering only distances as edge features.
# Zitnick et al.18improves handling of angular information.
# Cloudhary et al. presents an Atomistic Line Graph Neural Network
# (ALIGNN)19, a...
#
#
#
# Result 3 Score: 0.2756: Original_score: 0.6889
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
#
#
# Result 4 Score: 0.2124: Original_score: 0.7079
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: [CLS] natural encoding of the locality of interactions. in the recent open catalyst benchmark5, gnns solidly outperform the physics - based descriptors. therefore, in this section, we only focus on gn...
#
#
#
# Result 5 Score: 0.2008: Original_score: 0.6692
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * What is the core idea of SRGNN?
#
# Result 1 Score: 0.2826: Original_score: 0.7064
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
#
#
# Result 2 Score: 0.2779: Original_score: 0.6947
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: information due to considering only distances as edge features.
# Zitnick et al.18improves handling of angular information.
# Cloudhary et al. presents an Atomistic Line Graph Neural Network
# (ALIGNN)19, a...
#
#
#
# Result 3 Score: 0.2769: Original_score: 0.6922
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
#
#
# Result 4 Score: 0.2147: Original_score: 0.7155
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: stacked to provide an expressive deep architecture. letg = ( v, e, u ) be a crystal graph from the previous step, the nodes are represented by vectors v¼fv igjvj i¼0, w h e r e vi2rdv [UNK] the number...
#
#
#
# Result 5 Score: 0.2065: Original_score: 0.6883
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How to run the code?
#
# Result 1 Score: 0.2371: Original_score: 0.5929
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
#
# Result 2 Score: 0.2246: Original_score: 0.5614
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: 38. Kresse, G. & Furthmüller, J. Ef ﬁcient iterative schemes for ab initio total-energy
# calculations using a plane-wave basis set. Phys. Rev. B 54, 11169 (1996).
# 39. Kresse, G. & Furthmüller, J. Ef ﬁc...
#
#
#
# Result 3 Score: 0.2222: Original_score: 0.5555
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: University.
# AUTHOR CONTRIBUTIONS
# P.H., A.U., and K.S.N. conceived the research; P.H. and R.L. done most of the
# calculations, P.H., R.L., M.F., N.K., and A.R.A.-M. participated in data analyses, D.V.A....
#
#
#
# Result 4 Score: 0.1938: Original_score: 0.6460
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: code
# Text: [CLS] data availability the datasets analyzed during this study are available at https : / / research. constructor. tech / p / 2d - defects - prediction. code availability code used to calculate the r...
#
#
#
# Result 5 Score: 0.1767: Original_score: 0.5889
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 5 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Which frameworks were used for SRGNN implementation?
#
# Result 1 Score: 0.2690: Original_score: 0.6725
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
#
#
#
# Result 2 Score: 0.2660: Original_score: 0.6650
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
#
#
# Result 3 Score: 0.2657: Original_score: 0.6643
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: natural encoding of the locality of interactions. In the recent Open
# Catalyst benchmark5, GNNs solidly outperform the physics-based
# descriptors. Therefore, in this section, we only focus on GNNs.
# Xie ...
#
#
#
# Result 4 Score: 0.2039: Original_score: 0.6798
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: [CLS] natural encoding of the locality of interactions. in the recent open catalyst benchmark5, gnns solidly outperform the physics - based descriptors. therefore, in this section, we only focus on gn...
#
#
#
# Result 5 Score: 0.1985: Original_score: 0.6617
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Can SRGNN be developed on a CPU, not a GPU?
#
# Result 1 Score: 0.2774: Original_score: 0.6936
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
#
#
# Result 2 Score: 0.2653: Original_score: 0.6632
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
#
#
# Result 3 Score: 0.2651: Original_score: 0.6628
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: information due to considering only distances as edge features.
# Zitnick et al.18improves handling of angular information.
# Cloudhary et al. presents an Atomistic Line Graph Neural Network
# (ALIGNN)19, a...
#
#
#
# Result 4 Score: 0.2114: Original_score: 0.7045
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: gpu
# Text: [CLS] prediction quality. the prediction quality for mos 2and wse 2is improved by a factor of 1. 3 – 4. 8, but this is outweighted by a factor of 1. 06 – 1. 15 increase in mae for the other materials....
#
#
#
# Result 5 Score: 0.2041: Original_score: 0.6803
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * What is the code license?
#
# Result 1 Score: 0.2624: Original_score: 0.6561
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: indicated otherwise in a credit line to the material. If material is not included in thearticle ’s Creative Commons license and your intended use is not permitted by statutory
# regulation or exceeds th...
#
#
#
# Result 2 Score: 0.2563: Original_score: 0.6409
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: regulation or exceeds the permitted use, you will need to obtain permission directlyfrom the copyright holder. To view a copy of this license, visit http://
# creativecommons.org/licenses/by/4.0/ .
# © Th...
#
#
#
# Result 3 Score: 0.2317: Original_score: 0.5793
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: Publisher ’s note Springer Nature remains neutral with regard to jurisdictional claims
# in published maps and institutional af ﬁliations.
# Open Access This article is licensed under a Creative Commons
# A...
#
#
#
# Result 4 Score: 0.1990: Original_score: 0.6633
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: license
# Text: [CLS] novoselov, pengru huang or andrey ustyuzhanin. reprints and permission information is available at http : / / www. nature. com / reprints publisher ’ s note springer nature remains neutral with ...
#
#
#
# Result 5 Score: 0.1916: Original_score: 0.6388
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: regulation or exceeds the permitted use, you will need to obtain permission directlyfrom the copyright holder. To view a copy of this license, visit http://
# creativecommons.org/licenses/by/4.0/ .
# © Th...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How to cite the code?
#
# Result 1 Score: 0.2740: Original_score: 0.6851
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: indicated otherwise in a credit line to the material. If material is not included in thearticle ’s Creative Commons license and your intended use is not permitted by statutory
# regulation or exceeds th...
#
#
#
# Result 2 Score: 0.2490: Original_score: 0.6226
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: DATA AVAILABILITY
# The datasets analyzed during this study are available at https://
# research.constructor.tech/p/2d-defects-prediction .
# CODE AVAILABILITY
# Code used to calculate the results of this stu...
#
#
#
# Result 3 Score: 0.2470: Original_score: 0.6175
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: regulation or exceeds the permitted use, you will need to obtain permission directlyfrom the copyright holder. To view a copy of this license, visit http://
# creativecommons.org/licenses/by/4.0/ .
# © Th...
#
#
#
# Result 4 Score: 0.2104: Original_score: 0.7012
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: indicated otherwise in a credit line to the material. If material is not included in thearticle ’s Creative Commons license and your intended use is not permitted by statutory
# regulation or exceeds th...
#
#
#
# Result 5 Score: 0.2076: Original_score: 0.6920
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: cite
# Text: ##tions. open access this article is licensed under a creative commons attribution 4. 0 international license, which permits use, sharing, adaptation, distribution and reproduction in any medium or fo...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Which materials has the SRGNN been trained on?
#
# Result 1 Score: 0.3018: Original_score: 0.7544
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
#
#
# Result 2 Score: 0.2977: Original_score: 0.7442
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: 3564 –3572 (2019).
# 11. Xie, T. & Grossman, J. C. Crystal graph convolutional neural networks for an
# accurate and interpretable prediction of material properties. Phys. Rev. Lett. 120,
# 145301 (2018).
# 1...
#
#
#
# Result 3 Score: 0.2967: Original_score: 0.7418
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: 13. Schütt, K. T., Sauceda, H. E., Kindermans, P.-J., Tkatchenko, A. & Müller, K.-R.
# Schnet –a deep learning architecture for molecules and materials. J. Chem. Phys.
# 148, 241722 (2018).
# 14. Gasteiger,...
#
#
#
# Result 4 Score: 0.2315: Original_score: 0.7716
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: each structure using a vector with the set of atomic numbers of the pristine material, e. g. ( 42, 16 ) for mos 2. this simple approach is suf ﬁcient on our structures. as a future direction, in case ...
#
#
#
# Result 5 Score: 0.2204: Original_score: 0.7348
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Which materials can the SRGNN be trained on?
#
# Result 1 Score: 0.3030: Original_score: 0.7575
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
#
#
# Result 2 Score: 0.2972: Original_score: 0.7431
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: 3564 –3572 (2019).
# 11. Xie, T. & Grossman, J. C. Crystal graph convolutional neural networks for an
# accurate and interpretable prediction of material properties. Phys. Rev. Lett. 120,
# 145301 (2018).
# 1...
#
#
#
# Result 3 Score: 0.2949: Original_score: 0.7374
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: Phys. 86, 253 (2014).
# 9. Smith, J. S., Isayev, O. & Roitberg, A. E. Ani-1: an extensible neural network
# potential with dft accuracy at force ﬁeld computational cost. Chem. Sci. 8,
# 3192 –3203 (2017).
# 1...
#
#
#
# Result 4 Score: 0.2321: Original_score: 0.7737
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: each structure using a vector with the set of atomic numbers of the pristine material, e. g. ( 42, 16 ) for mos 2. this simple approach is suf ﬁcient on our structures. as a future direction, in case ...
#
#
#
# Result 5 Score: 0.2193: Original_score: 0.7310
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 5 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Which defect types can the SRGNN be trained on?
#
# Result 1 Score: 0.2972: Original_score: 0.7429
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: crystal as a vector of atomic numbers.
# Dataset
# We established a machine learning friendly 2D material defect
# database (2DMD)
# 15for the training and evaluation of models. The
# datasets contain structure...
#
#
#
# Result 2 Score: 0.2971: Original_score: 0.7426
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
#
#
# Result 3 Score: 0.2948: Original_score: 0.7371
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: For formation energy, just enabling the zcoordinate difference
# in sparse representation edges allows the Sparse-Z model to
# outperform the Full model everywhere except h-BN; adding
# pristine atom specie...
#
#
#
# Result 4 Score: 0.2239: Original_score: 0.7464
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: defect types
# Text: [CLS] class imbalance, we use weighted mean absolute error ( mae ) as the quality metric during both training and evaluation : mae ¼ pn i¼1jyi / c0yijwipn i¼1wi ; ( 3 ) where wiis the weight assigned ...
#
#
#
# Result 5 Score: 0.2174: Original_score: 0.7247
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: crystal as a vector of atomic numbers.
# Dataset
# We established a machine learning friendly 2D material defect
# database (2DMD)
# 15for the training and evaluation of models. The
# datasets contain structure...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 7 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How many structures are needed for SRGNN training?
#
# Result 1 Score: 0.2933: Original_score: 0.7334
# Document ID: s41524-023-01062-z.pdf
# ...
# ...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * What is the inference speed of a SRGNN?
#
# Result 1 Score: 0.2913: Original_score: 0.7283
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
#
#
# Result 2 Score: 0.2868: Original_score: 0.7170
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
#
#
# Result 3 Score: 0.2827: Original_score: 0.7066
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
#
#
#
# Result 4 Score: 0.2182: Original_score: 0.7274
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
#
#
# Result 5 Score: 0.2160: Original_score: 0.7199
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: [CLS] natural encoding of the locality of interactions. in the recent open catalyst benchmark5, gnns solidly outperform the physics - based descriptors. therefore, in this section, we only focus on gn...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Which properties can be predicted using SRGNN?
#
# Result 1 Score: 0.3102: Original_score: 0.7754
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: accuracy compared to the state-of-the-art general methods. The
# high accuracy allows to reproduce the nonlinear non-monotonic
# property-distance correlation of defects which is a combination ofthe quant...
#
#
#
# Result 2 Score: 0.3092: Original_score: 0.7730
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: natural encoding of the locality of interactions. In the recent Open
# Catalyst benchmark5, GNNs solidly outperform the physics-based
# descriptors. Therefore, in this section, we only focus on GNNs.
# Xie ...
#
#
#
# Result 3 Score: 0.3032: Original_score: 0.7581
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: graphs. Published at the International Conference on Learning Representations(ICLR) 2020. Preprint at https://arXiv.org/abs/2003.03123 (2020).
# 18. Shuaibi, M. et al. Rotation invariant graph neural ne...
#
#
#
# Result 4 Score: 0.2355: Original_score: 0.7850
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: [CLS] natural encoding of the locality of interactions. in the recent open catalyst benchmark5, gnns solidly outperform the physics - based descriptors. therefore, in this section, we only focus on gn...
#
#
#
# Result 5 Score: 0.2301: Original_score: 0.7670
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: accuracy compared to the state-of-the-art general methods. The
# high accuracy allows to reproduce the nonlinear non-monotonic
# property-distance correlation of defects which is a combination ofthe quant...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * What was the quality of SRGNN for each property and material?
#
# Result 1 Score: 0.2917: Original_score: 0.7293
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: accuracy compared to the state-of-the-art general methods. The
# high accuracy allows to reproduce the nonlinear non-monotonic
# property-distance correlation of defects which is a combination ofthe quant...
#
#
#
# Result 2 Score: 0.2873: Original_score: 0.7182
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: h-BN High 244 ± 24 227 ± 6 233 ± 4 208±3 260 ± 14
# MoS 2 Low 187 ± 180 46 ± 42 30 ± 2 26.7 ± 0.8 5.7±0.2
# WSe 2 Low 236 ± 224 64 ± 46 32 ± 5 18.3 ± 0.6 8.1±0.6
# Sparse (MEGNet) is our representation impl...
#
#
#
# Result 3 Score: 0.2870: Original_score: 0.7175
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
#
#
# Result 4 Score: 0.2183: Original_score: 0.7278
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: reproduce the nonlinear non - monotonic property - distance correlation of defects which is a combination ofthe quantum mechanic effect and the periodic lattice nature in 2dmaterials. the general meth...
#
#
#
# Result 5 Score: 0.2109: Original_score: 0.7030
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: h-BN High 244 ± 24 227 ± 6 233 ± 4 208±3 260 ± 14
# MoS 2 Low 187 ± 180 46 ± 42 30 ± 2 26.7 ± 0.8 5.7±0.2
# WSe 2 Low 236 ± 224 64 ± 46 32 ± 5 18.3 ± 0.6 8.1±0.6
# Sparse (MEGNet) is our representation impl...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 7 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Can pre-trained SRGNN be used out-of-the-box?
#
# Result 1 Score: 0.2782: Original_score: 0.6954
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: natural encoding of the locality of interactions. In the recent Open
# Catalyst benchmark5, GNNs solidly outperform the physics-based
# descriptors. Therefore, in this section, we only focus on GNNs.
# Xie ...
#
#
#
# Result 2 Score: 0.2753: Original_score: 0.6883
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: graphs. Published at the International Conference on Learning Representations(ICLR) 2020. Preprint at https://arXiv.org/abs/2003.03123 (2020).
# 18. Shuaibi, M. et al. Rotation invariant graph neural ne...
#
#
#
# Result 3 Score: 0.2738: Original_score: 0.6846
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
#
#
# Result 4 Score: 0.2132: Original_score: 0.7106
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: [CLS] natural encoding of the locality of interactions. in the recent open catalyst benchmark5, gnns solidly outperform the physics - based descriptors. therefore, in this section, we only focus on gn...
#
#
#
# Result 5 Score: 0.2055: Original_score: 0.6851
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: graphs. Published at the International Conference on Learning Representations(ICLR) 2020. Preprint at https://arXiv.org/abs/2003.03123 (2020).
# 18. Shuaibi, M. et al. Rotation invariant graph neural ne...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How well do SRGNN results correspond to experiment?
#
# Result 1 Score: 0.2944: Original_score: 0.7361
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: h-BN High 244 ± 24 227 ± 6 233 ± 4 208±3 260 ± 14
# MoS 2 Low 187 ± 180 46 ± 42 30 ± 2 26.7 ± 0.8 5.7±0.2
# WSe 2 Low 236 ± 224 64 ± 46 32 ± 5 18.3 ± 0.6 8.1±0.6
# Sparse (MEGNet) is our representation impl...
#
#
#
# Result 2 Score: 0.2910: Original_score: 0.7274
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: combined test dataset. Error indicates the standard deviation of the results obtained from 12 experiments with the same datasets and model parameter s, but
# different random initialization. Bold font i...
#
#
#
# Result 3 Score: 0.2866: Original_score: 0.7164
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: 13. Schütt, K. T., Sauceda, H. E., Kindermans, P.-J., Tkatchenko, A. & Müller, K.-R.
# Schnet –a deep learning architecture for molecules and materials. J. Chem. Phys.
# 148, 241722 (2018).
# 14. Gasteiger,...
#
#
#
# Result 4 Score: 0.2212: Original_score: 0.7372
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: electrons and hence non - zero magnetic momentum. therefore, dft was computed taking into accounttwo channels of spin - up and spin - down bands, resulting in themajority and minority homo - lumo gaps...
#
#
#
# Result 5 Score: 0.2178: Original_score: 0.7259
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: h-BN High 244 ± 24 227 ± 6 233 ± 4 208±3 260 ± 14
# MoS 2 Low 187 ± 180 46 ± 42 30 ± 2 26.7 ± 0.8 5.7±0.2
# WSe 2 Low 236 ± 224 64 ± 46 32 ± 5 18.3 ± 0.6 8.1±0.6
# Sparse (MEGNet) is our representation impl...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 5 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Can I use SRGNN in place of DFT?
#
# Result 1 Score: 0.2807: Original_score: 0.7016
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: information due to considering only distances as edge features.
# Zitnick et al.18improves handling of angular information.
# Cloudhary et al. presents an Atomistic Line Graph Neural Network
# (ALIGNN)19, a...
#
#
#
# Result 2 Score: 0.2788: Original_score: 0.6970
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
#
#
# Result 3 Score: 0.2749: Original_score: 0.6873
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: Phys. 86, 253 (2014).
# 9. Smith, J. S., Isayev, O. & Roitberg, A. E. Ani-1: an extensible neural network
# potential with dft accuracy at force ﬁeld computational cost. Chem. Sci. 8,
# 3192 –3203 (2017).
# 1...
#
#
#
# Result 4 Score: 0.2109: Original_score: 0.7031
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: the low - density structures with defects andperformed initial computational experiments using catboost + matminer and schnet. a. t. contributed to discussion. a. h. c. n. proposed eos. p. h. did the ...
#
#
#
# Result 5 Score: 0.2053: Original_score: 0.6843
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 23 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * How can I use SRGNN to find materials for solar panels/transistors/photodetectors/single photon emitters/quantum computers?
#
# Result 1 Score: 0.3126: Original_score: 0.7816
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: within hours, such computations are not scalable. The propertiesof each new defect has to be calculated from scratch. The state-of-the-art research paradigm integrated of high throughput simula-
# tions...
#
#
#
# Result 2 Score: 0.3084: Original_score: 0.7709
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: arXiv.2010.09435 (2020).
# 15. Mounet, N. et al. Two-dimensional materials from high-throughput computa-
# tional exfoliation of experimentally known compounds. Nat. Nanotechnol. 13
# ,
# 246–252 (2018).
# 16. ...
#
#
#
# Result 3 Score: 0.3072: Original_score: 0.7681
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
#
#
# Result 4 Score: 0.2356: Original_score: 0.7855
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: within hours, such computations are not scalable. The propertiesof each new defect has to be calculated from scratch. The state-of-the-art research paradigm integrated of high throughput simula-
# tions...
#
#
#
# Result 5 Score: 0.2320: Original_score: 0.7735
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: materials
# Text: [CLS] article open sparse representation for machine learning the properties of defects in 2d materials nikita kazeev1, 2, 6, abdalaziz rashid al - maeeni3, 6, ignat romanov3, maxim faleev4, ruslan lu...
#
#
# Retrieving: 1 keyword results, 1 chunk results, 3 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results
#
# Hybrid Query Results:
#  ***  * Is SRGNN patented?
#
# Result 1 Score: 0.2579: Original_score: 0.6448
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: 13. Schütt, K. T., Sauceda, H. E., Kindermans, P.-J., Tkatchenko, A. & Müller, K.-R.
# Schnet –a deep learning architecture for molecules and materials. J. Chem. Phys.
# 148, 241722 (2018).
# 14. Gasteiger,...
#
#
#
# Result 2 Score: 0.2562: Original_score: 0.6404
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: regulation or exceeds the permitted use, you will need to obtain permission directlyfrom the copyright holder. To view a copy of this license, visit http://
# creativecommons.org/licenses/by/4.0/ .
# © Th...
#
#
#
# Result 3 Score: 0.2553: Original_score: 0.6384
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: information due to considering only distances as edge features.
# Zitnick et al.18improves handling of angular information.
# Cloudhary et al. presents an Atomistic Line Graph Neural Network
# (ALIGNN)19, a...
#
#
#
# Result 4 Score: 0.1949: Original_score: 0.6497
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: [CLS] natural encoding of the locality of interactions. in the recent open catalyst benchmark5, gnns solidly outperform the physics - based descriptors. therefore, in this section, we only focus on gn...
#
#
#
# Result 5 Score: 0.1925: Original_score: 0.6416
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: regulation or exceeds the permitted use, you will need to obtain permission directlyfrom the copyright holder. To view a copy of this license, visit http://
# creativecommons.org/licenses/by/4.0/ .
# © Th...
