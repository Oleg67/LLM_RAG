# %% [markdown]
# # RAPTOR: Recursive Abstractive Processing for Tree-Organized Retrieval

# %%
## python=3.9
#!pip install --upgrade sentence_transformers

# %%
#!pip install pandas
#!pip install PyPDF2
#!pip install ragas
#!pip install termcolor

# %%
# NOTE: An OpenAI API key must be set here for application initialization, even if not in use.
# If you're not utilizing OpenAI models, assign a placeholder string (e.g., "not_used").
import os
try:
    from .utils import OPENAI_API_KEY
except:
    path = os.getcwd()
    os.chdir('/home/oleg/SIT/LLM')
    #print(os.getcwd())
    from utils import OPENAI_API_KEY
    os.chdir(path)


os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

#os.environ["OPENAI_API_KEY"] = "your-openai-key"

# %% [markdown]
# 1) **Building**: RAPTOR recursively embeds, clusters, and summarizes chunks of text to construct a tree with varying levels of summarization from the bottom up. You can create a tree from the text in 'sample.txt' using `RA.add_documents(text)`.
#
# 2) **Querying**: At inference time, the RAPTOR model retrieves information from this tree, integrating data across lengthy documents at different abstraction levels. You can perform queries on the tree with `RA.answer_question`.

# %% [markdown]
# ### Building the tree

# %%
#os.environ["HF_HUB_DISABLE_TELEMETRY"] = "1"
from raptor import RetrievalAugmentation, RetrievalAugmentationConfig
# Out:
# 2024-12-10 18:07:03,928 - PyTorch version 2.5.1 available.
# 2024-12-10 18:07:04,160 - Loading faiss with AVX2 support.
# 2024-12-10 18:07:04,176 - Successfully loaded faiss with AVX2 support.

# %% [markdown]
# ### Apply to ai4mat articles

# %%
pdf_list = ["/home/oleg/SIT/LLM/data/data_rag/s41524-023-01062-z.pdf",
    "/home/oleg/SIT/LLM//data/data_rag/s41699-023-00369-1.pdf"
           ]
         #   "https://github.com/HSE-LAMBDA/ai4material_design/tree/main/docs/CONSTRUCTOR-MOCK.md"
         #   "https://github.com/HSE-LAMBDA/ai4material_design/blob/main/docs/CONSTRUCTOR.md",
         #   "https://github.com/HSE-LAMBDA/ai4material_design/blob/main/docs/DATA.md",
         #   "https://github.com/HSE-LAMBDA/ai4material_design/blob/main/docs/ENVIRONMENT.md",
         #   "https://github.com/HSE-LAMBDA/ai4material_design/blob/main/docs/GENERATING-CONSTRUCTOR.md",
         #   "https://github.com/HSE-LAMBDA/ai4material_design/blob/main/docs/GENERATING-MOCK.md",
         #   "https://github.com/HSE-LAMBDA/ai4material_design/blob/main/docs/PILOT.md",
         #   "https://github.com/HSE-LAMBDA/ai4material_design/blob/main/docs/SPARSE-PAPER.md"
          #  "https://www.nature.com/articles/s41377-024-01407-3",
          #  "https://www.nature.com/articles/s41565-023-01407-1",
          #  "https://www.nature.com/articles/s41699-023-00369-1",

# %%
from raptor import BaseSummarizationModel, BaseQAModel
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_core.output_parsers import JsonOutputParser

class CustomSummarizationModel(BaseSummarizationModel):
    def __init__(self, model="gpt-4o-mini", **kwargs):
        super().__init__( **kwargs)
        self.llm = ChatOpenAI(model=model, temperature=0.) 
        
        pass

    def summarize(self, context, max_tokens=100):
        prompt = PromptTemplate.from_template("""
You are an expert in analyzing scientific articles.
You are given "Text":
###
{context}
--------------
Your task is to give a short summary of "Text" of no more than {max_tokens}.
Output is a string format.
"""
                                             )
        # Return the summary as a string
        agent = prompt | self.llm 
        summary = agent.invoke({'context': context, 'max_tokens':max_tokens})
        return summary.content


class CustomQAModel(BaseQAModel):
    def __init__(self, model="gpt-4o-mini", **kwargs):
        super().__init__(**kwargs)
        self.llm = ChatOpenAI(model=model, temperature=0.)
        
        pass

    def answer_question(self, context, question):
         # Define prompt
        prompt = PromptTemplate.from_template("""
    Human: You are an AI assistant , an expert in machine learning and the quantum physics. 
    You are able to find answers to the questions from the contextual passage snippets provided.
    \n
    Use the following pieces of information enclosed in <context> tags 
    to provide an answer to the question enclosed in <question> tags.
    <context> : {context}
    
    <question> :{question}
    
    if you do not know the answer, just say that you don't know. Do not make up an answer.
    """
                                             )
        agent = prompt | self.llm 
        answer = agent.invoke({'context': context, 'question':question})
        return answer.content

# %%
su = CustomSummarizationModel()
su.__dict__
# Out:
# {'llm': ChatOpenAI(client=<openai.resources.chat.completions.Completions object at 0x7fd84d6b5790>, async_client=<openai.resources.chat.completions.AsyncCompletions object at 0x7fd84d6be940>, root_client=<openai.OpenAI object at 0x7fd9880ac1f0>, root_async_client=<openai.AsyncOpenAI object at 0x7fd84d6b57f0>, model_name='gpt-4o-mini', temperature=0.0, model_kwargs={}, openai_api_key=SecretStr('**********'))}

# %%
WORKING_DIR = "./ai4mat"



if not os.path.exists(WORKING_DIR):
    os.mkdir(WORKING_DIR)

mode = True
if mode:
    RA_conf = RetrievalAugmentationConfig(
        #tree_builder_config=None,
        #tree_retriever_config=None,  # Change from default instantiation
        qa_model=CustomQAModel(),
        #embedding_model=None,
        summarization_model=CustomSummarizationModel(),
        #tree_builder_type="cluster",
        # New parameters for TreeRetrieverConfig and TreeBuilderConfig
        # TreeRetrieverConfig arguments
        #tr_tokenizer=None,
        #tr_threshold=0.5,
        #tr_top_k=10,
        #tr_selection_mode="top_k",
        #tr_context_embedding_model="OpenAI",
        #tr_embedding_model=None,
        #tr_num_layers=3,
        #tr_start_layer=None,
        # TreeBuilderConfig arguments
        #tb_tokenizer=None,
        tb_max_tokens=300,
        tb_num_layers=3,
        tb_threshold=0.8,
        #tb_top_k=10,
        #tb_selection_mode="top_k",
        tb_summarization_length=300,
        #tb_summarization_model=CustomSummarizationModel(),
        #tb_embedding_models=None,
        #tb_cluster_embedding_model="OpenAI",
    )
    RA = RetrievalAugmentation(RA_conf)
    #RA.tree_builder.max_tokens = 1000
    #RA.tree_builder.summarization_length = 1000
    #RA.tree_builder.top_k = 10
    #RA.tree_builder.summarization_model = CustomSummarizationModel()
    
    
else:    
    RA = RetrievalAugmentation()
# Out:
# 2024-12-10 18:13:30,499 - Successfully initialized TreeBuilder with Config
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 300
#             Num Layers: 3
#             Threshold: 0.8
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 300
#             Summarization Model: <__main__.CustomSummarizationModel object at 0x7fd84c388d60>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84d0d7940>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
# 2024-12-10 18:13:30,500 - Successfully initialized ClusterTreeBuilder with Config
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 300
#             Num Layers: 3
#             Threshold: 0.8
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 300
#             Summarization Model: <__main__.CustomSummarizationModel object at 0x7fd84c388d60>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84d0d7940>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
# 2024-12-10 18:13:30,501 - Successfully initialized RetrievalAugmentation with Config
#         RetrievalAugmentationConfig:
#
#         TreeBuilderConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Max Tokens: 300
#             Num Layers: 3
#             Threshold: 0.8
#             Top K: 5
#             Selection Mode: top_k
#             Summarization Length: 300
#             Summarization Model: <__main__.CustomSummarizationModel object at 0x7fd84c388d60>
#             Embedding Models: {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84d0d7940>}
#             Cluster Embedding Model: OpenAI
#
#         Reduction Dimension: 10
#         Clustering Algorithm: RAPTOR_Clustering
#         Clustering Parameters: {}
#
#
#
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
#
#             QA Model: <__main__.CustomQAModel object at 0x7fd84d110640>
#             Tree Builder Type: cluster

# %%
from PyPDF2 import PdfReader
import nest_asyncio
nest_asyncio.apply()

for pdf in pdf_list:

    # Create a PdfReader instance
    reader = PdfReader(pdf)
    for page in reader.pages:
        RA.add_documents(page.extract_text())
    #RA.add_documents(text_content.decode('utf-8'))
    #RA.add_documents(pdf)
# Out:
# 2024-12-10 18:13:36,247 - Creating Leaf Nodes
# 2024-12-10 18:13:36,571 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:36,574 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:36,634 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:36,658 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:36,662 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:36,667 - Created 5 Leaf Embeddings
# 2024-12-10 18:13:36,668 - Building All Nodes
# 2024-12-10 18:13:36,674 - Using Cluster TreeBuilder
# 2024-12-10 18:13:36,675 - Constructing Layer 0
# 2024-12-10 18:13:36,676 - Stopping Layer construction: Cannot Create More Layers. Total Layers in tree: 0
# 2024-12-10 18:13:36,676 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-12-10 18:13:36,731 - Warning: Overwriting existing tree. Did you mean to call 'add_to_existing'
# 2024-12-10 18:13:36,733 - Creating Leaf Nodes
# 2024-12-10 18:13:37,085 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,088 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,097 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,135 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,138 - Created 4 Leaf Embeddings
# 2024-12-10 18:13:37,138 - Building All Nodes
# 2024-12-10 18:13:37,142 - Using Cluster TreeBuilder
# 2024-12-10 18:13:37,143 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-12-10 18:13:37,166 - Warning: Overwriting existing tree. Did you mean to call 'add_to_existing'
# 2024-12-10 18:13:37,169 - Creating Leaf Nodes
# 2024-12-10 18:13:37,490 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,547 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,559 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,577 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,584 - Created 4 Leaf Embeddings
# 2024-12-10 18:13:37,586 - Building All Nodes
# 2024-12-10 18:13:37,591 - Using Cluster TreeBuilder
# 2024-12-10 18:13:37,593 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-12-10 18:13:37,640 - Warning: Overwriting existing tree. Did you mean to call 'add_to_existing'
# 2024-12-10 18:13:37,644 - Creating Leaf Nodes
# 2024-12-10 18:13:37,901 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,946 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,959 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:37,997 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:38,011 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:38,311 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:38,320 - Created 6 Leaf Embeddings
# 2024-12-10 18:13:38,322 - Building All Nodes
# 2024-12-10 18:13:38,343 - Using Cluster TreeBuilder
# 2024-12-10 18:13:38,345 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-12-10 18:13:38,440 - Warning: Overwriting existing tree. Did you mean to call 'add_to_existing'
# 2024-12-10 18:13:38,442 - Creating Leaf Nodes
# 2024-12-10 18:13:38,668 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:38,714 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:39,232 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:39,241 - Created 3 Leaf Embeddings
# 2024-12-10 18:13:39,244 - Building All Nodes
# 2024-12-10 18:13:39,255 - Using Cluster TreeBuilder
# 2024-12-10 18:13:39,257 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-12-10 18:13:39,297 - Warning: Overwriting existing tree. Did you mean to call 'add_to_existing'
# 2024-12-10 18:13:39,300 - Creating Leaf Nodes
# 2024-12-10 18:13:39,643 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:39,650 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:39,656 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:39,663 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:39,675 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:39,688 - Created 5 Leaf Embeddings
# 2024-12-10 18:13:39,690 - Building All Nodes
# 2024-12-10 18:13:39,698 - Using Cluster TreeBuilder
# 2024-12-10 18:13:39,699 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-12-10 18:13:39,953 - Warning: Overwriting existing tree. Did you mean to call 'add_to_existing'
# 2024-12-10 18:13:39,954 - Creating Leaf Nodes
# 2024-12-10 18:13:40,256 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:44,047 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:44,056 - Created 2 Leaf Embeddings
# 2024-12-10 18:13:44,060 - Building All Nodes
# 2024-12-10 18:13:44,070 - Using Cluster TreeBuilder
# 2024-12-10 18:13:44,072 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-12-10 18:13
- HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:48,816 - Created 7 Leaf Embeddings
# 2024-12-10 18:13:48,817 - Building All Nodes
# 2024-12-10 18:13:48,823 - Using Cluster TreeBuilder
# 2024-12-10 18:13:48,823 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-12-10 18:13:48,865 - Warning: Overwriting existing tree. Did you mean to call 'add_to_existing'
# 2024-12-10 18:13:48,867 - Creating Leaf Nodes
# 2024-12-10 18:13:49,167 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:49,170 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:49,234 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:49,591 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:49,652 - Created 4 Leaf Embeddings
# 2024-12-10 18:13:49,652 - Building All Nodes
# 2024-12-10 18:13:49,656 - Using Cluster TreeBuilder
# 2024-12-10 18:13:49,657 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-12-10 18:13:49,702 - Warning: Overwriting existing tree. Did you mean to call 'add_to_existing'
# 2024-12-10 18:13:49,706 - Creating Leaf Nodes
# 2024-12-10 18:13:49,986 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:49,989 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:50,023 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:50,028 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:50,071 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:50,073 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:50,098 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:50,160 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:50,234 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:50,601 - Created 9 Leaf Embeddings
# 2024-12-10 18:13:50,602 - Building All Nodes
# 2024-12-10 18:13:50,610 - Using Cluster TreeBuilder
# 2024-12-10 18:13:50,611 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None
#
# 2024-12-10 18:13:50,643 - Warning: Overwriting existing tree. Did you mean to call 'add_to_existing'
# 2024-12-10 18:13:50,646 - Creating Leaf Nodes
# 2024-12-10 18:13:51,011 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:51,015 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:51,018 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:51,064 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:13:51,214 - Created 4 Leaf Embeddings
# 2024-12-10 18:13:51,215 - Building All Nodes
# 2024-12-10 18:13:51,230 - Using Cluster TreeBuilder
# 2024-12-10 18:13:51,234 - Successfully initialized TreeRetriever with Config
#         TreeRetrieverConfig:
#             Tokenizer: <Encoding 'cl100k_base'>
#             Threshold: 0.5
#             Top K: 5
#             Selection Mode: top_k
#             Context Embedding Model: OpenAI
#             Embedding Model: <raptor.EmbeddingModels.OpenAIEmbeddingModel object at 0x7fd84c2081f0>
#             Num Layers: None
#             Start Layer: None

# %%
RA.tree_builder.__dict__
# Out:
# {'tokenizer': <Encoding 'cl100k_base'>,
#  'max_tokens': 300,
#  'num_layers': 0,
#  'top_k': 5,
#  'threshold': 0.8,
#  'selection_mode': 'top_k',
#  'summarization_length': 300,
#  'summarization_model': <__main__.CustomSummarizationModel at 0x7fd84c388d60>,
#  'embedding_models': {'OpenAI': <raptor.EmbeddingModels.OpenAIEmbeddingModel at 0x7fd84d0d7940>},
#  'cluster_embedding_model': 'OpenAI',
#  'reduction_dimension': 10,
#  'clustering_algorithm': raptor.cluster_utils.RAPTOR_Clustering,
#  'clustering_params': {}}

# %%
RA.tree.__dict__
# Out:
# {'all_nodes': {0: <raptor.tree_structures.Node at 0x7fd84c346100>,
#   3: <raptor.tree_structures.Node at 0x7fd84c3c37c0>,
#   1: <raptor.tree_structures.Node at 0x7fd84c3c3430>,
#   2: <raptor.tree_structures.Node at 0x7fd84d0f0580>},
#  'root_nodes': {0: <raptor.tree_structures.Node at 0x7fd84c346100>,
#   3: <raptor.tree_structures.Node at 0x7fd84c3c37c0>,
#   1: <raptor.tree_structures.Node at 0x7fd84c3c3430>,
#   2: <raptor.tree_structures.Node at 0x7fd84d0f0580>},
#  'leaf_nodes': {0: <raptor.tree_structures.Node at 0x7fd84c2c7d90>,
#   3: <raptor.tree_structures.Node at 0x7fd84d28fd30>,
#   1: <raptor.tree_structures.Node at 0x7fd84c346580>,
#   2: <raptor.tree_structures.Node at 0x7fd84d0d3970>},
#  'num_layers': 0,
#  'layer_to_nodes': {0: [<raptor.tree_structures.Node at 0x7fd84c2c7d90>,
#    <raptor.tree_structures.Node at 0x7fd84d28fd30>,
#    <raptor.tree_structures.Node at 0x7fd84c346580>,
#    <raptor.tree_structures.Node at 0x7fd84d0d3970>]}}

# %% [markdown]
# #### Load Test Q&A

# %%
import pandas as pd

df_ground_true = pd.read_csv("/home/oleg/SIT/LLM/data/data_rag/QA_ai4mat_2articles.csv")

questions = df_ground_true['question'].values.tolist()
answers = df_ground_true['answer'].values.tolist()

# %%
answer = RA.answer_question(question=questions[0])
print("Question:", questions[0])
print("Answer: ", answer)
# Out:
# 2024-12-10 18:14:24,313 - Using collapsed_tree
# 2024-12-10 18:14:24,700 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:25,210 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# Question: * Which materials are in the dataset?
# Answer:  I don't know.

# %% [markdown]
# ### Evaluate metrics on Test Q&A

# %%
from ragas.metrics import (
    #context_utilization,
    #context_entity_recall,
    #context_relevancy,
    answer_relevancy,
    answer_correctness, 
    faithfulness,
    context_precision,
    context_recall,
)

from datasets import Dataset 
from tqdm import tqdm

from ragas.evaluation import evaluate

# %%
def get_datasamples(questions, 
                    answers,
                    model,
                    mode="local",
                    top_k=10,
                   ):
    contexts = []
    ideal_answers = []

    for i,q in tqdm(enumerate(questions)):
        _context = model.retrieve(q)[0]
        # Convert the CSV string into a Pandas DataFrame
        # Regular expression to find all content between triple backticks
        context = [_context]
        
        i_answer = model.answer_question(question=q)
    
        #contexts.append(context)
        contexts.append(context)
        ideal_answers.append(i_answer)

    data_samples = {'question': questions, 
           'ground_truth': answers,
           "contexts": contexts,
          "answer": ideal_answers
          }
    return Dataset.from_dict(data_samples)

# %%
metrics = [
   answer_relevancy,
    answer_correctness, 
   faithfulness,
    context_precision,
    context_recall,
 #   context_entity_recall,
 #   context_relevancy,
 #   context_utilization,
]

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

# %%
dataset = get_datasamples(questions,answers, RA)
# Out:
# 0it [00:00, ?it/s]2024-12-10 18:14:32,361 - Using collapsed_tree
# 2024-12-10 18:14:32,669 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:32,681 - Using collapsed_tree
# 2024-12-10 18:14:33,095 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:33,708 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 1it [00:01,  1.35s/it]2024-12-10 18:14:33,717 - Using collapsed_tree
# 2024-12-10 18:14:34,119 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:34,130 - Using collapsed_tree
# 2024-12-10 18:14:34,426 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:34,937 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2it [00:02,  1.28s/it]2024-12-10 18:14:34,945 - Using collapsed_tree
# 2024-12-10 18:14:35,348 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:35,360 - Using collapsed_tree
# 2024-12-10 18:14:35,644 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:36,268 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 3it [00:03,  1.30s/it]2024-12-10 18:14:36,278 - Using collapsed_tree
# 2024-12-10 18:14:36,576 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:36,588 - Using collapsed_tree
# 2024-12-10 18:14:36,884 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:38,112 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 4it [00:05,  1.52s/it]2024-12-10 18:14:38,119 - Using collapsed_tree
# 2024-12-10 18:14:38,420 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:38,431 - Using collapsed_tree
# 2024-12-10 18:14:38,775 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:39,237 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 5it [00:06,  1.38s/it]2024-12-10 18:14:39,246 - Using collapsed_tree
# 2024-12-10 18:14:39,649 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:39,660 - Using collapsed_tree
# 2024-12-10 18:14:40,161 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:40,671 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 6it [00:08,  1.39s/it]2024-12-10 18:14:40,678 - Using collapsed_tree
# 2024-12-10 18:14:41,082 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14:41,093 - Using collapsed_tree
# 2024-12-10 18:14:41,389 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:14
- HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 22it [00:31,  1.35s/it]2024-12-10 18:15:03,716 - Using collapsed_tree
# 2024-12-10 18:15:04,020 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:04,031 - Using collapsed_tree
# 2024-12-10 18:15:04,327 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:04,695 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 23it [00:32,  1.24s/it]2024-12-10 18:15:04,704 - Using collapsed_tree
# 2024-12-10 18:15:05,146 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:05,151 - Using collapsed_tree
# 2024-12-10 18:15:05,412 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:05,964 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 24it [00:33,  1.25s/it]2024-12-10 18:15:05,969 - Using collapsed_tree
# 2024-12-10 18:15:06,375 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:06,386 - Using collapsed_tree
# 2024-12-10 18:15:06,887 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:07,396 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 25it [00:35,  1.30s/it]2024-12-10 18:15:07,399 - Using collapsed_tree
# 2024-12-10 18:15:07,706 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:07,712 - Using collapsed_tree
# 2024-12-10 18:15:08,014 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:08,524 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 26it [00:36,  1.25s/it]2024-12-10 18:15:08,533 - Using collapsed_tree
# 2024-12-10 18:15:08,833 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:08,839 - Using collapsed_tree
# 2024-12-10 18:15:09,181 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:09,650 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 27it [00:37,  1.21s/it]2024-12-10 18:15:09,659 - Using collapsed_tree
# 2024-12-10 18:15:09,957 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:09,969 - Using collapsed_tree
# 2024-12-10 18:15:10,369 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:10,805 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 28it [00:38,  1.20s/it]2024-12-10 18:15:10,815 - Using collapsed_tree
# 2024-12-10 18:15:11,085 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:11,097 - Using collapsed_tree
# 2024-12-10 18:15:11,495 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:12,006 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 29it [00:39,  1.20s/it]2024-12-10 18:15:12,014 - Using collapsed_tree
# 2024-12-10 18:15:12,518 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:12,523 - Using collapsed_tree
# 2024-12-10 18:15:12,929 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:13,439 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 30it [00:41,  1.27s/it]2024-12-10 18:15:13,445 - Using collapsed_tree
# 2024-12-10 18:15:13,850 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:13,860 - Using collapsed_tree
# 2024-12-10 18:15:14,260 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:14,682 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 31it [00:42,  1.26s/it]2024-12-10 18:15:14,690 - Using collapsed_tree
# 2024-12-10 18:15:15,079 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:15,088 - Using collapsed_tree
# 2024-12-10 18:15:15,343 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:15,789 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 32it [00:43,  1.22s/it]2024-12-10 18:15:15,800 - Using collapsed_tree
# 2024-12-10 18:15:16,103 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:16,111 - Using collapsed_tree
# 2024-12-10 18:15:16,410 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:16,921 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 33it [00:44,  1.19s/it]2024-12-10 18:15:16,929 - Using collapsed_tree
# 2024-12-10 18:15:17,332 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:17,340 - Using collapsed_tree
# 2024-12-10 18:15:17,646 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:21,836 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 34it [00:49,  2.31s/it]2024-12-10 18:15:21,847 - Using collapsed_tree
# 2024-12-10 18:15:22,146 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:22,157 - Using collapsed_tree
# 2024-12-10 18:15:22,453 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:15:22,963 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 35it [00:50,  1.45s/it]

# %%
result = evaluate(dataset, metrics,
                        llm=ChatOpenAI(model="gpt-4o-mini", temperature=0),  
                        raise_exceptions=False, embeddings=OpenAIEmbeddings())
# Out:
# Evaluating:   0%|          | 0/175 [00:00<?, ?it/s]
# 2024-12-10 18:15:24,706 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,713 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,728 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,819 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,873 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,904 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,913 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,925 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,941 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,967 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,985 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:24,987 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:25,039 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:25,422 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:25,428 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15:25,505 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:15
- HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:00,241 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:00,586 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:00,773 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:00,783 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:00,792 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:00,799 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:00,808 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:00,815 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:00,823 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:00,828 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:01,003 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:01,101 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:01,262 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:01,571 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:01,574 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:01,874 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:01,971 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:02,011 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:02,068 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:02,489 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:02,579 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:02,609 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:02,690 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:02,738 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:03,002 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:03,057 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:03,059 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:03,515 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:03,522 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:03,944 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:04,286 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:04,743 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,051 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,155 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,158 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,161 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,165 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,167 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,172 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,175 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,179 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,568 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:05,971 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,164 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,167 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,169 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,219 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,427 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,522 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,683 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,791 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,823 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,922 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,931 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:06,943 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:07,036 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:07,058 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:07,061 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:07,118 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:07,302 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:07,609 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:07,736 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:07,823 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:08,173 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:08,738 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:08,815 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:08,818 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:08,821 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:08,824 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:08,828 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:08,832 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:09,091 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:09,352 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:09,441 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:09,444 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:09,449 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:09,454 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:09,459 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:09,601 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:09,863 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:10,274 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:10,279 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:10,477 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:10,485 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:10,493 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:10,603 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:10,615 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:10,718 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:10,989 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:11,107 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:11,502 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:11,845 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,026 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,033 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,041 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,047 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,053 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,058 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,061 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,064 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,076 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,105 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,109 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,228 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,315 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,513 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,533 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,553 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:12,837 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:13,074 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:13,355 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:13,371 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:13,378 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:13,386 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:13,390 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:13,394 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:13,397 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:13,400 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,165 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,169 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,179 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,419 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,779 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,834 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,836 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,838 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,839 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,841 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:14,864 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:15,290 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:15,400 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:15,664 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:15,668 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:15,674 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:15,677 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,212 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,462 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,595 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,598 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,601 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,605 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,607 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,611 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,614 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,617 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,918 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,924 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:16,929 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:17,086 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:17,340 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:17,345 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:17,366 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:17,395 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:17,472 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:17,852 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,262 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,468 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,470 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,471 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,473 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,474 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,476 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,478 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,480 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,679 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:18,693 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:19,034 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:19,592 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:19,660 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:19,661 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:19,663 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:19,664 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:19,666 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:19,667 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:19,677 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:19,751 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:20,000 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:20,340 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:20,396 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:20,718 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:21,050 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:21,231 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:21,233 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:21,236 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:21,240 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:21,639 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:21,715 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:22,049 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:22,065 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:22,459 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:22,693 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:22,813 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:23,176 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:23,483 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:23,994 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:24,303 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:24,309 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:24,645 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:24,662 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:25,122 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:25,838 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:26,146 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:26,453 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:29,626 - HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2024-12-10 18:16:30,037 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2024-12-10 18:16:30,344 - HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"

# %% [markdown]
# ### Results

# %%
import ragas
def print_dict(d, indent=0):
    """
    Recursively prints a dictionary, including nested dictionaries, 
    with indentation to represent structure.
    """
    if isinstance(d, ragas.dataset_schema.EvaluationResult):
        _d = d._repr_dict.copy()
    else:
        _d = d.copy()
    for key, value in _d.items():
        print('  ' * indent + str(key) + ": ", end="")
        if isinstance(value, dict):
            print()  # Print a newline for nested dictionaries
            print_dict(value, indent + 1)
        else:
            print(str(value))

# %%
print_dict(result)
d_result = dict()
d_result['raptor'] = result
# Out:
# answer_relevancy: 0.04932377522932352
# answer_correctness: 0.19359120912877228
# faithfulness: 0.05714285714285714
# context_precision: 0.08571428570571428
# context_recall: 0.11428571428571428

# %%
naive = {'answer_relevancy': 0.6295814045264221,
'answer_correctness': 0.41957449852216616,
'faithfulness': 0.12835978835978834,
'context_precision': 0.0,
'context_recall': 0.08571428571428572
        }

# %%
d_result = {'raptor': result, 'naive': naive}

df = pd.DataFrame()

for k in d_result.keys():
    print(k)
    print_dict(d_result[k])
    #df[k] = d_result[k]
    print()
# Out:
# raptor
# answer_relevancy: 0.04932377522932352
# answer_correctness: 0.19359120912877228
# faithfulness: 0.05714285714285714
# context_precision: 0.08571428570571428
# context_recall: 0.11428571428571428
#
# naive
# answer_relevancy: 0.6295814045264221
# answer_correctness: 0.41957449852216616
# faithfulness: 0.12835978835978834
# context_precision: 0.0
# context_recall: 0.08571428571428572

# %%
from termcolor import colored

# Print colored text with termcolor

for i,r in dataset.to_pandas().iterrows():
    #print(i, "\n" ,10*"*** ")
    print(colored(r['question'], "red", attrs=["bold"]))
    print(r['answer'])
    print()
# Out:
# * Which materials are in the dataset?
# I don't know.
#
# * How many structures are there in the dataset?
# I don't know.
#
# * How to obtain the dataset?
# I don't know.
#
# * What is the dataset license?
# The dataset license is a Creative Commons Attribution 4.0 International License, which permits use, sharing, adaptation, distribution, and reproduction in any medium or format, as long as appropriate credit is given to the original author(s) and the source, a link to the Creative Commons license is provided, and any changes made are indicated.
#
# * What is the data format?
# I don't know.
#
# * How to read the dataset?
# I don't know.
#
# * How to browse the dataset?
# I don't know.
#
# * Can I work with the dataset without Python?
# I don't know.
#
# * How to obtain the raw VASP files?
# I don't know.
#
# * What were the settings used for the DFT computations?
# I don't know.
#
# * How well the DFT calculations correspond to experiment?
# I don't know.
#
# * How to cite the dataset?
# I don't know.
#
# * What was the procedure for SRGNN quality evaluation?
# I don't know.
#
# * How is SRGNN different from the baselines?
# I don't know.
#
# * What are the limitations of SRGNN?
# I don't know.
#
# * What is the core idea of SRGNN?
# I don't know.
#
# * How to run the code?
# I don't know.
#
# * Which frameworks were used for SRGNN implementation?
# I don't know.
#
# * Can SRGNN be developed on a CPU, not a GPU?
# I don't know.
#
# * What is the code license?
# The article is licensed under a Creative Commons Attribution 4.0 International License.
#
# * How to cite the code?
# I don't know.
#
# * Which materials has the SRGNN been trained on?
# I don't know.
#
# * Which materials can the SRGNN be trained on?
# I don't know.
#
# * Which defect types can the SRGNN be trained on?
# I don't know.
#
# * How many structures are needed for SRGNN training?
# I don't know.
#
# * Can SRGNN handle 3D materials?
# I don't know.
#
# * How much computational resources does SRGNN require for training?
# I don't know.
#
# * What is the inference speed of a SRGNN?
# I don't know.
#
# * Which properties can be predicted using SRGNN?
# I don't know.
#
# * What was the quality of SRGNN for each property and material?
# I don't know.
#
# * Can pre-trained SRGNN be used out-of-the-box?
# I don't know.
#
# * How well do SRGNN results correspond to experiment?
# I don't know.
#
# * Can I use SRGNN in place of DFT?
# I don't know.
#
# * How can I use SRGNN to find materials for solar panels/transistors/photodetectors/single photon emitters/quantum computers?
# I don't know.
#
# * Is SRGNN patented?
# I don't know.
