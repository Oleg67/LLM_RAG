# %%
import os, json
#from langchain.chains import AnalyzeDocumentChain
from langchain_openai import ChatOpenAI

from utils import OPENAI_API_KEY

os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

# %%
from contextual_rag import ContextualRAG

# %%
# Example usage
rag = ContextualRAG()
    
# Process PDF files
chunks, chunk_metadata = rag.upload_files("./data/data_rag/pdf")
# Out:
# Using device: cuda
# Loading embedding model: BAAI/bge-base-en-v1.5
# Loading PDF files from ./data/data_rag/pdf
# Loaded 30 documents
# Created 193 text chunks from 3 documents

# %%
   
# Extract keywords from each chunk
keywords = rag.get_keywords(chunks)
    
# Generate chunk embeddings and token IDs
chunk_embeddings, token_ids_list = rag.get_chunk_emb(chunks)
# Out:
# Extracting keywords: 100%|██████████████████| 193/193 [00:00<00:00, 3826.00it/s]
# Extracted 127 unique keywords across 193 chunks
# Generating chunk embeddings: 100%|████████████| 193/193 [00:09<00:00, 19.45it/s]
# Generated token embeddings for 193 chunks

# %%
keywords[100]
# Out:
# ['eos',
#  'crystals',
#  'density',
#  'low',
#  'datasets',
#  'prediction',
#  'sparse',
#  'properties',
#  'information',
#  'homo lumo',
#  'nature',
#  'space',
#  'combined',
#  'full',
#  'data']

# %%
# Generate keyword embeddings with context and document ID
keyword_context_doc_embeddings = rag.get_keyword_emb(
    keywords, chunk_embeddings, token_ids_list, chunks, chunk_metadata
    )
# Out:
# Generating keyword embeddings: 100%|██████████| 193/193 [00:02<00:00, 94.76it/s]
# Generated embeddings for 4633 keyword-context-document pairs
# Average 37.52 contexts per keyword

# %%
keyword_stats = rag.get_all_unique_keywords()
    

    
# Print a summary
print(f"Total unique keywords: {len(keyword_stats)}")
# Out:
# Total unique keywords: 124
#
# Top 10 keywords by document coverage:
# 'properties': 3 documents, 75 total occurrences
# 'con ﬁguration': 3 documents, 34 total occurrences
# 'ﬁguration': 3 documents, 34 total occurrences
# 'defects': 3 documents, 198 total occurrences
# 'con': 3 documents, 62 total occurrences
# 'machine': 3 documents, 61 total occurrences
# 'machine learning': 3 documents, 61 total occurrences
# 'materials': 3 documents, 173 total occurrences
# 'learning': 3 documents, 90 total occurrences
# 'space': 3 documents, 35 total occurrences
# Total unique keywords: 124

# %%
keyword_stats.keys()
# Out:
# dict_keys(['properties', 'con ﬁguration', 'ﬁguration', 'defects', 'con', 'machine', 'machine learning', 'materials', 'learning', 'space', 'sparse representation', 'lattice', 'crystals', 'electronic', 'sparse', 'defect', 'https', 'network', 'neural network', 'npj', 'prediction', 'methods', 'atomic', 'state', 'quantum', 'atom', 'property', 'point', 'crystal', 'point defects', 'density', 'calculations', 'material', 'networks', 'neural networks', 'graph neural', 'megnet', 'dft', 'used', 'graph', 'datasets', 'database', 'high', 'wse', 'use', 'neural', 'nature', 'performance', 'based', 'partnership', 'published', 'information', 'edge', 'features', 'atoms', 'representation', 'structure', 'wave function', 'function', 'electrons', 'wave', 'states', 'fig', 'energy', 'band', 'sites', 'lumo', 'con ﬁgurations', 'gap', 'homo', 'ﬁgurations', 'formation', 'structures', 'pristine', 'single', 'data', 'dataset', 'interaction', 'number', 'vacancies', 'using', 'eos', 'vacancy', 'nodes', 'site', 'full', 'mos', 'low', 'available', 'formation energy', 'model', 'supplementary', 'combined', 'computational', 'mater', 'phys', 'rev', 'centre', 'research', 'project', 'hse', 'university', 'excellence', 'singapore', 'award', 'institute', 'acknowledgements', 'ministry', 'functional', 'intelligent', 'education', 'supported', 'license', 'publisher', 'note', 'creativecommons', 'commons', 'permitted', 'article', 'credit', 'springer', 'remains', 'included', 'creative'])

# %%
    
# Create vector database
rag.make_db(keyword_context_doc_embeddings, chunks, chunk_metadata)
# Out:
# Created keyword vector database with 4633 entries
# Generating full chunk embeddings: 100%|███████| 193/193 [00:09<00:00, 20.39it/s]
# Generated embeddings for 193 chunks
# Created chunk vector database with 193 entries

# %%
    
# Save the system
rag.save(".data/context_rag_system")
# Out:
# Saved RAG system to .data/context_rag_system

# %%
query = "What is machine learning?"
results = rag.process_query(
        query, 
        top_k=3, 
        keyword_weight=0.7,  # Emphasize keyword matches
        chunk_weight=0.3     # But also consider whole-chunk similarity
    )
    
print("\nHybrid Query Results:")
for i, result in enumerate(results):
    print(f"\nResult {i+1} (Score: {result['score']:.4f}):")
    print(f"Document ID: {result['doc_id']}")
    print(f"Page: {result['page_num']}")
    print(f"Keywords: {', '.join(result['keywords'])}")
    print(f"Relevant terms: {', '.join(result['relevant_terms'])}")
    print(f"Text: {result['chunk_text'][:200]}...")
# Out:
# Query terms: ['machine', 'machine learning', 'learning']
#
# Hybrid Query Results:
#
# Result 1 (Score: 0.3020):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defect, learning, formation energy, machine, materials, partnership, datasets, vacancies, interaction, defects, fig, space, machine learning, edge
# Relevant terms: machine, machine learning, learning
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.2905):
# Document ID: s41699-023-00369-1.pdf
# Page: 0
# Keywords: available, pristine, defect, learning, data, machine, materials, database, dft, material, datasets, properties, machine learning, wse, model
# Relevant terms: machine, machine learning, learning
# Text: materials are notoriously dif ﬁcult to model. Thus, it is very tempting to apply machine learning methods to such systems.
# Unfortunately, there is only a handful of machine learning-friendly material ...
#
# Result 3 (Score: 0.2902):
# Document ID: s41699-023-00369-1.pdf
# Page: 0
# Keywords: structure, learning, high, materials, machine, based, datasets, properties, methods, defects, machine learning, property, model
# Relevant terms: machine, machine learning, learning
# Text: ARTICLE OPEN
# Unveiling the complex structure-property correlation of defects
# in 2D materials based on high throughput datasets
# Pengru Huang1, Ruslan Lukin2, Maxim Faleev2, Nikita Kazeev1,3, Abdalaziz ...

# %%
def query_searching(query):
    # Example query - search across all documents
    
    results = rag.process_query(
        query, 
        top_k=3, 
        keyword_weight=0.7,  # Emphasize keyword matches
        chunk_weight=0.3     # But also consider whole-chunk similarity
    )
    
    print(f"\nHybrid Query Results: \n ***  {query}")
    for i, result in enumerate(results):
        print(f"\nResult {i+1} (Score: {result['score']:.4f}):")
        print(f"Document ID: {result['doc_id']}")
        print(f"Page: {result['page_num']}")
        print(f"Keywords: {', '.join(result['keywords'])}")
        print(f"Relevant terms: {', '.join(result['relevant_terms'])}")
        print(f"Text: {result['chunk_text'][:200]}...")

# %%
import pandas as pd

df_ground_true = pd.read_csv("./data/data_rag/QA_ai4mat_2articles.csv")

questions = df_ground_true['question'].values.tolist()
answers = df_ground_true['answer'].values.tolist()

# %%
for q in questions:
    #print("****",q)
    query_searching(q)
    #print(8*".-.", "\n")
# Out:
# Query terms: ['materials', 'dataset']
#
# Hybrid Query Results:
#  ***  * Which materials are in the dataset?
#
# Result 1 (Score: 0.2959):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: atom, phys, learning, ﬁguration, machine, materials, rev, mater, density, features, con ﬁguration, information, machine learning, structure
# Relevant terms: materials
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 2 (Score: 0.2959):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 8
# Keywords: atom, phys, learning, ﬁguration, machine, materials, rev, mater, density, features, con ﬁguration, information, machine learning, structure
# Relevant terms: materials
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 3 (Score: 0.2956):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defect, learning, formation energy, machine, materials, partnership, datasets, vacancies, interaction, defects, fig, space, machine learning, edge
# Relevant terms: materials, dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
# Query terms: ['many structures', 'structures', 'dataset', 'many']
#
# Hybrid Query Results:
#  ***  * How many structures are there in the dataset?
#
# Result 1 (Score: 0.3120):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defect, learning, formation energy, machine, materials, partnership, datasets, vacancies, interaction, defects, fig, space, machine learning, edge
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.2932):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: atom, phys, learning, ﬁguration, machine, materials, rev, mater, density, features, con ﬁguration, information, machine learning, structure
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 3 (Score: 0.2932):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 8
# Keywords: atom, phys, learning, ﬁguration, machine, materials, rev, mater, density, features, con ﬁguration, information, machine learning, structure
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['obtain', 'dataset']
#
# Hybrid Query Results:
#  ***  * How to obtain the dataset?
#
# Result 1 (Score: 0.2891):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defect, learning, formation energy, machine, materials, partnership, datasets, vacancies, interaction, defects, fig, space, machine learning, edge
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.2889):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: formation, available, atomic, formation energy, defect, band, mos, energy, vacancies, properties, interaction, structures, defects, wse, edge
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.2888):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: atom, phys, learning, ﬁguration, machine, materials, rev, mater, density, features, con ﬁguration, information, machine learning, structure
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['dataset license', 'dataset', 'license']
#
# Hybrid Query Results:
#  ***  * What is the dataset license?
#
# Result 1 (Score: 0.2920):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defect, learning, formation energy, machine, materials, partnership, datasets, vacancies, interaction, defects, fig, space, machine learning, edge
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.2873):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: formation, available, atomic, formation energy, defect, band, mos, energy, vacancies, properties, interaction, structures, defects, wse, edge
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.2871):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: sparse representation, defect, performance, megnet, high, combined, density, use, sparse, low, using, representation, structures, dataset, number
# Relevant terms: dataset
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
# Query terms: ['format', 'data format', 'data']
#
# Hybrid Query Results:
#  ***  * What is the data format?
#
# Result 1 (Score: 0.2889):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: formation, available, atomic, formation energy, defect, band, mos, energy, vacancies, properties, interaction, structures, defects, wse, edge
# Relevant terms: data, format
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 2 (Score: 0.2886):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: atom, phys, learning, ﬁguration, machine, materials, rev, mater, density, features, con ﬁguration, information, machine learning, structure
# Relevant terms: format
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 3 (Score: 0.2886):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 8
# Keywords: atom, phys, learning, ﬁguration, machine, materials, rev, mater, density, features, con ﬁguration, information, machine learning, structure
# Relevant terms: format
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['read', 'dataset']
#
# Hybrid Query Results:
#  ***  * How to read the dataset?
#
# Result 1 (Score: 0.3071):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defect, learning, formation energy, machine, materials, partnership, datasets, vacancies, interaction, defects, fig, space, machine learning, edge
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.2893):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: formation, available, atomic, formation energy, defect, band, mos, energy, vacancies, properties, interaction, structures, defects, wse, edge
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.2892):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: sparse representation, defect, performance, megnet, high, combined, density, use, sparse, low, using, representation, structures, dataset, number
# Relevant terms: dataset
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
# Query terms: ['browse', 'dataset']
#
# Hybrid Query Results:
#  ***  * How to browse the dataset?
#
# Result 1 (Score: 0.3051):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defect, learning, formation energy, machine, materials, partnership, datasets, vacancies, interaction, defects, fig, space, machine learning, edge
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.2889):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: formation, available, atomic, formation energy, defect, band, mos, energy, vacancies, properties, interaction, structures, defects, wse, edge
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.2887):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: atom, phys, learning, ﬁguration, machine, materials, rev, mater, density, features, con ﬁguration, information, machine learning, structure
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['work', 'without python', 'dataset without', 'dataset', 'python']
#
# Hybrid Query Results:
#  ***  * Can I work with the dataset without Python?
#
# Result 1 (Score: 0.3032):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defect, learning, formation energy, machine, materials, partnership, datasets, vacancies, interaction, defects, fig, space, machine learning, edge
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.2932):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, networks, data, nodes, learning, based, neural networks, combined, state, dataset, graph, model
# Relevant terms: work, dataset
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 3 (Score: 0.2932):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 7
# Keywords: neural, networks, data, nodes, learning, based, neural networks, combined, state, dataset, graph, model
# Relevant terms: work, dataset
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
# Query terms: ['raw vasp', 'raw', 'obtain', 'vasp', 'vasp files', 'files']
#
# Hybrid Query Results:
#  ***  * How to obtain the raw VASP files?
#
# Result 1 (Score: 0.2897):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, networks, data, nodes, learning, based, neural networks, combined, state, dataset, graph, model
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 (Score: 0.2897):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 7
# Keywords: neural, networks, data, nodes, learning, based, neural networks, combined, state, dataset, graph, model
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 3 (Score: 0.2893):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: information, available, data, megnet, dft, material, nature, density, low, using, structures, computational, defects, https, supplementary
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
# Query terms: ['dft', 'dft computations', 'settings used', 'used', 'settings', 'computations']
#
# Hybrid Query Results:
#  ***  * What were the settings used for the DFT computations?
#
# Result 1 (Score: 0.2936):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: sparse representation, formation, formation energy, ﬁguration, performance, megnet, sparse, representation, use, energy, supplementary, con ﬁguration, con, full, model
# Relevant terms:
# Text: sparse representation succeeds perfectly, including the non-
# monotonous reduction at 5 Å.
# As shown in the Supplementary Discussion 3, the result is
# similar for untuned hyperparameters.
# Ablation study
# ...
#
# Result 2 (Score: 0.2936):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 4
# Keywords: sparse representation, formation, formation energy, ﬁguration, performance, megnet, sparse, representation, use, energy, supplementary, con ﬁguration, con, full, model
# Relevant terms:
# Text: sparse representation succeeds perfectly, including the non-
# monotonous reduction at 5 Å.
# As shown in the Supplementary Discussion 3, the result is
# similar for untuned hyperparameters.
# Ablation study
# ...
#
# Result 3 (Score: 0.2936):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: sparse representation, data, performance, vacancy, ﬁgurations, sparse, quantum, representation, use, low, supplementary, con ﬁgurations, used, dataset, model
# Relevant terms: used
# Text: a GPU, and costs 7.5 CPU core-minutes per structure and 1860
# core-hours for the whole 2DMD dataset. Model con ﬁgurations are
# listed in Supplementary Discussion 1.
# Quantum oscillations prediction
# In ad...
# Query terms: ['correspond', 'calculations', 'dft', 'experiment', 'dft calculations', 'calculations correspond']
#
# Hybrid Query Results:
#  ***  * How well the DFT calculations correspond to experiment?
#
# Result 1 (Score: 0.2960):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: formation, pristine, formation energy, defect, sites, lumo, dft, gap, electronic, use, energy, defects, structure, number
# Relevant terms: dft
# Text: We use two target variables for evaluating machine learning
# methods: defect formation energy per site and HOMO –LUMO gap.
# Formation energy, i.e., the energy required to create a defect is
# deﬁned as
# E
# ...
#
# Result 2 (Score: 0.2960):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 3
# Keywords: formation, pristine, formation energy, defect, sites, lumo, dft, gap, electronic, use, energy, defects, structure, number
# Relevant terms: dft
# Text: We use two target variables for evaluating machine learning
# methods: defect formation energy per site and HOMO –LUMO gap.
# Formation energy, i.e., the energy required to create a defect is
# deﬁned as
# E
# ...
#
# Result 3 (Score: 0.2959):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: con, materials, npj, partnership, electronic, ﬁgurations, quantum, lattice, published, con ﬁgurations, space, dataset, structure, site
# Relevant terms:
# Text: the lattice site and distance are observed and explained in depththrough symmetry and quantum mechanics electronic structure
# analysis. The dispersive dataset was created to span over as large
# as possi...
# Query terms: ['dataset', 'cite']
#
# Hybrid Query Results:
#  ***  * How to cite the dataset?
#
# Result 1 (Score: 0.3076):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defect, learning, formation energy, machine, materials, partnership, datasets, vacancies, interaction, defects, fig, space, machine learning, edge
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.2896):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: atom, phys, learning, ﬁguration, machine, materials, rev, mater, density, features, con ﬁguration, information, machine learning, structure
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 3 (Score: 0.2896):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 8
# Keywords: atom, phys, learning, ﬁguration, machine, materials, rev, mater, density, features, con ﬁguration, information, machine learning, structure
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['quality evaluation', 'quality', 'srgnn quality', 'procedure', 'srgnn', 'evaluation']
#
# Hybrid Query Results:
#  ***  * What was the procedure for SRGNN quality evaluation?
#
# Result 1 (Score: 0.2900):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: sparse representation, graph, nodes, based, material, sparse, representation, state, information, used, edge, model
# Relevant terms:
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
#
# Result 2 (Score: 0.2900):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 7
# Keywords: sparse representation, graph, nodes, based, material, sparse, representation, state, information, used, edge, model
# Relevant terms:
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
#
# Result 3 (Score: 0.2894):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: function, wave function, sites, defect, ﬁguration, states, band, energy, vacancies, lattice, fig, con ﬁguration, con, interaction, wave
# Relevant terms:
# Text: vacancies is smaller than that of the third con ﬁguration, the two
# vacancies occupy lattice sites where there is a knot of their wavefunctions. The wave functions of the HOMO retain that of the
# isolat...
# Query terms: ['srgnn', 'baselines', 'srgnn different', 'different']
#
# Hybrid Query Results:
#  ***  * How is SRGNN different from the baselines?
#
# Result 1 (Score: 0.2941):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, networks, data, nodes, learning, based, neural networks, combined, state, dataset, graph, model
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 (Score: 0.2941):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 7
# Keywords: neural, networks, data, nodes, learning, based, neural networks, combined, state, dataset, graph, model
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 3 (Score: 0.2941):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: information, available, data, megnet, dft, material, nature, density, low, using, structures, computational, defects, https, supplementary
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
# Query terms: ['limitations', 'srgnn']
#
# Hybrid Query Results:
#  ***  * What are the limitations of SRGNN?
#
# Result 1 (Score: 0.2926):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: sparse representation, model, megnet, ﬁgurations, sparse, representation, features, combined, low, supplementary, quantum, con ﬁgurations, full, wse, prediction
# Relevant terms:
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
# Result 2 (Score: 0.2926):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 4
# Keywords: sparse representation, model, megnet, ﬁgurations, sparse, representation, features, combined, low, supplementary, quantum, con ﬁgurations, full, wse, prediction
# Relevant terms:
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
# Result 3 (Score: 0.2925):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: sparse representation, graph, nodes, based, material, sparse, representation, state, information, used, edge, model
# Relevant terms:
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
# Query terms: ['core idea', 'core', 'idea', 'srgnn']
#
# Hybrid Query Results:
#  ***  * What is the core idea of SRGNN?
#
# Result 1 (Score: 0.3164):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: function, wave function, sites, defect, formation energy, crystals, electrons, lattice, vacancies, interaction, fig, wave, structure, site, number
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
#
# Result 2 (Score: 0.2923):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: graph neural, available, networks, calculations, states, neural network, network, neural networks, electronic, electrons, low, supplementary, single, graph, neural
# Relevant terms:
# Text: structures with unpaired electrons, we utilize standard collinearspin-polarized calculations with magnetic ions in a high-spin
# ferromagnetic initialization (the ion moments can of course relax to
# a lo...
#
# Result 3 (Score: 0.2923):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 6
# Keywords: graph neural, available, networks, calculations, states, neural network, network, neural networks, electronic, electrons, low, supplementary, single, graph, neural
# Relevant terms:
# Text: structures with unpaired electrons, we utilize standard collinearspin-polarized calculations with magnetic ions in a high-spin
# ferromagnetic initialization (the ion moments can of course relax to
# a lo...
# Query terms: ['run', 'code']
#
# Hybrid Query Results:
#  ***  * How to run the code?
#
# Result 1 (Score: 0.2893):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: information, available, data, megnet, dft, material, nature, density, low, using, structures, computational, defects, https, supplementary
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 2 (Score: 0.2893):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 9
# Keywords: information, available, data, megnet, dft, material, nature, density, low, using, structures, computational, defects, https, supplementary
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 3 (Score: 0.2890):
# Document ID: s41699-023-00369-1.pdf
# Page: 4
# Keywords: sites, defect, lumo, atomic, vacancy, npj, partnership, homo, published, supplementary, fig, structures, site, number
# Relevant terms: code
# Text: difference. The total spin of the carbon-impurity complexes in hBN
# is governed by the difference between the carbon substitutions atthe two sublattices according to Lieb ’s theorem
# 26,27.
# S¼NCNðÞ/C0NC...
# Query terms: ['srgnn', 'frameworks', 'used', 'srgnn implementation', 'implementation']
#
# Hybrid Query Results:
#  ***  * Which frameworks were used for SRGNN implementation?
#
# Result 1 (Score: 0.2906):
# Document ID: s41699-023-00369-1.pdf
# Page: 7
# Keywords: point, calculations, defect, atoms, database, materials, electronic, electrons, low, interaction, structures, using, space, used, supplementary
# Relevant terms: used
# Text: calculations. The initial crystal structures were obtained from
# the Material Project database and the supercell sizes and thecomputational parameters for each materials are listed in the
# supplemental ...
#
# Result 2 (Score: 0.2904):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: graph neural, available, networks, calculations, states, neural network, network, neural networks, electronic, electrons, low, supplementary, single, graph, neural
# Relevant terms:
# Text: structures with unpaired electrons, we utilize standard collinearspin-polarized calculations with magnetic ions in a high-spin
# ferromagnetic initialization (the ion moments can of course relax to
# a lo...
#
# Result 3 (Score: 0.2904):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 6
# Keywords: graph neural, available, networks, calculations, states, neural network, network, neural networks, electronic, electrons, low, supplementary, single, graph, neural
# Relevant terms:
# Text: structures with unpaired electrons, we utilize standard collinearspin-polarized calculations with magnetic ions in a high-spin
# ferromagnetic initialization (the ion moments can of course relax to
# a lo...
# Query terms: ['cpu', 'developed', 'srgnn', 'gpu']
#
# Hybrid Query Results:
#  ***  * Can SRGNN be developed on a CPU, not a GPU?
#
# Result 1 (Score: 0.2915):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: sparse representation, megnet, high, sparse, representation, eos, using, structures, computational, used
# Relevant terms:
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
#
# Result 2 (Score: 0.2915):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 9
# Keywords: sparse representation, megnet, high, sparse, representation, eos, using, structures, computational, used
# Relevant terms:
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
#
# Result 3 (Score: 0.2899):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: centre, research, project, supported, hse, materials, university, excellence, singapore, award, institute, acknowledgements, ministry, computational, functional, education, intelligent, number
# Relevant terms:
# Text: ACKNOWLEDGEMENTS
# This research/project is supported by the Ministry of Education, Singapore, under its
# Research Centre of Excellence award to the Institute for Functional Intelligent Materials
# (I-FIM,...
# Query terms: ['code license', 'license', 'code']
#
# Hybrid Query Results:
#  ***  * What is the code license?
#
# Result 1 (Score: 0.2889):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: sparse representation, defect, performance, megnet, high, combined, density, use, sparse, low, using, representation, structures, dataset, number
# Relevant terms:
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
# Result 2 (Score: 0.2889):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 3
# Keywords: sparse representation, defect, performance, megnet, high, combined, density, use, sparse, low, using, representation, structures, dataset, number
# Relevant terms:
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
# Result 3 (Score: 0.2875):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defect, learning, formation energy, machine, materials, partnership, datasets, vacancies, interaction, defects, fig, space, machine learning, edge
# Relevant terms:
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
# Query terms: ['cite', 'code']
#
# Hybrid Query Results:
#  ***  * How to cite the code?
#
# Result 1 (Score: 0.3764):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: function, wave function, sites, atomic, atoms, nodes, pristine, vacancy, states, electrons, energy, lattice, fig, interaction, wave
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.2920):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: graph neural, phys, networks, rev, neural network, network, neural networks, mater, npj, datasets, https, property, graph, neural
# Relevant terms:
# Text: graphs. Published at the International Conference on Learning Representations(ICLR) 2020. Preprint at https://arXiv.org/abs/2003.03123 (2020).
# 18. Shuaibi, M. et al. Rotation invariant graph neural ne...
#
# Result 3 (Score: 0.2920):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 8
# Keywords: graph neural, phys, networks, rev, neural network, network, neural networks, mater, npj, datasets, https, property, graph, neural
# Relevant terms:
# Text: graphs. Published at the International Conference on Learning Representations(ICLR) 2020. Preprint at https://arXiv.org/abs/2003.03123 (2020).
# 18. Shuaibi, M. et al. Rotation invariant graph neural ne...
# Query terms: ['materials', 'srgnn', 'trained']
#
# Hybrid Query Results:
#  ***  * Which materials has the SRGNN been trained on?
#
# Result 1 (Score: 0.2936):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: sparse representation, defect, performance, megnet, lumo, partnership, combined, representation, features, vacancies, low, full, wse
# Relevant terms: materials
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 2 (Score: 0.2936):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 3
# Keywords: sparse representation, defect, performance, megnet, lumo, partnership, combined, representation, features, vacancies, low, full, wse
# Relevant terms: materials
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 3 (Score: 0.2934):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: function, graph, formation energy, ﬁguration, nodes, dft, neural network, network, npj, atoms, partnership, con ﬁguration, property, edge
# Relevant terms: materials, trained
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
# Query terms: ['materials', 'srgnn', 'trained']
#
# Hybrid Query Results:
#  ***  * Which materials can the SRGNN be trained on?
#
# Result 1 (Score: 0.2924):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, atoms, nodes, states, neural network, network, crystal, state, edge, structure, graph, number
# Relevant terms:
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
# Result 2 (Score: 0.2924):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 7
# Keywords: neural, atoms, nodes, states, neural network, network, crystal, state, edge, structure, graph, number
# Relevant terms:
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
# Result 3 (Score: 0.2924):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: phys, calculations, learning, defect, rev, materials, mater, features, energy, using, interaction, wave, neural
# Relevant terms: materials
# Text: (2018).
# 33. Banik, S. et al. Learning with delayed rewards –A case study on inverse defect
# design in 2d materials. ACS Appl. Mater. Interfaces 13, 36455 –36464 (2021).
# 34. Shytov, A. V., Abanin, D. A....
# Query terms: ['defect types', 'defect', 'trained', 'srgnn', 'types']
#
# Hybrid Query Results:
#  ***  * Which defect types can the SRGNN be trained on?
#
# Result 1 (Score: 0.2907):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: sparse representation, megnet, high, sparse, representation, eos, using, structures, computational, used
# Relevant terms: defect
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
#
# Result 2 (Score: 0.2907):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 9
# Keywords: sparse representation, megnet, high, sparse, representation, eos, using, structures, computational, used
# Relevant terms: defect
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
#
# Result 3 (Score: 0.2905):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, atoms, nodes, states, neural network, network, crystal, state, edge, structure, graph, number
# Relevant terms:
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
# Query terms: ['training', 'many structures', 'srgnn training', 'many', 'srgnn', 'structures', 'needed']
#
# Hybrid Query Results:
#  ***  * How many structures are needed for SRGNN training?
#
# Result 1 (Score: 0.3033):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: available, npj, materials, partnership, published, fig, structures, computational, defects, space, supplementary
# Relevant terms: structures
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 (Score: 0.3033):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 4
# Keywords: available, npj, materials, partnership, published, fig, structures, computational, defects, space, supplementary
# Relevant terms: structures
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 3 (Score: 0.2934):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: function, graph, formation energy, ﬁguration, nodes, dft, neural network, network, npj, atoms, partnership, con ﬁguration, property, edge
# Relevant terms: training
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
# Query terms: ['handle', 'srgnn', 'srgnn handle', 'materials']
#
# Hybrid Query Results:
#  ***  * Can SRGNN handle 3D materials?
#
# Result 1 (Score: 0.2952):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: sparse representation, defect, performance, megnet, lumo, partnership, combined, representation, features, vacancies, low, full, wse
# Relevant terms: materials
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 2 (Score: 0.2952):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 3
# Keywords: sparse representation, defect, performance, megnet, lumo, partnership, combined, representation, features, vacancies, low, full, wse
# Relevant terms: materials
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 3 (Score: 0.2947):
# Document ID: s41524-023-01062-z.pdf
# Page: 5
# Keywords: sparse representation, learning, machine, neural network, network, crystals, sparse, representation, combined, vacancies, properties, using, defects, full, machine learning
# Relevant terms:
# Text: possible con ﬁgurations is vast. Thus, the ability to predict the
# properties of such crystals ef ﬁciently becomes a vital task. In this
# paper, we focus on predicting the properties of such crystals
# bl...
# Query terms: ['training', 'resources', 'computational resources', 'srgnn', 'much', 'computational', 'require', 'much computational', 'srgnn require']
#
# Hybrid Query Results:
#  ***  * How much computational resources does SRGNN require for training?
#
# Result 1 (Score: 0.2933):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: sparse representation, model, megnet, ﬁgurations, sparse, representation, features, combined, low, supplementary, quantum, con ﬁgurations, full, wse, prediction
# Relevant terms:
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
# Result 2 (Score: 0.2933):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 4
# Keywords: sparse representation, model, megnet, ﬁgurations, sparse, representation, features, combined, low, supplementary, quantum, con ﬁgurations, full, wse, prediction
# Relevant terms:
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
# Result 3 (Score: 0.2928):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, networks, data, nodes, learning, based, neural networks, combined, state, dataset, graph, model
# Relevant terms: training
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
# Query terms: ['speed', 'inference speed', 'srgnn', 'inference']
#
# Hybrid Query Results:
#  ***  * What is the inference speed of a SRGNN?
#
# Result 1 (Score: 0.2935):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, networks, data, nodes, learning, based, neural networks, combined, state, dataset, graph, model
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 (Score: 0.2935):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 7
# Keywords: neural, networks, data, nodes, learning, based, neural networks, combined, state, dataset, graph, model
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 3 (Score: 0.2934):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: information, available, data, megnet, dft, material, nature, density, low, using, structures, computational, defects, https, supplementary
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
# Query terms: ['using srgnn', 'predicted', 'srgnn', 'using', 'properties', 'predicted using']
#
# Hybrid Query Results:
#  ***  * Which properties can be predicted using SRGNN?
#
# Result 1 (Score: 0.2953):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: graph neural, atomic, networks, materials, neural networks, based, nature, partnership, published, properties, graph, neural
# Relevant terms: properties
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.2953):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 0
# Keywords: graph neural, atomic, networks, materials, neural networks, based, nature, partnership, published, properties, graph, neural
# Relevant terms: properties
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 3 (Score: 0.2950):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: sparse representation, atom, pristine, defect, available, sparse, low, fig, structures, defects, supplementary, space, full, dataset, model
# Relevant terms:
# Text: For formation energy, just enabling the zcoordinate difference
# in sparse representation edges allows the Sparse-Z model to
# outperform the Full model everywhere except h-BN; adding
# pristine atom specie...
# Query terms: ['srgnn', 'quality', 'property', 'material']
#
# Hybrid Query Results:
#  ***  * What was the quality of SRGNN for each property and material?
#
# Result 1 (Score: 0.2997):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: available, npj, materials, partnership, published, fig, structures, computational, defects, space, supplementary
# Relevant terms: material
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 (Score: 0.2997):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 4
# Keywords: available, npj, materials, partnership, published, fig, structures, computational, defects, space, supplementary
# Relevant terms: material
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 3 (Score: 0.2930):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: function, wave function, sites, defect, ﬁguration, states, band, energy, vacancies, lattice, fig, con ﬁguration, con, interaction, wave
# Relevant terms:
# Text: vacancies is smaller than that of the third con ﬁguration, the two
# vacancies occupy lattice sites where there is a knot of their wavefunctions. The wave functions of the HOMO retain that of the
# isolat...
# Query terms: ['pre trained', 'pre', 'trained', 'srgnn', 'box', 'trained srgnn', 'used']
#
# Hybrid Query Results:
#  ***  * Can pre-trained SRGNN be used out-of-the-box?
#
# Result 1 (Score: 0.3072):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: graph neural, atomic, networks, materials, neural networks, based, nature, partnership, published, properties, graph, neural
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.3072):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 0
# Keywords: graph neural, atomic, networks, materials, neural networks, based, nature, partnership, published, properties, graph, neural
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 3 (Score: 0.2935):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, networks, data, nodes, learning, based, neural networks, combined, state, dataset, graph, model
# Relevant terms: pre, trained
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
# Query terms: ['correspond', 'results correspond', 'results', 'experiment', 'srgnn', 'srgnn results']
#
# Hybrid Query Results:
#  ***  * How well do SRGNN results correspond to experiment?
#
# Result 1 (Score: 0.3024):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: graph neural, atomic, networks, materials, neural networks, based, nature, partnership, published, properties, graph, neural
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.3024):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 0
# Keywords: graph neural, atomic, networks, materials, neural networks, based, nature, partnership, published, properties, graph, neural
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 3 (Score: 0.2938):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: phys, calculations, learning, defect, rev, materials, mater, features, energy, using, interaction, wave, neural
# Relevant terms:
# Text: (2018).
# 33. Banik, S. et al. Learning with delayed rewards –A case study on inverse defect
# design in 2d materials. ACS Appl. Mater. Interfaces 13, 36455 –36464 (2021).
# 34. Shytov, A. V., Abanin, D. A....
# Query terms: ['use srgnn', 'place', 'dft', 'use', 'srgnn']
#
# Hybrid Query Results:
#  ***  * Can I use SRGNN in place of DFT?
#
# Result 1 (Score: 0.3024):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: atomic, calculations, atoms, defect, high, electronic, electrons, energy, interaction, structures, space, used, structure
# Relevant terms: use
# Text: only Monkhorst-Pack grid for structural relaxation and denser grids
# for further electronic structure calculations. A vacuum space of atleast 15 Åwas used to avoid interaction between neighboring
# layer...
#
# Result 2 (Score: 0.2934):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: information, available, data, megnet, dft, material, nature, density, low, using, structures, computational, defects, https, supplementary
# Relevant terms: dft
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 3 (Score: 0.2934):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 9
# Keywords: information, available, data, megnet, dft, material, nature, density, low, using, structures, computational, defects, https, supplementary
# Relevant terms: dft
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
# Query terms: ['single photon', 'transistors', 'use', 'photodetectors', 'use srgnn', 'panels', 'find', 'solar panels', 'quantum computers', 'panels transistors', 'computers', 'emitters quantum', 'emitters', 'quantum', 'solar', 'transistors photodetectors', 'photon emitters', 'materials', 'photon', 'srgnn', 'find materials', 'single', 'photodetectors single']
#
# Hybrid Query Results:
#  ***  * How can I use SRGNN to find materials for solar panels/transistors/photodetectors/single photon emitters/quantum computers?
#
# Result 1 (Score: 0.2956):
# Document ID: s41524-023-01062-z.pdf
# Page: 1
# Keywords: point, pristine, point defects, megnet, data, materials, dft, based, use, properties, defects, structures, single, used
# Relevant terms: use, materials, single
# Text: different materials, but the authors didn ’t consider con ﬁgurations
# with multiple interacting defects. In a recent preprint27, the
# authors use a model based on CGCNN12to conduct a large scale
# screeni...
#
# Result 2 (Score: 0.2956):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 1
# Keywords: point, pristine, point defects, megnet, data, materials, dft, based, use, properties, defects, structures, single, used
# Relevant terms: use, materials, single
# Text: different materials, but the authors didn ’t consider con ﬁgurations
# with multiple interacting defects. In a recent preprint27, the
# authors use a model based on CGCNN12to conduct a large scale
# screeni...
#
# Result 3 (Score: 0.2955):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: atomic, defect, data, learning, dft, materials, mos, ﬁgurations, datasets, properties, con ﬁgurations, space, dataset, wse, con
# Relevant terms: materials
# Text: small subspace of the whole defect space. The other group of
# dispersive datasets aims to spread data in the large defect space.This is done here by calculating the properties of a wide
# concentration r...
# Query terms: ['srgnn', 'srgnn patented', 'patented']
#
# Hybrid Query Results:
#  ***  * Is SRGNN patented?
#
# Result 1 (Score: 0.2908):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: sparse representation, atom, pristine, defect, available, sparse, low, fig, structures, defects, supplementary, space, full, dataset, model
# Relevant terms:
# Text: For formation energy, just enabling the zcoordinate difference
# in sparse representation edges allows the Sparse-Z model to
# outperform the Full model everywhere except h-BN; adding
# pristine atom specie...
#
# Result 2 (Score: 0.2908):
# Document ID: Sparse representation for machine learning the properties of defects in 2D materials.pdf
# Page: 4
# Keywords: sparse representation, atom, pristine, defect, available, sparse, low, fig, structures, defects, supplementary, space, full, dataset, model
# Relevant terms:
# Text: For formation energy, just enabling the zcoordinate difference
# in sparse representation edges allows the Sparse-Z model to
# outperform the Full model everywhere except h-BN; adding
# pristine atom specie...
#
# Result 3 (Score: 0.2908):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: sparse representation, defect, performance, megnet, lumo, partnership, combined, representation, features, vacancies, low, full, wse
# Relevant terms:
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
