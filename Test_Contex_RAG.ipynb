# %%
import os, json
#from langchain.chains import AnalyzeDocumentChain
from langchain_openai import ChatOpenAI

from utils import OPENAI_API_KEY

os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

# %%
from contextual_rag import ContextualRAG

# %%
# Example usage
rag = ContextualRAG()
    
# Process PDF files
chunks, chunk_metadata = rag.upload_files("./data")
# Out:
# Using device: cuda
# Loading embedding model: BAAI/bge-base-en-v1.5
# Loading PDF files from ./data
# Loaded 20 documents
# Created 127 text chunks from 2 documents

# %%
   
# Make Vector DB
rag.make_db(chunks, chunk_metadata)
    
# Generate chunk embeddings and token IDs
#chunk_embeddings, token_ids_list = rag.get_chunk_emb(chunks)
# Out:
# Creating vector databases...
# Extracting keywords from chunks...
# Extracting keywords: 100%|██████████████████| 127/127 [00:00<00:00, 6396.83it/s]
# Extracted 100 unique keywords across 127 chunks
# Generating token-level embeddings...
# Generating chunk embeddings: 100%|████████████| 127/127 [00:06<00:00, 19.16it/s]
# Generated token embeddings for 127 chunks
# Generating full chunk embeddings...
# Generating full chunk embeddings: 100%|███████| 127/127 [00:06<00:00, 20.37it/s]
# Generated embeddings for 127 chunks
# Generating keyword embeddings...
# Generating keyword embeddings: 100%|██████████| 127/127 [00:01<00:00, 79.98it/s]
# Generated embeddings for 3044 keyword-context-document pairs
# Average 30.56 contexts per keyword
# Generating keyword-based chunk embeddings...
# Generating chunk embeddings: 100%|████████████| 127/127 [00:02<00:00, 61.22it/s]
# Generated embeddings for 127 chunks
# Found keywords in 127 chunks
# Average 24.06 keywords per chunk with keywords
# Creating keyword embedding database...
# Creating chunk embedding database...
# Creating keyword-based chunk embedding database...
# Creating vector database for efficient similarity search...
# Vector databases created with 3044 keyword embeddings, 127 chunk embeddings, and 127 keyword-chunk embeddings.

# %%
rag.keywords
# Out:
# [['ﬁguration',
#   'properties',
#   'defects',
#   'machine',
#   'machine learning',
#   'materials',
#   'learning',
#   'sparse representation',
#   'huang',
#   'open',
#   'space',
#   'crystals',
#   'electronic',
#   'lattice',
#   'sparse'],
#  ['ﬁguration',
#   'materials',
#   'properties',
#   'defect',
#   'https',
#   'npj',
#   'prediction',
#   'methods',
#   'neural',
#   'atomic',
#   'computational',
#   'state',
#   'quantum',
#   'material',
#   'energy'],
#  ['atomic',
#   'quantum',
#   'defects',
#   'properties',
#   'ﬁguration',
#   'space',
#   'materials',
#   'crystals',
#   'property',
#   'point',
#   'methods',
#   'crystal',
#   'structure',
#   'material'],
#  ['ﬁguration',
#   'defects',
#   'space',
#   'methods',
#   'quantum',
#   'learning',
#   'point defects',
#   'crystals',
#   'property',
#   'large',
#   'prediction',
#   'point',
#   'state',
#   'density',
#   'machine'],
#  ['learning',
#   'machine',
#   'machine learning',
#   'methods',
#   'calculations',
#   'materials',
#   'material',
#   'networks',
#   'neural networks',
#   'functional',
#   'graph neural',
#   'megnet',
#   'used',
#   'large',
#   'dft'],
#  ['datasets',
#   'database',
#   'high',
#   'defects',
#   'machine',
#   'machine learning',
#   'materials',
#   'learning',
#   'gase',
#   'inse',
#   'use',
#   'wse',
#   'calculations',
#   'electronic',
#   'prediction'],
#  ['networks',
#   'neural networks',
#   'graph neural',
#   'property',
#   'graph',
#   'methods',
#   'neural',
#   'properties',
#   'nature',
#   'range',
#   'lattice',
#   'based',
#   'atomic',
#   'state',
#   'quantum'],
#  ['singapore',
#   'university',
#   'networks',
#   'neural networks',
#   'functional',
#   'nature',
#   'graph neural',
#   'materials',
#   'partnership',
#   'published partnership',
#   'graph',
#   'based',
#   'neural',
#   'atomic',
#   'published'],
#  ['information',
#   'graph neural',
#   'megnet',
#   'open',
#   'graph',
#   'based',
#   'neural',
#   'representation',
#   'atomic',
#   'atoms',
#   'structure',
#   'materials'],
#  ['graph',
#   'information',
#   'graph neural',
#   'neural',
#   'networks',
#   'neural networks',
#   'use',
#   'wave function',
#   'megnet',
#   'function',
#   'materials',
#   'crystals',
#   'electronic',
#   'model',
#   'wave'],
#  ['defect',
#   'levels',
#   'electrons',
#   'lattice',
#   'wave',
#   'states',
#   'fig',
#   'energy',
#   'networks',
#   'neural networks',
#   'wave function',
#   'graph neural',
#   'band',
#   'function',
#   'sites'],
#  ['defect',
#   'states',
#   'lumo',
#   'gap',
#   'ﬁgurations',
#   'homo',
#   'formation',
#   'defects',
#   'machine',
#   'machine learning',
#   'learning',
#   'levels',
#   'point defects',
#   'functional',
#   'use'],
#  ['based',
#   'use',
#   'point defects',
#   'used',
#   'point',
#   'defects',
#   'structures',
#   'properties',
#   'combined',
#   'pristine',
#   'megnet',
#   'materials',
#   'large',
#   'single',
#   'dft'],
#  ['dft',
#   'quantum',
#   'dataset',
#   'defects',
#   'nature',
#   'use',
#   'wave function',
#   'function',
#   'crystals',
#   'single',
#   'electronic',
#   'lattice',
#   'prediction',
#   'sparse',
#   'wave'],
#  ['wave function',
#   'function',
#   'wave',
#   'defect',
#   'levels',
#   'lattice',
#   'crystal',
#   'nature',
#   'partnership',
#   'published partnership',
#   'single',
#   'sites',
#   'dft',
#   'npj',
#   'interaction'],
#  ['structures',
#   'point',
#   'defects',
#   'number',
#   'atomic',
#   'machine',
#   'machine learning',
#   'learning',
#   'properties',
#   'point defects',
#   'sparse representation',
#   'space',
#   'crystals',
#   'electrons',
#   'sparse'],
#  ['structure',
#   'atomic',
#   'pristine',
#   'number',
#   'point',
#   'defects',
#   'atoms',
#   'crystal',
#   'structures',
#   'sites',
#   'vacancies',
#   'using',
#   'state',
#   'site',
#   'fig'],
#  ['pristine',
#   'material',
#   'graph',
#   'crystal',
#   'structure',
#   'networks',
#   'neural networks',
#   'graph neural',
#   'used',
#   'crystals',
#   'electronic',
#   'using',
#   'neural',
#   'atomic',
#   'state'],
#  ['electronic',
#   'wave',
#   'nature',
#   'eos',
#   'wave function',
#   'function',
#   'states',
#   'defect',
#   'used',
#   'crystals',
#   'electrons',
#   'crystal',
#   'fig',
#   'vacancy',
#   'formation'],
#  ['eos',
#   'atoms',
#   'electron',
#   'wave function',
#   'function',
#   'crystals',
#   'number',
#   'lattice',
#   'wave',
#   'interaction',
#   'representation',
#   'atomic',
#   'crystal',
#   'site',
#   'dataset'],
#  ['graph',
#   'representation',
#   'eos',
#   'sparse representation',
#   'sparse',
#   'mos',
#   'partnership',
#   'published partnership',
#   'vacancies',
#   'npj',
#   'lattice',
#   'point',
#   'computational',
#   'crystal',
#   'published'],
#  ['graph',
#   'graph neural',
#   'neural',
#   'atomic',
#   'eos',
#   'networks',
#   'neural networks',
#   'point defects',
#   'structure',
#   'number',
#   'point',
#   'representation',
#   'pristine',
#   'sparse representation',
#   'defect'],
#  ['defect',
#   'ﬁgurations',
#   'wse',
#   'low',
#   'used',
#   'point',
#   'datasets',
#   'dataset',
#   'fig',
#   'high',
#   'mos',
#   'structures',
#   'available',
#   'gase',
#   'inse'],
#  ['structures',
#   'defect',
#   'used',
#   'energy',
#   'dft',
#   'density',
#   'formation energy',
#   'dataset',
#   'formation',
#   'functional',
#   'nature',
#   'use',
#   'lumo',
#   'data',
#   'gap'],
#  ['energy',
#   'number',
#   'formation energy',
#   'formation',
#   'defects',
#   'defect',
#   'structure',
#   'pristine',
#   'use',
#   'sites',
#   'dft',
#   'electronic',
#   'lumo',
#   'gap',
#   'homo'],
#  ['spin',
#   'number',
#   'lumo',
#   'homo',
#   'states',
#   'defects',
#   'energy',
#   'levels',
#   'gase',
#   'inse',
#   'electrons',
#   'sites',
#   'dft',
#   'electronic',
#   'gap'],
#  ['model',
#   'use',
#   'ﬁguration',
#   'material',
#   'supplementary',
#   'lumo',
#   'gap',
#   'ﬁgurations',
#   'dataset',
#   'structures',
#   'energy'],
#  ['density',
#   'number',
#   'dataset',
#   'high',
#   'combined',
#   'low',
#   'defect',
#   'sparse representation',
#   'use',
#   'megnet',
#   'sparse',
#   'using',
#   'representation',
#   'structures'],
#  ['representation',
#   'combined',
#   'megnet',
#   'gase',
#   'inse',
#   'sparse representation',
#   'defect',
#   'wse',
#   'low',
#   'partnership',
#   'published partnership',
#   'vacancies',
#   'lumo',
#   'model',
#   'npj'],
#  ['representation',
#   'prediction',
#   'sparse representation',
#   'megnet',
#   'sparse',
#   'combined',
#   'supplementary',
#   'wse',
#   'low',
#   'model',
#   'ﬁgurations',
#   'quantum',
#   'dataset',
#   'mos',
#   'structure'],
#  ['dataset',
#   'sparse representation',
#   'supplementary',
#   'model',
#   'sparse',
#   'data',
#   'representation',
#   'quantum',
#   'vacancy',
#   'use',
#   'low',
#   'used',
#   'prediction',
#   'ﬁgurations',
#   'density'],
#  ['sparse',
#   'sparse representation',
#   'representation',
#   'model',
#   'supplementary',
#   'use',
#   'megnet',
#   'ﬁguration',
#   'formation energy',
#   'formation',
#   'energy'],
#  ['sparse',
#   'pristine',
#   'model',
#   'dataset',
#   'fig',
#   'structures',
#   'available',
#   'sparse representation',
#   'supplementary',
#   'defect',
#   'defects',
#   'low',
#   'space',
#   'number',
#   'representation'],
#  ['available',
#   'supplementary',
#   'space',
#   'partnership',
#   'published partnership',
#   'npj',
#   'computational',
#   'published',
#   'fig',
#   'structures',
#   'defects',
#   'materials'],
#  ['eos',
#   'crystals',
#   'density',
#   'low',
#   'prediction',
#   'sparse',
#   'datasets',
#   'properties',
#   'combined',
#   'information',
#   'nature',
#   'space',
#   'lumo',
#   'model',
#   'data'],
#  ['representation',
#   'properties',
#   'crystals',
#   'sparse',
#   'using',
#   'machine',
#   'machine learning',
#   'learning',
#   'combined',
#   'sparse representation',
#   'graph neural',
#   'megnet',
#   'defects',
#   'vacancies',
#   'prediction'],
#  ['representation',
#   'functional',
#   'materials',
#   'dft',
#   'sparse',
#   'dataset',
#   'material',
#   'point defects',
#   'sparse representation',
#   'defect',
#   'defects',
#   'calculations',
#   'used',
#   'crystals',
#   'interaction'],
#  ['high',
#   'megnet',
#   'material',
#   'energy',
#   'combined',
#   'gase',
#   'inse',
#   'supplementary',
#   'functional',
#   'database',
#   'used',
#   'electrons',
#   'large',
#   'sparse',
#   'wave'],
#  ['high',
#   'low',
#   'wse',
#   'gase',
#   'inse',
#   'megnet',
#   'mos',
#   'combined',
#   'lumo',
#   'sparse',
#   'gap',
#   'homo',
#   'density',
#   'material'],
#  ['dataset',
#   'megnet',
#   'combined',
#   'low',
#   'model',
#   'sparse',
#   'representation',
#   'datasets',
#   'density',
#   'high',
#   'mos',
#   'structures',
#   'material'],
#  ['dataset',
#   'combined',
#   'partnership',
#   'published partnership',
#   'model',
#   'npj',
#   'computational',
#   'datasets',
#   'published',
#   'materials'],
#  ['calculations',
#   'energy',
#   'spin',
#   'space',
#   'used',
#   'electrons',
#   'electronic',
#   'interaction',
#   'atomic',
#   'atoms',
#   'high',
#   'structures',
#   'structure',
#   'defect'],
#  ['spin',
#   'neural',
#   'available',
#   'networks',
#   'neural networks',
#   'graph neural',
#   'calculations',
#   'graph',
#   'supplementary',
#   'low',
#   'electrons',
#   'single',
#   'electronic',
#   'state',
#   'states'],
#  ['graph',
#   'ﬁguration',
#   'function',
#   'property',
#   'large',
#   'partnership',
#   'published partnership',
#   'dft',
#   'npj',
#   'neural',
#   'atoms',
#   'computational',
#   'crystal',
#   'published',
#   'formation energy'],
#  ['graph',
#   'number',
#   'atoms',
#   'state',
#   'neural',
#   'crystal',
#   'states',
#   'structure'],
#  ['state',
#   'information',
#   'graph',
#   'sparse representation',
#   'used',
#   'model',
#   'sparse',
#   'based',
#   'representation',
#   'material'],
#  ['based',
#   'state',
#   'combined',
#   'networks',
#   'neural networks',
#   'information',
#   'model',
#   'data',
#   'graph',
#   'neural',
#   'dataset',
#   'learning'],
#  ['high',
#   'sparse',
#   'combined',
#   'low',
#   'eos',
#   'gase',
#   'inse',
#   'wse',
#   'lumo',
#   'data',
#   'gap',
#   'using',
#   'based',
#   'homo',
#   'crystal'],
#  ['sparse',
#   'high',
#   'eos',
#   'low',
#   'wse',
#   'megnet',
#   'used',
#   'mos',
#   'structure',
#   'material',
#   'combined',
#   'gase',
#   'inse',
#   'pristine',
#   'lumo'],
#  ['eos',
#   'pristine',
#   'partnership',
#   'published partnership',
#   'npj',
#   'sparse',
#   'atomic',
#   'computational',
#   'published',
#   'site',
#   'dataset',
#   'material',
#   'defects',
#   'materials'],
#  ['available',
#   'https',
#   'prediction',
#   'nature',
#   'defects',
#   'used',
#   'single',
#   'data',
#   'datasets',
#   'state',
#   'machine',
#   'machine learning',
#   'learning'],
#  ['point defects',
#   'point',
#   'mater',
#   'quantum',
#   'defects',
#   'phys',
#   'calculations',
#   'database',
#   'rev',
#   'open',
#   'materials',
#   'dft',
#   'npj',
#   'based',
#   'neural'],
#  ['phys',
#   'graph',
#   'neural',
#   'networks',
#   'learning',
#   'mater',
#   'neural networks',
#   'phys rev',
#   'graph neural',
#   'rev',
#   'crystals',
#   'dft',
#   'prediction',
#   'computational',
#   'crystal'],
#  ['neural',
#   'mater',
#   'phys',
#   'graph',
#   'materials',
#   'learning',
#   'networks',
#   'neural networks',
#   'phys rev',
#   'https',
#   'graph neural',
#   'huang',
#   'rev',
#   'property',
#   'npj'],
#  ['https',
#   'graph',
#   'neural',
#   'graph neural',
#   'spin',
#   'mater',
#   'networks',
#   'neural networks',
#   'phys rev',
#   'phys',
#   'huang',
#   'rev',
#   'property',
#   'large',
#   'npj'],
#  ['vacancy',
#   'formation',
#   'https',
#   'phys',
#   'energy',
#   'phys rev',
#   'graph neural',
#   'calculations',
#   'huang',
#   'rev',
#   'materials',
#   'model',
#   'prediction',
#   'graph',
#   'using'],
#  ['mater',
#   'learning',
#   'defect',
#   'machine',
#   'machine learning',
#   'mos',
#   'https',
#   'phys',
#   'open',
#   'materials',
#   'data',
#   'point',
#   'using',
#   'based',
#   'high'],
#  ['phys rev',
#   'phys',
#   'rev',
#   'mater',
#   'materials',
#   'range',
#   'calculations',
#   'open',
#   'wave',
#   'interaction',
#   'using',
#   'neural',
#   'learning',
#   'energy',
#   'defect'],
#  ['phys',
#   'wave',
#   'phys rev',
#   'calculations',
#   'rev',
#   'using',
#   'energy',
#   'mater',
#   'https',
#   'information',
#   'open',
#   'graph',
#   'learning',
#   'materials'],
#  ['mater',
#   'structure',
#   'materials',
#   'density',
#   'machine',
#   'machine learning',
#   'learning',
#   'phys rev',
#   'information',
#   'phys',
#   'rev',
#   'ﬁguration',
#   'open',
#   'used',
#   'interaction'],
#  ['partnership',
#   'published partnership',
#   'npj',
#   'based',
#   'representation',
#   'atoms',
#   'computational',
#   'published',
#   'structure',
#   'materials'],
#  ['university',
#   'singapore',
#   'functional',
#   'number',
#   'computational',
#   'materials'],
#  ['computational',
#   'sparse representation',
#   'megnet',
#   'sparse',
#   'representation',
#   'singapore',
#   'eos',
#   'used',
#   'using',
#   'high',
#   'structures'],
#  ['information',
#   'available',
#   'supplementary',
#   'computational',
#   'https',
#   'nature',
#   'megnet',
#   'huang',
#   'low',
#   'dft',
#   'data',
#   'using',
#   'density',
#   'structures',
#   'material'],
#  ['nature',
#   'use',
#   'material',
#   'available',
#   'information',
#   'huang',
#   'open',
#   'published'],
#  ['use',
#   'material',
#   'partnership',
#   'published partnership',
#   'npj',
#   'computational',
#   'published',
#   'materials'],
#  ['materials',
#   'properties',
#   'defects',
#   'huang',
#   'open',
#   'property',
#   'model',
#   'based',
#   'methods',
#   'datasets',
#   'high',
#   'machine',
#   'machine learning',
#   'structure',
#   'learning'],
#  ['machine',
#   'machine learning',
#   'materials',
#   'learning',
#   'datasets',
#   'properties',
#   'defect',
#   'material',
#   'available',
#   'gase',
#   'inse',
#   'pristine',
#   'wse',
#   'database',
#   'dft'],
#  ['materials',
#   'properties',
#   'crystals',
#   'available',
#   'https',
#   'database',
#   'npj',
#   'atoms',
#   'crystal',
#   'material'],
#  ['defects',
#   'single',
#   'properties',
#   'database',
#   'used',
#   'crystals',
#   'electronic',
#   'using',
#   'methods',
#   'machine',
#   'machine learning',
#   'mos',
#   'structures',
#   'learning',
#   'material'],
#  ['single',
#   'state',
#   'defect',
#   'high',
#   'structure',
#   'properties',
#   'functional',
#   'defects',
#   'space',
#   'materials',
#   'property',
#   'dft',
#   'methods',
#   'density',
#   'material'],
#  ['material',
#   'machine',
#   'machine learning',
#   'learning',
#   'materials',
#   'graph neural',
#   'megnet',
#   'database',
#   'property',
#   'large',
#   'number',
#   'prediction',
#   'data',
#   'graph',
#   'methods'],
#  ['singapore',
#   'learning',
#   'university',
#   'machine',
#   'machine learning',
#   'prediction',
#   'defects',
#   'properties',
#   'functional',
#   'nature',
#   'materials',
#   'methods',
#   'datasets',
#   'states',
#   'quantum'],
#  ['singapore',
#   'university',
#   'functional',
#   'nature',
#   'materials',
#   'partnership',
#   'published partnership',
#   'npj',
#   'published'],
#  ['defect',
#   'prediction',
#   'database',
#   'properties',
#   'point',
#   'machine',
#   'machine learning',
#   'materials',
#   'learning',
#   'point defects',
#   'range',
#   'data',
#   'methods',
#   'density',
#   'quantum'],
#  ['property',
#   'quantum',
#   'datasets',
#   'defect',
#   'crystals',
#   'model',
#   'prediction',
#   'interaction',
#   'crystal',
#   'formation energy',
#   'formation',
#   'high',
#   'machine',
#   'machine learning',
#   'learning'],
#  ['defect',
#   'space',
#   'prediction',
#   'datasets',
#   'wave function',
#   'function',
#   'materials',
#   'model',
#   'wave',
#   'data',
#   'ﬁgurations',
#   'states',
#   'fig',
#   'machine',
#   'machine learning'],
#  ['space',
#   'datasets',
#   'fig',
#   'defect',
#   'defects',
#   'ﬁguration',
#   'materials',
#   'large',
#   'vacancies',
#   'prediction',
#   'data',
#   'ﬁgurations',
#   'methods',
#   'computational',
#   'machine'],
#  ['datasets',
#   'defect',
#   'properties',
#   'dataset',
#   'nature',
#   'space',
#   'data',
#   'ﬁgurations',
#   'defects',
#   'information',
#   'wse',
#   'large',
#   'single',
#   'crystal',
#   'site'],
#  ['properties',
#   'defect',
#   'range',
#   'space',
#   'data',
#   'mos',
#   'learning',
#   'gase',
#   'inse',
#   'wse',
#   'materials',
#   'large',
#   'dft',
#   'ﬁgurations',
#   'atomic'],
#  ['range',
#   'mos',
#   'structures',
#   'wse',
#   'atomic',
#   'formation energy',
#   'formation',
#   'defect',
#   'defects',
#   'properties',
#   'energy',
#   'levels',
#   'available',
#   'gase',
#   'inse'],
#  ['datasets',
#   'defect',
#   'defects',
#   'machine',
#   'machine learning',
#   'learning',
#   'huang',
#   'space',
#   'materials',
#   'partnership',
#   'published partnership',
#   'vacancies',
#   'interaction',
#   'published',
#   'formation energy'],
#  ['range',
#   'lumo',
#   'homo',
#   'structure',
#   'energy',
#   'defect',
#   'huang',
#   'number',
#   'partnership',
#   'published partnership',
#   'npj',
#   'published',
#   'site',
#   'formation energy',
#   'formation'],
#  ['range',
#   'huang',
#   'partnership',
#   'published partnership',
#   'lumo',
#   'homo',
#   'published',
#   'site',
#   'structure',
#   'energy',
#   'defect',
#   'materials'],
#  ['vacancy',
#   'formation energy',
#   'formation',
#   'energy',
#   'range',
#   'defects',
#   'lattice',
#   'electron',
#   'ﬁguration',
#   'large',
#   'vacancies',
#   'atoms'],
#  ['band',
#   'lattice',
#   'quantum',
#   'defect',
#   'electron',
#   'information',
#   'ﬁguration',
#   'single',
#   'electronic',
#   'lumo',
#   'gap',
#   'homo',
#   'atoms',
#   'formation energy',
#   'formation'],
#  ['band',
#   'gap',
#   'levels',
#   'property',
#   'formation energy',
#   'quantum',
#   'dataset',
#   'fig',
#   'formation',
#   'defects',
#   'energy',
#   'defect',
#   'information',
#   'range',
#   'space'],
#  ['gap',
#   'levels',
#   'defects',
#   'formation',
#   'energy',
#   'low',
#   'band',
#   'property',
#   'large',
#   'single',
#   'vacancies',
#   'electronic',
#   'lattice',
#   'state',
#   'states'],
#  ['band',
#   'formation',
#   'defects',
#   'formation energy',
#   'vacancies',
#   'energy',
#   'gap',
#   'vacancy',
#   'range',
#   'low',
#   'property',
#   'number',
#   'single',
#   'sites',
#   'lattice'],
#  ['defects',
#   'property',
#   'mos',
#   'gase',
#   'inse',
#   'wse',
#   'density',
#   'fig',
#   'high',
#   'band',
#   'materials',
#   'electrons',
#   'number',
#   'vacancies',
#   'formation energy'],
#  ['defects',
#   'electron',
#   'gase',
#   'inse',
#   'band',
#   'electrons',
#   'gap',
#   'spin',
#   'information',
#   'wse',
#   'number',
#   'atoms',
#   'datasets',
#   'states',
#   'vacancy'],
#  ['sites',
#   'vacancy',
#   'spin',
#   'supplementary',
#   'defect',
#   'range',
#   'huang',
#   'large',
#   'number',
#   'partnership',
#   'published partnership',
#   'lumo',
#   'npj',
#   'homo',
#   'atomic'],
#  ['vacancies',
#   'vacancy',
#   'sites',
#   'energy',
#   'interaction',
#   'quantum',
#   'properties',
#   'defect',
#   'defects',
#   'function',
#   'number',
#   'single',
#   'lumo',
#   'ﬁgurations',
#   'homo'],
#  ['sites',
#   'defect',
#   'structure',
#   'wave function',
#   'range',
#   'function',
#   'crystals',
#   'electrons',
#   'number',
#   'vacancies',
#   'lattice',
#   'wave',
#   'interaction',
#   'site',
#   'formation energy'],
#  ['property',
#   'single',
#   'defect',
#   'defects',
#   'electron',
#   'wave function',
#   'band',
#   'function',
#   'sites',
#   'lattice',
#   'wave',
#   'gap',
#   'interaction',
#   'atoms',
#   'crystal'],
#  ['vacancy',
#   'defects',
#   'band',
#   'property',
#   'lumo',
#   'gap',
#   'fig',
#   'energy',
#   'defect',
#   'huang',
#   'function',
#   'partnership',
#   'published partnership',
#   'sites',
#   'data'],
#  ['sites',
#   'electron',
#   'energy',
#   'defect',
#   'band',
#   'electrons',
#   'single',
#   'lattice',
#   'wave',
#   'atomic',
#   'states',
#   'defects'],
#  ['electron',
#   'electrons',
#   'sites',
#   'state',
#   'energy',
#   'defect',
#   'ﬁguration',
#   'band',
#   'interaction',
#   'defects'],
#  ['wave',
#   'interaction',
#   'energy',
#   'fig',
#   'vacancy',
#   'electron',
#   'wave function',
#   'function',
#   'lattice',
#   'gap',
#   'levels',
#   'defect',
#   'sites',
#   'based',
#   'atoms'],
#  ['function',
#   'wave',
#   'wave function',
#   'fig',
#   'sites',
#   'vacancy',
#   'atomic',
#   'atoms',
#   'interaction',
#   'energy',
#   'electron',
#   'pristine',
#   'electrons',
#   'lattice',
#   'states'],
#  ['wave',
#   'atoms',
#   'electrons',
#   'vacancies',
#   'lattice',
#   'atomic',
#   'states',
#   'site',
#   'vacancy',
#   'wave function',
#   'function',
#   'sites',
#   'homo',
#   'mos',
#   'structure'],
#  ['states',
#   'vacancy',
#   'vacancies',
#   'lattice',
#   'wave',
#   'homo',
#   'wave function',
#   'function',
#   'sites',
#   'fig',
#   'energy',
#   'pristine',
#   'ﬁguration',
#   'large',
#   'interaction'],
#  ['fig',
#   'vacancies',
#   'wave',
#   'defect',
#   'wave function',
#   'function',
#   'sites',
#   'energy',
#   'states',
#   'levels',
#   'ﬁguration',
#   'band',
#   'large',
#   'lumo',
#   'lattice'],
#  ['defect',
#   'data',
#   'states',
#   'dataset',
#   'structure',
#   'supplementary',
#   'range',
#   'calculations',
#   'database',
#   'used',
#   'materials',
#   'electrons',
#   'property',
#   'sites',
#   'dft'],
#  ['property',
#   'defect',
#   'dataset',
#   'structure',
#   'calculations',
#   'band',
#   'large',
#   'single',
#   'vacancies',
#   'dft',
#   'electronic',
#   'lattice',
#   'data',
#   'gap',
#   'ﬁgurations'],
#  ['dataset',
#   'huang',
#   'space',
#   'materials',
#   'large',
#   'partnership',
#   'published partnership',
#   'electronic',
#   'npj',
#   'lattice',
#   'ﬁgurations',
#   'published',
#   'site',
#   'quantum',
#   'structure'],
#  ['materials',
#   'defects',
#   'property',
#   'vacancies',
#   'datasets',
#   'dataset',
#   'ﬁguration',
#   'single',
#   'methods',
#   'atomic',
#   'density',
#   'site',
#   'formation',
#   'high',
#   'mos'],
#  ['wse',
#   'mos',
#   'available',
#   'defects',
#   'dataset',
#   'structures',
#   'material',
#   'combined',
#   'gase',
#   'inse',
#   'point defects',
#   'defect',
#   'https',
#   'range',
#   'ﬁguration'],
#  ['calculations',
#   'functional',
#   'material',
#   'dft',
#   'density',
#   'structures',
#   'spin',
#   'defect',
#   'defects',
#   'database',
#   'electrons',
#   'wave',
#   'interaction',
#   'using',
#   'based'],
#  ['spin',
#   'calculations',
#   'used',
#   'structures',
#   'supplementary',
#   'defect',
#   'database',
#   'low',
#   'space',
#   'materials',
#   'electrons',
#   'large',
#   'electronic',
#   'interaction',
#   'point'],
#  ['vacancy',
#   'spin',
#   'vacancies',
#   'wave',
#   'structures',
#   'energy',
#   'defect',
#   'wave function',
#   'calculations',
#   'huang',
#   'low',
#   'band',
#   'function',
#   'partnership',
#   'published partnership'],
#  ['energy',
#   'defect',
#   'site',
#   'interaction',
#   'states',
#   'formation energy',
#   'formation',
#   'structure',
#   'levels',
#   'pristine',
#   'defects',
#   'number',
#   'single',
#   'electronic',
#   'homo'],
#  ['homo',
#   'defects',
#   'levels',
#   'band',
#   'pristine',
#   'electronic',
#   'lumo',
#   'representation',
#   'states',
#   'structures',
#   'properties',
#   'energy',
#   'defect'],
#  ['homo',
#   'pristine',
#   'energy',
#   'band',
#   'lumo',
#   'defect',
#   'space',
#   'mos',
#   'defects',
#   'wave',
#   'gap',
#   'state',
#   'states',
#   'structures'],
#  ['lumo',
#   'band',
#   'data',
#   'gap',
#   'methods',
#   'spin',
#   'available',
#   'point defects',
#   'functional',
#   'https',
#   'defects',
#   'calculations',
#   'rev',
#   'open',
#   'point'],
#  ['quantum',
#   'mater',
#   'materials',
#   'single',
#   'spin',
#   'wse',
#   'database',
#   'rev',
#   'open',
#   'state',
#   'published',
#   'structures',
#   'defects'],
#  ['mater',
#   'networks',
#   'database',
#   'open',
#   'graph',
#   'high',
#   'materials',
#   'neural networks',
#   'phys rev',
#   'functional',
#   'phys',
#   'rev',
#   'crystals',
#   'dft',
#   'npj'],
#  ['neural',
#   'networks',
#   'neural networks',
#   'phys',
#   'graph',
#   'learning',
#   'phys rev',
#   'https',
#   'information',
#   'graph neural',
#   'rev',
#   'materials',
#   'prediction',
#   'using',
#   'crystal'],
#  ['machine',
#   'machine learning',
#   'learning',
#   'materials',
#   'point',
#   'high',
#   'point defects',
#   'database',
#   'open',
#   'data',
#   'using',
#   'based',
#   'computational',
#   'quantum',
#   'defect'],
#  ['mater',
#   'point',
#   'point defects',
#   'learning',
#   'database',
#   'high',
#   'machine',
#   'machine learning',
#   'materials',
#   'phys rev',
#   'defect',
#   'https',
#   'phys',
#   'defects',
#   'rev'],
#  ['phys rev',
#   'phys',
#   'rev',
#   'point defects',
#   'https',
#   'range',
#   'huang',
#   'open',
#   'electrons',
#   'model',
#   'interaction',
#   'point',
#   'atoms',
#   'vacancy',
#   'defects'],
#  ['phys rev',
#   'phys',
#   'rev',
#   'range',
#   'huang',
#   'partnership',
#   'published partnership',
#   'npj',
#   'interaction',
#   'states',
#   'published',
#   'materials'],
#  ['phys rev',
#   'phys',
#   'rev',
#   'wave',
#   'using',
#   'mater',
#   'functional',
#   'calculations',
#   'atomic',
#   'atoms',
#   'density',
#   'energy'],
#  ['singapore',
#   'computational',
#   'university',
#   'phys rev',
#   'functional',
#   'phys',
#   'rev',
#   'materials',
#   'number'],
#  ['information',
#   'available',
#   'supplementary',
#   'nature',
#   'university',
#   'https',
#   'calculations',
#   'open',
#   'data',
#   'published',
#   'material',
#   'materials'],
#  ['use', 'material', 'nature', 'open', 'published'],
#  ['use',
#   'huang',
#   'partnership',
#   'published partnership',
#   'published',
#   'materials']]

# %%
keyword_stats = rag.get_all_unique_keywords()
    

    
# Print a summary
print(f"Total unique keywords: {len(keyword_stats)}")
# Out:
# Total unique keywords: 100
#
# Top 10 keywords by document coverage:
# 'ﬁguration': 2 documents, 21 total occurrences
# 'properties': 2 documents, 54 total occurrences
# 'defects': 2 documents, 144 total occurrences
# 'machine': 2 documents, 45 total occurrences
# 'machine learning': 2 documents, 43 total occurrences
# 'materials': 2 documents, 125 total occurrences
# 'learning': 2 documents, 60 total occurrences
# 'huang': 2 documents, 16 total occurrences
# 'open': 2 documents, 17 total occurrences
# 'space': 2 documents, 26 total occurrences
# Total unique keywords: 100

# %%
    
# Save the system
rag.save(".data/context_rag_system_v2")
# Out:
# Saving model to .data/context_rag_system_v2...
# Model saved successfully to .data/context_rag_system_v2
# - Saved 3044 keyword embeddings
# - Saved 127 chunk embeddings
# - Saved 127 keyword-chunk embeddings
# - Saved vectorizer: True
# - Embedding model name: Not specified

# %%
query = "What is machine learning?"
results = rag.process_query(
        query, 
        top_k=5, 
        keyword_weight=0.3,  # Emphasize keyword matches
        chunk_weight=0.3,     # But also consider whole-chunk similarity
        keyword_chunk_weight=0.4,
    )
# Out:
# Retrieving: 2 keyword results, 2 chunk results, 1 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 5 results

# %%
    
print("\nHybrid Query Results:")
for i, result in enumerate(results):
    print(f"\nResult {i+1} Score: {result['score']:.4f}: Original_score: {result['original_score']:.4f}")
    print(f"Document ID: {result.get('doc_id', '')}")
    print(f"Type of searching: {result.get('result_type', '')}")
    print(f"Keyword: {result.get('keyword','')}")
    print(f"Text: {result['text'][:200]}...")
# Out:
# Hybrid Query Results:
#
# Result 1 Score: 0.2905: Original_score: 0.9683
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: materials are notoriously dif ﬁcult to model. Thus, it is very tempting to apply machine learning methods to such systems.
# Unfortunately, there is only a handful of machine learning-friendly material ...
#
# Result 2 Score: 0.2902: Original_score: 0.9674
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: ARTICLE OPEN
# Unveiling the complex structure-property correlation of defects
# in 2D materials based on high throughput datasets
# Pengru Huang1, Ruslan Lukin2, Maxim Faleev2, Nikita Kazeev1,3, Abdalaziz ...
#
# Result 3 Score: 0.0107: Original_score: 0.0356
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: learning
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 4 Score: 0.0102: Original_score: 0.0341
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: machine
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 5 Score: -0.0022: Original_score: -0.0055
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...

# %%
def query_searching(query):
    # Example query - search across all documents
    
    results = rag.process_query(
        query, 
        top_k=3, 
        keyword_weight=0.8,  # Emphasize keyword matches
        chunk_weight=0.2     # But also consider whole-chunk similarity
    )
    
    print(f"\nHybrid Query Results: \n ***  {query}")
    for i, result in enumerate(results):
        print(f"\nResult {i+1} Score: {result['score']:.4f}: Original_score: {result['original_score']:.4f}")
        print(f"Document ID: {result.get('doc_id', '')}")
        print(f"Type of searching: {result.get('result_type', '')}")
        print(f"Keyword: {result.get('keyword','')}")
        print(f"Text: {result['text'][:200]}...")

# %%
import pandas as pd

df_ground_true = pd.read_csv("../data/data_rag/QA_ai4mat_2articles.csv")

questions = df_ground_true['question'].values.tolist()
answers = df_ground_true['answer'].values.tolist()

# %%
for q in questions:
    #print("****",q)
    query_searching(q)
    #print(8*".-.", "\n")
# Out:
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Which materials are in the dataset?
#
# Result 1 Score: 0.1409: Original_score: 0.9864
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 2 Score: 0.0243: Original_score: 0.0425
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: materials
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0003: Original_score: -0.0011
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How many structures are there in the dataset?
#
# Result 1 Score: 0.1396: Original_score: 0.9774
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 2 Score: 0.0299: Original_score: 0.0523
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: many
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0027: Original_score: 0.0094
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How to obtain the dataset?
#
# Result 1 Score: 0.1377: Original_score: 0.9636
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 Score: 0.0224: Original_score: 0.0393
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: dataset
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0016: Original_score: 0.0057
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * What is the dataset license?
#
# Result 1 Score: 0.1368: Original_score: 0.9575
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 2 Score: 0.0224: Original_score: 0.0393
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: dataset
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0015: Original_score: -0.0054
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * What is the data format?
#
# Result 1 Score: 0.1376: Original_score: 0.9630
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 2 Score: 0.0304: Original_score: 0.0532
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: format
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0056: Original_score: 0.0197
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How to read the dataset?
#
# Result 1 Score: 0.1378: Original_score: 0.9645
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 2 Score: 0.0224: Original_score: 0.0393
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: dataset
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0014: Original_score: 0.0048
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How to browse the dataset?
#
# Result 1 Score: 0.1377: Original_score: 0.9636
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 Score: 0.0224: Original_score: 0.0393
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: dataset
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0000: Original_score: -0.0001
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 5 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Can I work with the dataset without Python?
#
# Result 1 Score: 0.1396: Original_score: 0.9773
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 Score: 0.0251: Original_score: 0.0439
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: python
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0003: Original_score: -0.0011
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How to obtain the raw VASP files?
#
# Result 1 Score: 0.1379: Original_score: 0.9655
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 Score: 0.0290: Original_score: 0.0508
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: raw
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0030: Original_score: 0.0105
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * What were the settings used for the DFT computations?
#
# Result 1 Score: 0.1398: Original_score: 0.9787
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: sparse representation succeeds perfectly, including the non-
# monotonous reduction at 5 Å.
# As shown in the Supplementary Discussion 3, the result is
# similar for untuned hyperparameters.
# Ablation study
# ...
#
# Result 2 Score: 0.0288: Original_score: 0.0503
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: settings used
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 3 Score: 0.0019: Original_score: 0.0065
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How well the DFT calculations correspond to experiment?
#
# Result 1 Score: 0.1409: Original_score: 0.9866
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: We use two target variables for evaluating machine learning
# methods: defect formation energy per site and HOMO –LUMO gap.
# Formation energy, i.e., the energy required to create a defect is
# deﬁned as
# E
# ...
#
# Result 2 Score: 0.0233: Original_score: 0.0407
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: correspond
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0010: Original_score: 0.0035
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How to cite the dataset?
#
# Result 1 Score: 0.1379: Original_score: 0.9652
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 2 Score: 0.0229: Original_score: 0.0401
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: cite
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 3 Score: 0.0027: Original_score: 0.0094
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * What was the procedure for SRGNN quality evaluation?
#
# Result 1 Score: 0.1381: Original_score: 0.9667
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
#
# Result 2 Score: 0.0250: Original_score: 0.0437
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: quality
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0006: Original_score: -0.0022
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How is SRGNN different from the baselines?
#
# Result 1 Score: 0.1400: Original_score: 0.9803
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 Score: 0.0279: Original_score: 0.0488
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: baselines
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0028: Original_score: 0.0097
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * What are the limitations of SRGNN?
#
# Result 1 Score: 0.1393: Original_score: 0.9754
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
# Result 2 Score: 0.0196: Original_score: 0.0343
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0009: Original_score: 0.0032
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * What is the core idea of SRGNN?
#
# Result 1 Score: 0.1392: Original_score: 0.9744
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: structures with unpaired electrons, we utilize standard collinearspin-polarized calculations with magnetic ions in a high-spin
# ferromagnetic initialization (the ion moments can of course relax to
# a lo...
#
# Result 2 Score: 0.0310: Original_score: 0.0543
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: core
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 3 Score: 0.0016: Original_score: 0.0057
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How to run the code?
#
# Result 1 Score: 0.1377: Original_score: 0.9642
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 2 Score: 0.0242: Original_score: 0.0423
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: run
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 3 Score: 0.0027: Original_score: 0.0095
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 5 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Which frameworks were used for SRGNN implementation?
#
# Result 1 Score: 0.1384: Original_score: 0.9688
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: calculations. The initial crystal structures were obtained from
# the Material Project database and the supercell sizes and thecomputational parameters for each materials are listed in the
# supplemental ...
#
# Result 2 Score: 0.0284: Original_score: 0.0497
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: used
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0013: Original_score: 0.0046
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Can SRGNN be developed on a CPU, not a GPU?
#
# Result 1 Score: 0.1388: Original_score: 0.9717
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
#
# Result 2 Score: 0.0215: Original_score: 0.0376
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: cpu
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 3 Score: 0.0009: Original_score: 0.0032
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * What is the code license?
#
# Result 1 Score: 0.1376: Original_score: 0.9631
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
# Result 2 Score: 0.0179: Original_score: 0.0314
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: code
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 3 Score: -0.0006: Original_score: -0.0021
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 2 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How to cite the code?
#
# Result 1 Score: 0.1390: Original_score: 0.9733
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: graphs. Published at the International Conference on Learning Representations(ICLR) 2020. Preprint at https://arXiv.org/abs/2003.03123 (2020).
# 18. Shuaibi, M. et al. Rotation invariant graph neural ne...
#
# Result 2 Score: 0.0229: Original_score: 0.0401
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: cite
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 3 Score: 0.0029: Original_score: 0.0102
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Which materials has the SRGNN been trained on?
#
# Result 1 Score: 0.1398: Original_score: 0.9786
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 2 Score: 0.0243: Original_score: 0.0425
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: materials
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0000: Original_score: -0.0002
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Which materials can the SRGNN be trained on?
#
# Result 1 Score: 0.1392: Original_score: 0.9746
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
# Result 2 Score: 0.0243: Original_score: 0.0425
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: materials
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0011: Original_score: -0.0037
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 5 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Which defect types can the SRGNN be trained on?
#
# Result 1 Score: 0.1384: Original_score: 0.9689
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
#
# Result 2 Score: 0.0250: Original_score: 0.0438
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: types
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0023: Original_score: -0.0082
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 7 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How many structures are needed for SRGNN training?
#
# Result 1 Score: 0.1399: Original_score: 0.9792
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 Score: 0.0299: Original_score: 0.0523
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: many
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0003: Original_score: -0.0010
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Can SRGNN handle 3D materials?
#
# Result 1 Score: 0.1406: Original_score: 0.9840
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 2 Score: 0.0243: Original_score: 0.0425
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: materials
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0024: Original_score: -0.0083
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 9 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How much computational resources does SRGNN require for training?
#
# Result 1 Score: 0.1396: Original_score: 0.9775
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
# Result 2 Score: 0.0267: Original_score: 0.0467
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: resources
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0017: Original_score: -0.0060
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * What is the inference speed of a SRGNN?
#
# Result 1 Score: 0.1397: Original_score: 0.9782
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 Score: 0.0318: Original_score: 0.0557
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: speed
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 3 Score: 0.0047: Original_score: 0.0166
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Which properties can be predicted using SRGNN?
#
# Result 1 Score: 0.1406: Original_score: 0.9844
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 Score: 0.0274: Original_score: 0.0480
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: properties
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 3 Score: 0.0017: Original_score: 0.0060
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 4 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * What was the quality of SRGNN for each property and material?
#
# Result 1 Score: 0.1395: Original_score: 0.9767
# Document ID: s41699-023-00369-1.pdf
# Type of searching: chunk
# Keyword: None
# Text: vacancies is smaller than that of the third con ﬁguration, the two
# vacancies occupy lattice sites where there is a knot of their wavefunctions. The wave functions of the HOMO retain that of the
# isolat...
#
# Result 2 Score: 0.0250: Original_score: 0.0437
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: quality
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0011: Original_score: -0.0040
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 7 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Can pre-trained SRGNN be used out-of-the-box?
#
# Result 1 Score: 0.1398: Original_score: 0.9784
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 Score: 0.0284: Original_score: 0.0497
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: used
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0006: Original_score: 0.0020
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 6 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How well do SRGNN results correspond to experiment?
#
# Result 1 Score: 0.1399: Original_score: 0.9792
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: (2018).
# 33. Banik, S. et al. Learning with delayed rewards –A case study on inverse defect
# design in 2d materials. ACS Appl. Mater. Interfaces 13, 36455 –36464 (2021).
# 34. Shytov, A. V., Abanin, D. A....
#
# Result 2 Score: 0.0233: Original_score: 0.0407
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: correspond
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0006: Original_score: 0.0020
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 5 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Can I use SRGNN in place of DFT?
#
# Result 1 Score: 0.1397: Original_score: 0.9780
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 2 Score: 0.0236: Original_score: 0.0413
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: place
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: 0.0010: Original_score: 0.0035
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 23 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * How can I use SRGNN to find materials for solar panels/transistors/photodetectors/single photon emitters/quantum computers?
#
# Result 1 Score: 0.1408: Original_score: 0.9855
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: different materials, but the authors didn ’t consider con ﬁgurations
# with multiple interacting defects. In a recent preprint27, the
# authors use a model based on CGCNN12to conduct a large scale
# screeni...
#
# Result 2 Score: 0.0313: Original_score: 0.0549
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: solar panels
# Text: the next generation of ( opto - ) electronic devices and other high technology applications. one of the most exciting characteristics of 2d crystals is the ability to tune their properties via control...
#
# Result 3 Score: -0.0006: Original_score: -0.0021
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Normalized weights: keyword=0.5714285714285715, chunk=0.14285714285714288, keyword_chunk=0.28571428571428575
# Retrieving: 1 keyword results, 1 chunk results, 1 keyword-chunk results
# Searching keyword database with 3 query terms...
# Searching chunk database...
# Searching keyword-chunk database...
# Retrieved 3 results
#
# Hybrid Query Results:
#  ***  * Is SRGNN patented?
#
# Result 1 Score: 0.1385: Original_score: 0.9693
# Document ID: s41524-023-01062-z.pdf
# Type of searching: chunk
# Keyword: None
# Text: For formation energy, just enabling the zcoordinate difference
# in sparse representation edges allows the Sparse-Z model to
# outperform the Full model everywhere except h-BN; adding
# pristine atom specie...
#
# Result 2 Score: 0.0196: Original_score: 0.0343
# Document ID: s41699-023-00369-1.pdf
# Type of searching: keyword
# Keyword: srgnn
# Text: a separate feature, which we call eos parity. fig. 2 the transition from full to sparse representation for an example mos 2supercell. a a full mos 2structure with one mo →w, two s→se...
#
# Result 3 Score: -0.0014: Original_score: -0.0049
# Document ID: s41524-023-01062-z.pdf
# Type of searching: keyword_chunk
# Keyword: None
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...

# %%
def query_searching(query):
    # Example query - search across all documents
    
    results = rag.process_query(
        query, 
        top_k=3, 
        mode= 'keywords_only',
        keyword_weight=0.8,  # Emphasize keyword matches
        chunk_weight=0.2     # But also consider whole-chunk similarity
    )
    
    print(f"\nHybrid Query Results: \n ***  {query}")
    for i, result in enumerate(results):
        print(f"\nResult {i+1} (Score: {result['score']:.4f}):")
        print(f"Document ID: {result['doc_id']}")
        print(f"Page: {result['page_num']}")
        print(f"Keywords: {', '.join(result['keywords'])}")
        print(f"Relevant terms: {', '.join(result['relevant_terms'])}")
        print(f"Text: {result['chunk_text'][:200]}...")

# %%
for q in questions:
    #print("****",q)
    query_searching(q)
    #print(8*".-.", "\n")
# Out:
# Query terms: ['materials', 'dataset']
#
# Hybrid Query Results:
#  ***  * Which materials are in the dataset?
#
# Result 1 (Score: 0.1112):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 2 (Score: 0.1031):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 3 (Score: 0.0236):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['many structures', 'many', 'structures', 'dataset']
#
# Hybrid Query Results:
#  ***  * How many structures are there in the dataset?
#
# Result 1 (Score: 0.1289):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 2 (Score: 0.1206):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 3 (Score: 0.0567):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms: structures
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['obtain', 'dataset']
#
# Hybrid Query Results:
#  ***  * How to obtain the dataset?
#
# Result 1 (Score: 0.0959):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0852):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0407):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['license', 'dataset license', 'dataset']
#
# Hybrid Query Results:
#  ***  * What is the dataset license?
#
# Result 1 (Score: 0.0560):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 2 (Score: 0.0331):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 3 (Score: 0.0213):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: neural, nature, networks, singapore, published, university, graph, materials, graph neural, neural networks, properties, atomic, based, partnership
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
# Query terms: ['format', 'data', 'data format']
#
# Hybrid Query Results:
#  ***  * What is the data format?
#
# Result 1 (Score: 0.1794):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1619):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0989):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['read', 'dataset']
#
# Hybrid Query Results:
#  ***  * How to read the dataset?
#
# Result 1 (Score: 0.1325):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1150):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0452):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: neural, crystals, prediction, networks, crystal, computational, learning, dft, graph, phys, neural networks, graph neural, mater, rev
# Relevant terms:
# Text: Phys. 86, 253 (2014).
# 9. Smith, J. S., Isayev, O. & Roitberg, A. E. Ani-1: an extensible neural network
# potential with dft accuracy at force ﬁeld computational cost. Chem. Sci. 8,
# 3192 –3203 (2017).
# 1...
# Query terms: ['dataset', 'browse']
#
# Hybrid Query Results:
#  ***  * How to browse the dataset?
#
# Result 1 (Score: 0.1120):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 2 (Score: 0.1094):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 3 (Score: 0.0318):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['work', 'dataset without', 'dataset', 'python', 'without python']
#
# Hybrid Query Results:
#  ***  * Can I work with the dataset without Python?
#
# Result 1 (Score: 0.0839):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0799):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0325):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['raw vasp', 'vasp', 'files', 'obtain', 'raw', 'vasp files']
#
# Hybrid Query Results:
#  ***  * How to obtain the raw VASP files?
#
# Result 1 (Score: 0.1266):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1117):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0467):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms: raw
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['used', 'dft computations', 'settings used', 'dft', 'settings', 'computations']
#
# Hybrid Query Results:
#  ***  * What were the settings used for the DFT computations?
#
# Result 1 (Score: 0.1392):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0658):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0585):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['experiment', 'correspond', 'calculations correspond', 'dft calculations', 'dft', 'calculations']
#
# Hybrid Query Results:
#  ***  * How well the DFT calculations correspond to experiment?
#
# Result 1 (Score: 0.1245):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0697):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0515):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['dataset', 'cite']
#
# Hybrid Query Results:
#  ***  * How to cite the dataset?
#
# Result 1 (Score: 0.1469):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1397):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0479):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['quality', 'srgnn', 'procedure', 'evaluation', 'srgnn quality', 'quality evaluation']
#
# Hybrid Query Results:
#  ***  * What was the procedure for SRGNN quality evaluation?
#
# Result 1 (Score: 0.1361):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0934):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0210):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['baselines', 'srgnn', 'srgnn different', 'different']
#
# Hybrid Query Results:
#  ***  * How is SRGNN different from the baselines?
#
# Result 1 (Score: 0.1751):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1251):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0358):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['limitations', 'srgnn']
# Hybrid Query Results:
#  ***  * What are the limitations of SRGNN?
#
# Result 1 (Score: 0.1503):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1152):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0287):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['idea', 'srgnn', 'core idea', 'core']
#
# Hybrid Query Results:
#  ***  * What is the core idea of SRGNN?
#
# Result 1 (Score: 0.1587):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 2 (Score: 0.1499):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 3 (Score: 0.0355):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['code', 'run']
#
# Hybrid Query Results:
#  ***  * How to run the code?
#
# Result 1 (Score: 0.1413):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1156):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0709):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['used', 'frameworks', 'implementation', 'srgnn', 'srgnn implementation']
#
# Hybrid Query Results:
#  ***  * Which frameworks were used for SRGNN implementation?
#
# Result 1 (Score: 0.1539):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0941):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0442):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['cpu', 'srgnn', 'developed', 'gpu']
#
# Hybrid Query Results:
#  ***  * Can SRGNN be developed on a CPU, not a GPU?
#
# Result 1 (Score: 0.1721):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0660):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0293):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['license', 'code', 'code license']
#
# Hybrid Query Results:
#  ***  * What is the code license?
#
# Result 1 (Score: 0.0427):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 2 (Score: 0.0403):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 3 (Score: 0.0294):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
# Query terms: ['code', 'cite']
#
# Hybrid Query Results:
#  ***  * How to cite the code?
#
# Result 1 (Score: 0.1829):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1285):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0826):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['srgnn', 'trained', 'materials']
#
# Hybrid Query Results:
#  ***  * Which materials has the SRGNN been trained on?
#
# Result 1 (Score: 0.1382):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1087):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0249):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms: materials
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['srgnn', 'trained', 'materials']
#
# Hybrid Query Results:
#  ***  * Which materials can the SRGNN be trained on?
#
# Result 1 (Score: 0.1218):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1179):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0208):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['defect', 'srgnn', 'defect types', 'types', 'trained']
#
# Hybrid Query Results:
#  ***  * Which defect types can the SRGNN be trained on?
#
# Result 1 (Score: 0.0767):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms: defect
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0598):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms: defect
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0178):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms: defect
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['training', 'structures', 'many', 'srgnn', 'needed', 'many structures', 'srgnn training']
#
# Hybrid Query Results:
#  ***  * How many structures are needed for SRGNN training?
#
# Result 1 (Score: 0.1322):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1294):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0341):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['srgnn', 'handle', 'srgnn handle', 'materials']
#
# Hybrid Query Results:
#  ***  * Can SRGNN handle 3D materials?
#
# Result 1 (Score: 0.0841):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0671):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0213):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['much', 'srgnn require', 'training', 'resources', 'computational', 'srgnn', 'require', 'much computational', 'computational resources']
#
# Hybrid Query Results:
#  ***  * How much computational resources does SRGNN require for training?
#
# Result 1 (Score: 0.0908):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0597):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0257):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['inference speed', 'inference', 'srgnn', 'speed']
#
# Hybrid Query Results:
#  ***  * What is the inference speed of a SRGNN?
#
# Result 1 (Score: 0.2591):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0947):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0491):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['srgnn', 'predicted', 'using srgnn', 'using', 'properties', 'predicted using']
#
# Hybrid Query Results:
#  ***  * Which properties can be predicted using SRGNN?
#
# Result 1 (Score: 0.1556):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0960):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0386):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['srgnn', 'material', 'quality', 'property']
#
# Hybrid Query Results:
#  ***  * What was the quality of SRGNN for each property and material?
#
# Result 1 (Score: 0.1253):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0933):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0172):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, electron, function, atoms, lattice, energy, defect, fig, wave, wave function, sites, based, levels, vacancy, gap
# Relevant terms:
# Text: competition between the exchange and the direct Coulomb
# interactions of the two-electron state. According to the de ﬁnition
# in Eq. ( 2), the interaction energy is essentially the stabilization
# energy,...
# Query terms: ['used', 'pre trained', 'box', 'pre', 'srgnn', 'trained', 'trained srgnn']
#
# Hybrid Query Results:
#  ***  * Can pre-trained SRGNN be used out-of-the-box?
#
# Result 1 (Score: 0.1414):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1067):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0312):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms: pre
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['experiment', 'correspond', 'srgnn', 'srgnn results', 'results correspond', 'results']
#
# Hybrid Query Results:
#  ***  * How well do SRGNN results correspond to experiment?
#
# Result 1 (Score: 0.1430):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0646):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0242):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms: experiment, results
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
# Query terms: ['use srgnn', 'use', 'srgnn', 'place', 'dft']
#
# Hybrid Query Results:
#  ***  * Can I use SRGNN in place of DFT?
#
# Result 1 (Score: 0.1161):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0855):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0306):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['computers', 'use srgnn', 'srgnn', 'single', 'photodetectors single', 'panels', 'solar', 'emitters', 'find', 'emitters quantum', 'quantum', 'use', 'photon emitters', 'single photon', 'transistors photodetectors', 'materials', 'quantum computers', 'transistors', 'photon', 'find materials', 'solar panels', 'photodetectors', 'panels transistors']
#
# Hybrid Query Results:
#  ***  * How can I use SRGNN to find materials for solar panels/transistors/photodetectors/single photon emitters/quantum computers?
#
# Result 1 (Score: 0.0919):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0764):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0357):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms: materials
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
# Query terms: ['srgnn', 'srgnn patented', 'patented']
#
# Hybrid Query Results:
#  ***  * Is SRGNN patented?
#
# Result 1 (Score: 0.0736):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.0641):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 3 (Score: 0.0188):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
