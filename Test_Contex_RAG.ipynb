# %%
import os, json
#from langchain.chains import AnalyzeDocumentChain
from langchain_openai import ChatOpenAI

from utils import OPENAI_API_KEY

os.environ['OPENAI_API_KEY'] = OPENAI_API_KEY

# %%
from contextual_rag import ContextualRAG

# %%
# Example usage
rag = ContextualRAG()
    
# Process PDF files
chunks, chunk_metadata = rag.upload_files("./data")
# Out:
# Using device: cuda
# Loading embedding model: BAAI/bge-base-en-v1.5
# Loading PDF files from ./data
# Loaded 20 documents
# Created 127 text chunks from 2 documents

# %%
   
# Extract keywords from each chunk
keywords = rag.get_keywords(chunks)
    
# Generate chunk embeddings and token IDs
chunk_embeddings, token_ids_list = rag.get_chunk_emb(chunks)
# Out:
# Extracting keywords: 100%|██████████████████| 127/127 [00:00<00:00, 5533.44it/s]
# Extracted 100 unique keywords across 127 chunks
# Generating chunk embeddings: 100%|████████████| 127/127 [00:06<00:00, 18.55it/s]
# Generated token embeddings for 127 chunks

# %%
keywords[100]
# Out:
# ['wave',
#  'atoms',
#  'electrons',
#  'vacancies',
#  'lattice',
#  'atomic',
#  'states',
#  'site',
#  'vacancy',
#  'wave function',
#  'function',
#  'sites',
#  'homo',
#  'mos',
#  'structure']

# %%
# Generate keyword embeddings with context and document ID
keyword_context_doc_embeddings = rag.get_keyword_emb(
    keywords, chunk_embeddings, token_ids_list, chunks, chunk_metadata
    )
# Out:
# Generating keyword embeddings: 100%|██████████| 127/127 [00:01<00:00, 87.33it/s]
# Generated embeddings for 3067 keyword-context-document pairs
# Average 31.42 contexts per keyword

# %%
keyword_stats = rag.get_all_unique_keywords()
    

    
# Print a summary
print(f"Total unique keywords: {len(keyword_stats)}")
# Out:
# Total unique keywords: 98
#
# Top 10 keywords by document coverage:
# 'con ﬁguration': 2 documents, 21 total occurrences
# 'ﬁguration': 2 documents, 21 total occurrences
# 'properties': 2 documents, 55 total occurrences
# 'defects': 2 documents, 144 total occurrences
# 'con': 2 documents, 37 total occurrences
# 'machine': 2 documents, 42 total occurrences
# 'machine learning': 2 documents, 42 total occurrences
# 'materials': 2 documents, 125 total occurrences
# 'learning': 2 documents, 60 total occurrences
# 'open': 2 documents, 17 total occurrences
# Total unique keywords: 98

# %%
    
# Create vector database
rag.make_db(keyword_context_doc_embeddings, chunks, chunk_metadata)
# Out:
# Created keyword vector database with 3067 entries
# Generating full chunk embeddings: 100%|███████| 127/127 [00:06<00:00, 20.28it/s]
# Generated embeddings for 127 chunks
# Created chunk vector database with 127 entries

# %%
    
# Save the system
rag.save(".data/context_rag_system")
# Out:
# Saved RAG system to .data/context_rag_system

# %%
query = "What is machine learning?"
results = rag.process_query(
        query, 
        top_k=3, 
        keyword_weight=0.7,  # Emphasize keyword matches
        chunk_weight=0.3     # But also consider whole-chunk similarity
    )
    
print("\nHybrid Query Results:")
for i, result in enumerate(results):
    print(f"\nResult {i+1} (Score: {result['score']:.4f}):")
    print(f"Document ID: {result['doc_id']}")
    print(f"Page: {result['page_num']}")
    print(f"Keywords: {', '.join(result['keywords'])}")
    print(f"Relevant terms: {', '.join(result['relevant_terms'])}")
    print(f"Text: {result['chunk_text'][:200]}...")
# Out:
# Query terms: ['machine', 'learning', 'machine learning']
#
# Hybrid Query Results:
#
# Result 1 (Score: 0.2905):
# Document ID: s41699-023-00369-1.pdf
# Page: 0
# Keywords: model, datasets, pristine, database, available, data, defect, learning, dft, material, materials, machine learning, wse, machine, properties
# Relevant terms: machine, learning, machine learning
# Text: materials are notoriously dif ﬁcult to model. Thus, it is very tempting to apply machine learning methods to such systems.
# Unfortunately, there is only a handful of machine learning-friendly material ...
#
# Result 2 (Score: 0.2902):
# Document ID: s41699-023-00369-1.pdf
# Page: 0
# Keywords: defects, model, high, huang, datasets, property, learning, structure, materials, methods, machine learning, machine, based, open, properties
# Relevant terms: machine, learning, machine learning
# Text: ARTICLE OPEN
# Unveiling the complex structure-property correlation of defects
# in 2D materials based on high throughput datasets
# Pengru Huang1, Ruslan Lukin2, Maxim Faleev2, Nikita Kazeev1,3, Abdalaziz ...
#
# Result 3 (Score: 0.2901):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: machine, learning, machine learning
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...

# %%
def query_searching(query):
    # Example query - search across all documents
    
    results = rag.process_query(
        query, 
        top_k=3, 
        keyword_weight=0.8,  # Emphasize keyword matches
        chunk_weight=0.2     # But also consider whole-chunk similarity
    )
    
    print(f"\nHybrid Query Results: \n ***  {query}")
    for i, result in enumerate(results):
        print(f"\nResult {i+1} (Score: {result['score']:.4f}):")
        print(f"Document ID: {result['doc_id']}")
        print(f"Page: {result['page_num']}")
        print(f"Keywords: {', '.join(result['keywords'])}")
        print(f"Relevant terms: {', '.join(result['relevant_terms'])}")
        print(f"Text: {result['chunk_text'][:200]}...")

# %%
import pandas as pd

df_ground_true = pd.read_csv("../data/data_rag/QA_ai4mat_2articles.csv")

questions = df_ground_true['question'].values.tolist()
answers = df_ground_true['answer'].values.tolist()

# %%
for q in questions:
    #print("****",q)
    query_searching(q)
    #print(8*".-.", "\n")
# Out:
# Query terms: ['materials', 'dataset']
#
# Hybrid Query Results:
#  ***  * Which materials are in the dataset?
#
# Result 1 (Score: 0.1973):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms: materials
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 2 (Score: 0.1971):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: materials, dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 3 (Score: 0.1969):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset, materials
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
# Query terms: ['many structures', 'many', 'structures', 'dataset']
#
# Hybrid Query Results:
#  ***  * How many structures are there in the dataset?
#
# Result 1 (Score: 0.1955):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 2 (Score: 0.1953):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: structures, dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.1952):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
# Query terms: ['obtain', 'dataset']
#
# Hybrid Query Results:
#  ***  * How to obtain the dataset?
#
# Result 1 (Score: 0.1927):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.1926):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.1925):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['license', 'dataset license', 'dataset']
#
# Hybrid Query Results:
#  ***  * What is the dataset license?
#
# Result 1 (Score: 0.1915):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 2 (Score: 0.1914):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: density, high, structures, using, sparse representation, representation, defect, dataset, number, use, megnet, sparse, low, combined
# Relevant terms: dataset
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
# Result 3 (Score: 0.1907):
# Document ID: s41699-023-00369-1.pdf
# Page: 0
# Keywords: model, datasets, pristine, database, available, data, defect, learning, dft, material, materials, machine learning, wse, machine, properties
# Relevant terms: dataset
# Text: materials are notoriously dif ﬁcult to model. Thus, it is very tempting to apply machine learning methods to such systems.
# Unfortunately, there is only a handful of machine learning-friendly material ...
# Query terms: ['format', 'data', 'data format']
#
# Hybrid Query Results:
#  ***  * What is the data format?
#
# Result 1 (Score: 0.1926):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: data, format
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 2 (Score: 0.1924):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms: format
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 3 (Score: 0.1920):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: data, format
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
# Query terms: ['read', 'dataset']
#
# Hybrid Query Results:
#  ***  * How to read the dataset?
#
# Result 1 (Score: 0.1929):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 2 (Score: 0.1928):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: density, high, structures, using, sparse representation, representation, defect, dataset, number, use, megnet, sparse, low, combined
# Relevant terms: dataset
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
# Result 3 (Score: 0.1928):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['dataset', 'browse']
#
# Hybrid Query Results:
#  ***  * How to browse the dataset?
#
# Result 1 (Score: 0.1927):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.1926):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.1925):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['work', 'dataset without', 'dataset', 'python', 'without python']
#
# Hybrid Query Results:
#  ***  * Can I work with the dataset without Python?
#
# Result 1 (Score: 0.1955):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms: work, dataset
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 (Score: 0.1951):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: density, used, nature, structures, con ﬁgurations, data, lumo, defect, energy, formation energy, dft, dataset, use, formation, gap
# Relevant terms: dataset
# Text: Fig. 3. We used pymatgen35toﬁnd the con ﬁgurations, taking
# into account symmetry. The high-density dataset contains asample of randomly generated substitution and vacancy defects
# for all the materials...
#
# Result 3 (Score: 0.1951):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
# Query terms: ['raw vasp', 'vasp', 'files', 'obtain', 'raw', 'vasp files']
#
# Hybrid Query Results:
#  ***  * How to obtain the raw VASP files?
#
# Result 1 (Score: 0.1931):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 (Score: 0.1929):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 3 (Score: 0.1929):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, used, quantum, prediction, sparse representation, con ﬁgurations, representation, data, ﬁgurations, dataset, use, sparse, low, vacancy
# Relevant terms:
# Text: a GPU, and costs 7.5 CPU core-minutes per structure and 1860
# core-hours for the whole 2DMD dataset. Model con ﬁgurations are
# listed in Supplementary Discussion 1.
# Quantum oscillations prediction
# In ad...
# Query terms: ['used', 'dft computations', 'settings used', 'dft', 'settings', 'computations']
#
# Hybrid Query Results:
#  ***  * What were the settings used for the DFT computations?
#
# Result 1 (Score: 0.1957):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, con ﬁguration, ﬁguration, full, sparse representation, representation, use, formation energy, energy, megnet, con, sparse, formation
# Relevant terms:
# Text: sparse representation succeeds perfectly, including the non-
# monotonous reduction at 5 Å.
# As shown in the Supplementary Discussion 3, the result is
# similar for untuned hyperparameters.
# Ablation study
# ...
#
# Result 2 (Score: 0.1957):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, used, quantum, prediction, sparse representation, con ﬁgurations, representation, data, ﬁgurations, dataset, use, sparse, low, vacancy
# Relevant terms: used
# Text: a GPU, and costs 7.5 CPU core-minutes per structure and 1860
# core-hours for the whole 2DMD dataset. Model con ﬁgurations are
# listed in Supplementary Discussion 1.
# Quantum oscillations prediction
# In ad...
#
# Result 3 (Score: 0.1955):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms: dft computations, dft, computations
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
# Query terms: ['experiment', 'correspond', 'calculations correspond', 'dft calculations', 'dft', 'calculations']
#
# Hybrid Query Results:
#  ***  * How well the DFT calculations correspond to experiment?
#
# Result 1 (Score: 0.2083):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: high, used, electrons, interaction, structures, atoms, defect, energy, space, structure, electronic, calculations, atomic
# Relevant terms: calculations
# Text: only Monkhorst-Pack grid for structural relaxation and denser grids
# for further electronic structure calculations. A vacuum space of atleast 15 Åwas used to avoid interaction between neighboring
# layer...
#
# Result 2 (Score: 0.1973):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: defects, pristine, homo, lumo, defect, formation energy, number, energy, use, dft, sites, electronic, structure, formation, gap
# Relevant terms: dft
# Text: We use two target variables for evaluating machine learning
# methods: defect formation energy per site and HOMO –LUMO gap.
# Formation energy, i.e., the energy required to create a defect is
# deﬁned as
# E
# ...
#
# Result 3 (Score: 0.1972):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: huang, quantum, npj, con ﬁgurations, ﬁgurations, published, site, lattice, dataset, space, large, materials, electronic, partnership
# Relevant terms:
# Text: the lattice site and distance are observed and explained in depththrough symmetry and quantum mechanics electronic structure
# analysis. The dispersive dataset was created to span over as large
# as possi...
# Query terms: ['dataset', 'cite']
#
# Hybrid Query Results:
#  ***  * How to cite the dataset?
#
# Result 1 (Score: 0.1930):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 2 (Score: 0.1925):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.1924):
# Document ID: s41699-023-00369-1.pdf
# Page: 8
# Keywords: high, crystals, prediction, networks, npj, database, dft, graph, materials, phys, neural networks, mater, open, rev
# Relevant terms:
# Text: accelerating materials innovation. APL Mater. 1, 011002 (2013).
# 7. Kirklin, S. et al. The open quantum materials database (OQMD): assessing the
# accuracy of DFT formation energies. npj Comput. Mater. 1...
# Query terms: ['quality', 'srgnn', 'procedure', 'evaluation', 'srgnn quality', 'quality evaluation']
#
# Hybrid Query Results:
#  ***  * What was the procedure for SRGNN quality evaluation?
#
# Result 1 (Score: 0.2013):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 (Score: 0.1933):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: model, information, used, sparse representation, representation, graph, material, sparse, based, state
# Relevant terms:
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
#
# Result 3 (Score: 0.1929):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: ﬁguration, con ﬁguration, function, band, defect, energy, fig, large, wave function, vacancies, wave, sites, con, levels, states
# Relevant terms:
# Text: vacancies is smaller than that of the third con ﬁguration, the two
# vacancies occupy lattice sites where there is a knot of their wavefunctions. The wave functions of the HOMO retain that of the
# isolat...
# Query terms: ['baselines', 'srgnn', 'srgnn different', 'different']
#
# Hybrid Query Results:
#  ***  * How is SRGNN different from the baselines?
#
# Result 1 (Score: 0.1961):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 (Score: 0.1960):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 3 (Score: 0.1958):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: defects, pristine, homo, lumo, defect, formation energy, number, energy, use, dft, sites, electronic, structure, formation, gap
# Relevant terms: different
# Text: We use two target variables for evaluating machine learning
# methods: defect formation energy per site and HOMO –LUMO gap.
# Formation energy, i.e., the energy required to create a defect is
# deﬁned as
# E
# ...
# Query terms: ['limitations', 'srgnn']
#
# Hybrid Query Results:
#  ***  * What are the limitations of SRGNN?
#
# Result 1 (Score: 0.2084):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: neural, nature, networks, singapore, published, university, graph, materials, graph neural, neural networks, properties, atomic, based, partnership
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.1951):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, prediction, quantum, full, sparse representation, con ﬁgurations, representation, ﬁgurations, dataset, megnet, wse, sparse, low, combined
# Relevant terms:
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
# Result 3 (Score: 0.1950):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: model, information, used, sparse representation, representation, graph, material, sparse, based, state
# Relevant terms:
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
# Query terms: ['idea', 'srgnn', 'core idea', 'core']
#
# Hybrid Query Results:
#  ***  * What is the core idea of SRGNN?
#
# Result 1 (Score: 0.3209):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 2 (Score: 0.2228):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
#
# Result 3 (Score: 0.1949):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, supplementary, high, electrons, networks, available, electronic, single, graph, graph neural, neural networks, low, calculations, state, states
# Relevant terms:
# Text: structures with unpaired electrons, we utilize standard collinearspin-polarized calculations with magnetic ions in a high-spin
# ferromagnetic initialization (the ion moments can of course relax to
# a lo...
# Query terms: ['code', 'run']
#
# Hybrid Query Results:
#  ***  * How to run the code?
#
# Result 1 (Score: 0.2842):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 2 (Score: 0.1928):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 3 (Score: 0.1927):
# Document ID: s41699-023-00369-1.pdf
# Page: 4
# Keywords: supplementary, range, huang, npj, homo, published, lumo, defect, number, large, sites, atomic, vacancy, partnership
# Relevant terms: code
# Text: difference. The total spin of the carbon-impurity complexes in hBN
# is governed by the difference between the carbon substitutions atthe two sublattices according to Lieb ’s theorem
# 26,27.
# S¼NCNðÞ/C0NC...
# Query terms: ['used', 'frameworks', 'implementation', 'srgnn', 'srgnn implementation']
#
# Hybrid Query Results:
#  ***  * Which frameworks were used for SRGNN implementation?
#
# Result 1 (Score: 0.2090):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: high, used, electrons, interaction, structures, atoms, defect, energy, space, structure, electronic, calculations, atomic
# Relevant terms: used
# Text: only Monkhorst-Pack grid for structural relaxation and denser grids
# for further electronic structure calculations. A vacuum space of atleast 15 Åwas used to avoid interaction between neighboring
# layer...
#
# Result 2 (Score: 0.1938):
# Document ID: s41699-023-00369-1.pdf
# Page: 7
# Keywords: supplementary, used, electrons, interaction, structures, database, defect, space, large, materials, electronic, low, calculations, using, point
# Relevant terms: used
# Text: calculations. The initial crystal structures were obtained from
# the Material Project database and the supercell sizes and thecomputational parameters for each materials are listed in the
# supplemental ...
#
# Result 3 (Score: 0.1936):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, supplementary, high, electrons, networks, available, electronic, single, graph, graph neural, neural networks, low, calculations, state, states
# Relevant terms:
# Text: structures with unpaired electrons, we utilize standard collinearspin-polarized calculations with magnetic ions in a high-spin
# ferromagnetic initialization (the ion moments can of course relax to
# a lo...
# Query terms: ['cpu', 'srgnn', 'developed', 'gpu']
#
# Hybrid Query Results:
#  ***  * Can SRGNN be developed on a CPU, not a GPU?
#
# Result 1 (Score: 0.1943):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: high, used, structures, sparse representation, representation, singapore, eos, computational, megnet, sparse, using
# Relevant terms:
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
#
# Result 2 (Score: 0.1932):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: singapore, number, university, computational, materials
# Relevant terms:
# Text: ACKNOWLEDGEMENTS
# This research/project is supported by the Ministry of Education, Singapore, under its
# Research Centre of Excellence award to the Institute for Functional Intelligent Materials
# (I-FIM,...
#
# Result 3 (Score: 0.1932):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: model, information, used, sparse representation, representation, graph, material, sparse, based, state
# Relevant terms:
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
# Query terms: ['license', 'code', 'code license']
#
# Hybrid Query Results:
#  ***  * What is the code license?
#
# Result 1 (Score: 0.1926):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: density, high, structures, using, sparse representation, representation, defect, dataset, number, use, megnet, sparse, low, combined
# Relevant terms:
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
# Result 2 (Score: 0.1917):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms:
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 3 (Score: 0.1917):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: density, used, nature, structures, con ﬁgurations, data, lumo, defect, energy, formation energy, dft, dataset, use, formation, gap
# Relevant terms:
# Text: Fig. 3. We used pymatgen35toﬁnd the con ﬁgurations, taking
# into account symmetry. The high-density dataset contains asample of randomly generated substitution and vacancy defects
# for all the materials...
# Query terms: ['code', 'cite']
#
# Hybrid Query Results:
#  ***  * How to cite the code?
#
# Result 1 (Score: 0.3397):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1947):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: neural, huang, networks, npj, using, https, property, large, graph, graph neural, neural networks, phys, mater, rev
# Relevant terms:
# Text: graphs. Published at the International Conference on Learning Representations(ICLR) 2020. Preprint at https://arXiv.org/abs/2003.03123 (2020).
# 18. Shuaibi, M. et al. Rotation invariant graph neural ne...
#
# Result 3 (Score: 0.1942):
# Document ID: s41699-023-00369-1.pdf
# Page: 4
# Keywords: supplementary, range, huang, npj, homo, published, lumo, defect, number, large, sites, atomic, vacancy, partnership
# Relevant terms: code
# Text: difference. The total spin of the carbon-impurity complexes in hBN
# is governed by the difference between the carbon substitutions atthe two sublattices according to Lieb ’s theorem
# 26,27.
# S¼NCNðÞ/C0NC...
# Query terms: ['srgnn', 'trained', 'materials']
#
# Hybrid Query Results:
#  ***  * Which materials has the SRGNN been trained on?
#
# Result 1 (Score: 0.1957):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: model, prediction, full, npj, sparse representation, representation, lumo, defect, megnet, vacancies, wse, low, combined, partnership
# Relevant terms: materials
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 2 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, ﬁguration, con ﬁguration, function, npj, atoms, crystal, property, published, computational, dft, large, graph, partnership
# Relevant terms: trained, materials
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
# Result 3 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: defects, pristine, homo, lumo, defect, formation energy, number, energy, use, dft, sites, electronic, structure, formation, gap
# Relevant terms:
# Text: We use two target variables for evaluating machine learning
# methods: defect formation energy per site and HOMO –LUMO gap.
# Formation energy, i.e., the energy required to create a defect is
# deﬁned as
# E
# ...
# Query terms: ['srgnn', 'trained', 'materials']
#
# Hybrid Query Results:
#  ***  * Which materials can the SRGNN be trained on?
#
# Result 1 (Score: 0.1949):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, atoms, crystal, number, graph, structure, state, states
# Relevant terms:
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
# Result 2 (Score: 0.1949):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: neural, range, interaction, using, defect, energy, learning, wave, materials, phys, mater, calculations, open, rev
# Relevant terms: materials
# Text: (2018).
# 33. Banik, S. et al. Learning with delayed rewards –A case study on inverse defect
# design in 2d materials. ACS Appl. Mater. Interfaces 13, 36455 –36464 (2021).
# 34. Shytov, A. V., Abanin, D. A....
#
# Result 3 (Score: 0.1949):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: ﬁguration, con ﬁguration, function, band, defect, energy, fig, large, wave function, vacancies, wave, sites, con, levels, states
# Relevant terms:
# Text: vacancies is smaller than that of the third con ﬁguration, the two
# vacancies occupy lattice sites where there is a knot of their wavefunctions. The wave functions of the HOMO retain that of the
# isolat...
# Query terms: ['defect', 'srgnn', 'defect types', 'types', 'trained']
#
# Hybrid Query Results:
#  ***  * Which defect types can the SRGNN be trained on?
#
# Result 1 (Score: 0.1958):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms: defect
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 (Score: 0.1938):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: high, used, structures, sparse representation, representation, singapore, eos, computational, megnet, sparse, using
# Relevant terms: defect
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
#
# Result 3 (Score: 0.1936):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, atoms, crystal, number, graph, structure, state, states
# Relevant terms:
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
# Query terms: ['training', 'structures', 'many', 'srgnn', 'needed', 'many structures', 'srgnn training']
#
# Hybrid Query Results:
#  ***  * How many structures are needed for SRGNN training?
#
# Result 1 (Score: 0.2068):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms: structures
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, ﬁguration, con ﬁguration, function, npj, atoms, crystal, property, published, computational, dft, large, graph, partnership
# Relevant terms: training
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
# Result 3 (Score: 0.1954):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: high, used, electrons, interaction, structures, atoms, defect, energy, space, structure, electronic, calculations, atomic
# Relevant terms: structures
# Text: only Monkhorst-Pack grid for structural relaxation and denser grids
# for further electronic structure calculations. A vacuum space of atleast 15 Åwas used to avoid interaction between neighboring
# layer...
# Query terms: ['srgnn', 'handle', 'srgnn handle', 'materials']
#
# Hybrid Query Results:
#  ***  * Can SRGNN handle 3D materials?
#
# Result 1 (Score: 0.1968):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: model, prediction, full, npj, sparse representation, representation, lumo, defect, megnet, vacancies, wse, low, combined, partnership
# Relevant terms: materials
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 2 (Score: 0.1965):
# Document ID: s41524-023-01062-z.pdf
# Page: 5
# Keywords: defects, crystals, combined, full, sparse representation, representation, learning, megnet, vacancies, machine learning, sparse, graph neural, machine, using, properties
# Relevant terms:
# Text: possible con ﬁgurations is vast. Thus, the ability to predict the
# properties of such crystals ef ﬁciently becomes a vital task. In this
# paper, we focus on predicting the properties of such crystals
# bl...
#
# Result 3 (Score: 0.1965):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, ﬁguration, con ﬁguration, function, npj, atoms, crystal, property, published, computational, dft, large, graph, partnership
# Relevant terms: materials
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
# Query terms: ['much', 'srgnn require', 'training', 'resources', 'computational', 'srgnn', 'require', 'much computational', 'computational resources']
#
# Hybrid Query Results:
#  ***  * How much computational resources does SRGNN require for training?
#
# Result 1 (Score: 0.1955):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, prediction, quantum, full, sparse representation, con ﬁgurations, representation, ﬁgurations, dataset, megnet, wse, sparse, low, combined
# Relevant terms:
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
# Result 2 (Score: 0.1952):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms: training
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 3 (Score: 0.1951):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, used, quantum, prediction, sparse representation, con ﬁgurations, representation, data, ﬁgurations, dataset, use, sparse, low, vacancy
# Relevant terms: training
# Text: a GPU, and costs 7.5 CPU core-minutes per structure and 1860
# core-hours for the whole 2DMD dataset. Model con ﬁgurations are
# listed in Supplementary Discussion 1.
# Quantum oscillations prediction
# In ad...
# Query terms: ['inference speed', 'inference', 'srgnn', 'speed']
#
# Hybrid Query Results:
#  ***  * What is the inference speed of a SRGNN?
#
# Result 1 (Score: 0.2073):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 3 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
# Query terms: ['srgnn', 'predicted', 'using srgnn', 'using', 'properties', 'predicted using']
#
# Hybrid Query Results:
#  ***  * Which properties can be predicted using SRGNN?
#
# Result 1 (Score: 0.1969):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: neural, nature, networks, singapore, published, university, graph, materials, graph neural, neural networks, properties, atomic, based, partnership
# Relevant terms: properties
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.1967):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, defects, pristine, structures, full, sparse representation, available, defect, dataset, space, number, fig, sparse, low
# Relevant terms:
# Text: For formation energy, just enabling the zcoordinate difference
# in sparse representation edges allows the Sparse-Z model to
# outperform the Full model everywhere except h-BN; adding
# pristine atom specie...
#
# Result 3 (Score: 0.1965):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, ﬁguration, con ﬁguration, function, npj, atoms, crystal, property, published, computational, dft, large, graph, partnership
# Relevant terms: predicted
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
# Query terms: ['srgnn', 'material', 'quality', 'property']
#
# Hybrid Query Results:
#  ***  * What was the quality of SRGNN for each property and material?
#
# Result 1 (Score: 0.2035):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms: material
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 (Score: 0.1953):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: ﬁguration, con ﬁguration, function, band, defect, energy, fig, large, wave function, vacancies, wave, sites, con, levels, states
# Relevant terms:
# Text: vacancies is smaller than that of the third con ﬁguration, the two
# vacancies occupy lattice sites where there is a knot of their wavefunctions. The wave functions of the HOMO retain that of the
# isolat...
#
# Result 3 (Score: 0.1952):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: high, used, structures, sparse representation, representation, singapore, eos, computational, megnet, sparse, using
# Relevant terms:
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
# Query terms: ['used', 'pre trained', 'box', 'pre', 'srgnn', 'trained', 'trained srgnn']
#
# Hybrid Query Results:
#  ***  * Can pre-trained SRGNN be used out-of-the-box?
#
# Result 1 (Score: 0.2118):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: neural, nature, networks, singapore, published, university, graph, materials, graph neural, neural networks, properties, atomic, based, partnership
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.1957):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms: pre, trained
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 3 (Score: 0.1950):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, prediction, quantum, full, sparse representation, con ﬁgurations, representation, ﬁgurations, dataset, megnet, wse, sparse, low, combined
# Relevant terms: pre, trained
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
# Query terms: ['experiment', 'correspond', 'srgnn', 'srgnn results', 'results correspond', 'results']
#
# Hybrid Query Results:
#  ***  * How well do SRGNN results correspond to experiment?
#
# Result 1 (Score: 0.2060):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: neural, nature, networks, singapore, published, university, graph, materials, graph neural, neural networks, properties, atomic, based, partnership
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.1958):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: neural, range, interaction, using, defect, energy, learning, wave, materials, phys, mater, calculations, open, rev
# Relevant terms:
# Text: (2018).
# 33. Banik, S. et al. Learning with delayed rewards –A case study on inverse defect
# design in 2d materials. ACS Appl. Mater. Interfaces 13, 36455 –36464 (2021).
# 34. Shytov, A. V., Abanin, D. A....
#
# Result 3 (Score: 0.1957):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, prediction, quantum, full, sparse representation, con ﬁgurations, representation, ﬁgurations, dataset, megnet, wse, sparse, low, combined
# Relevant terms:
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
# Query terms: ['use srgnn', 'use', 'srgnn', 'place', 'dft']
#
# Hybrid Query Results:
#  ***  * Can I use SRGNN in place of DFT?
#
# Result 1 (Score: 0.2066):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: high, used, electrons, interaction, structures, atoms, defect, energy, space, structure, electronic, calculations, atomic
# Relevant terms: use
# Text: only Monkhorst-Pack grid for structural relaxation and denser grids
# for further electronic structure calculations. A vacuum space of atleast 15 Åwas used to avoid interaction between neighboring
# layer...
#
# Result 2 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms: dft
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 3 (Score: 0.1953):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
# Query terms: ['computers', 'use srgnn', 'srgnn', 'single', 'photodetectors single', 'panels', 'solar', 'emitters', 'find', 'emitters quantum', 'quantum', 'use', 'photon emitters', 'single photon', 'transistors photodetectors', 'materials', 'quantum computers', 'transistors', 'photon', 'find materials', 'solar panels', 'photodetectors', 'panels transistors']
#
# Hybrid Query Results:
#  ***  * How can I use SRGNN to find materials for solar panels/transistors/photodetectors/single photon emitters/quantum computers?
#
# Result 1 (Score: 0.1971):
# Document ID: s41524-023-01062-z.pdf
# Page: 1
# Keywords: defects, used, structures, pristine, use, dft, point defects, megnet, large, materials, single, based, properties, point
# Relevant terms: use, materials, single
# Text: different materials, but the authors didn ’t consider con ﬁgurations
# with multiple interacting defects. In a recent preprint27, the
# authors use a model based on CGCNN12to conduct a large scale
# screeni...
#
# Result 2 (Score: 0.1970):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: range, datasets, con ﬁgurations, ﬁgurations, data, defect, space, learning, mos, large, dft, wse, materials, atomic, properties
# Relevant terms: materials
# Text: small subspace of the whole defect space. The other group of
# dispersive datasets aims to spread data in the large defect space.This is done here by calculating the properties of a wide
# concentration r...
#
# Result 3 (Score: 0.1970):
# Document ID: s41699-023-00369-1.pdf
# Page: 8
# Keywords: high, crystals, prediction, networks, npj, database, dft, graph, materials, phys, neural networks, mater, open, rev
# Relevant terms: materials, quantum
# Text: accelerating materials innovation. APL Mater. 1, 011002 (2013).
# 7. Kirklin, S. et al. The open quantum materials database (OQMD): assessing the
# accuracy of DFT formation energies. npj Comput. Mater. 1...
# Query terms: ['srgnn', 'srgnn patented', 'patented']
#
# Hybrid Query Results:
#  ***  * Is SRGNN patented?
#
# Result 1 (Score: 0.1939):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, defects, pristine, structures, full, sparse representation, available, defect, dataset, space, number, fig, sparse, low
# Relevant terms:
# Text: For formation energy, just enabling the zcoordinate difference
# in sparse representation edges allows the Sparse-Z model to
# outperform the Full model everywhere except h-BN; adding
# pristine atom specie...
#
# Result 2 (Score: 0.1938):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: model, prediction, full, npj, sparse representation, representation, lumo, defect, megnet, vacancies, wse, low, combined, partnership
# Relevant terms:
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 3 (Score: 0.1938):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: defects, interaction, quantum, function, con ﬁgurations, ﬁgurations, lumo, defect, energy, number, single, vacancies, sites, vacancy, properties
# Relevant terms:
# Text: single-photon emitters aiming at the identi ﬁcation and engineer-
# ing of candidate emitting centers in 2D hosts instead of that in
# bulk materials such as the NV center in diamond27,28.
# The quantum ﬂuc...

# %%
def query_searching(query):
    # Example query - search across all documents
    
    results = rag.process_query(
        query, 
        top_k=3, 
        mode: str = 'keyword',
        keyword_weight=0.8,  # Emphasize keyword matches
        chunk_weight=0.2     # But also consider whole-chunk similarity
    )
    
    print(f"\nHybrid Query Results: \n ***  {query}")
    for i, result in enumerate(results):
        print(f"\nResult {i+1} (Score: {result['score']:.4f}):")
        print(f"Document ID: {result['doc_id']}")
        print(f"Page: {result['page_num']}")
        print(f"Keywords: {', '.join(result['keywords'])}")
        print(f"Relevant terms: {', '.join(result['relevant_terms'])}")
        print(f"Text: {result['chunk_text'][:200]}...")

# %%
for q in questions:
    #print("****",q)
    query_searching(q)
    #print(8*".-.", "\n")
# Out:
# Query terms: ['materials', 'dataset']
#
# Hybrid Query Results:
#  ***  * Which materials are in the dataset?
#
# Result 1 (Score: 0.1973):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms: materials
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 2 (Score: 0.1971):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: materials, dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 3 (Score: 0.1969):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset, materials
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
# Query terms: ['many structures', 'many', 'structures', 'dataset']
#
# Hybrid Query Results:
#  ***  * How many structures are there in the dataset?
#
# Result 1 (Score: 0.1955):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 2 (Score: 0.1953):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: structures, dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.1952):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
# Query terms: ['obtain', 'dataset']
#
# Hybrid Query Results:
#  ***  * How to obtain the dataset?
#
# Result 1 (Score: 0.1927):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.1926):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.1925):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['license', 'dataset license', 'dataset']
#
# Hybrid Query Results:
#  ***  * What is the dataset license?
#
# Result 1 (Score: 0.1915):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 2 (Score: 0.1914):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: density, high, structures, using, sparse representation, representation, defect, dataset, number, use, megnet, sparse, low, combined
# Relevant terms: dataset
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
# Result 3 (Score: 0.1907):
# Document ID: s41699-023-00369-1.pdf
# Page: 0
# Keywords: model, datasets, pristine, database, available, data, defect, learning, dft, material, materials, machine learning, wse, machine, properties
# Relevant terms: dataset
# Text: materials are notoriously dif ﬁcult to model. Thus, it is very tempting to apply machine learning methods to such systems.
# Unfortunately, there is only a handful of machine learning-friendly material ...
# Query terms: ['format', 'data', 'data format']
#
# Hybrid Query Results:
#  ***  * What is the data format?
#
# Result 1 (Score: 0.1926):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: data, format
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 2 (Score: 0.1924):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms: format
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 3 (Score: 0.1920):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: data, format
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
# Query terms: ['read', 'dataset']
#
# Hybrid Query Results:
#  ***  * How to read the dataset?
#
# Result 1 (Score: 0.1929):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 2 (Score: 0.1928):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: density, high, structures, using, sparse representation, representation, defect, dataset, number, use, megnet, sparse, low, combined
# Relevant terms: dataset
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
# Result 3 (Score: 0.1928):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['dataset', 'browse']
#
# Hybrid Query Results:
#  ***  * How to browse the dataset?
#
# Result 1 (Score: 0.1927):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 2 (Score: 0.1926):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.1925):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
# Query terms: ['work', 'dataset without', 'dataset', 'python', 'without python']
#
# Hybrid Query Results:
#  ***  * Can I work with the dataset without Python?
#
# Result 1 (Score: 0.1955):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms: work, dataset
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 (Score: 0.1951):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: density, used, nature, structures, con ﬁgurations, data, lumo, defect, energy, formation energy, dft, dataset, use, formation, gap
# Relevant terms: dataset
# Text: Fig. 3. We used pymatgen35toﬁnd the con ﬁgurations, taking
# into account symmetry. The high-density dataset contains asample of randomly generated substitution and vacancy defects
# for all the materials...
#
# Result 3 (Score: 0.1951):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms: dataset
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
# Query terms: ['raw vasp', 'vasp', 'files', 'obtain', 'raw', 'vasp files']
#
# Hybrid Query Results:
#  ***  * How to obtain the raw VASP files?
#
# Result 1 (Score: 0.1931):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 (Score: 0.1929):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 3 (Score: 0.1929):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, used, quantum, prediction, sparse representation, con ﬁgurations, representation, data, ﬁgurations, dataset, use, sparse, low, vacancy
# Relevant terms:
# Text: a GPU, and costs 7.5 CPU core-minutes per structure and 1860
# core-hours for the whole 2DMD dataset. Model con ﬁgurations are
# listed in Supplementary Discussion 1.
# Quantum oscillations prediction
# In ad...
# Query terms: ['used', 'dft computations', 'settings used', 'dft', 'settings', 'computations']
#
# Hybrid Query Results:
#  ***  * What were the settings used for the DFT computations?
#
# Result 1 (Score: 0.1957):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, con ﬁguration, ﬁguration, full, sparse representation, representation, use, formation energy, energy, megnet, con, sparse, formation
# Relevant terms:
# Text: sparse representation succeeds perfectly, including the non-
# monotonous reduction at 5 Å.
# As shown in the Supplementary Discussion 3, the result is
# similar for untuned hyperparameters.
# Ablation study
# ...
#
# Result 2 (Score: 0.1957):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, used, quantum, prediction, sparse representation, con ﬁgurations, representation, data, ﬁgurations, dataset, use, sparse, low, vacancy
# Relevant terms: used
# Text: a GPU, and costs 7.5 CPU core-minutes per structure and 1860
# core-hours for the whole 2DMD dataset. Model con ﬁgurations are
# listed in Supplementary Discussion 1.
# Quantum oscillations prediction
# In ad...
#
# Result 3 (Score: 0.1955):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms: dft computations, dft, computations
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
# Query terms: ['experiment', 'correspond', 'calculations correspond', 'dft calculations', 'dft', 'calculations']
#
# Hybrid Query Results:
#  ***  * How well the DFT calculations correspond to experiment?
#
# Result 1 (Score: 0.2083):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: high, used, electrons, interaction, structures, atoms, defect, energy, space, structure, electronic, calculations, atomic
# Relevant terms: calculations
# Text: only Monkhorst-Pack grid for structural relaxation and denser grids
# for further electronic structure calculations. A vacuum space of atleast 15 Åwas used to avoid interaction between neighboring
# layer...
#
# Result 2 (Score: 0.1973):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: defects, pristine, homo, lumo, defect, formation energy, number, energy, use, dft, sites, electronic, structure, formation, gap
# Relevant terms: dft
# Text: We use two target variables for evaluating machine learning
# methods: defect formation energy per site and HOMO –LUMO gap.
# Formation energy, i.e., the energy required to create a defect is
# deﬁned as
# E
# ...
#
# Result 3 (Score: 0.1972):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: huang, quantum, npj, con ﬁgurations, ﬁgurations, published, site, lattice, dataset, space, large, materials, electronic, partnership
# Relevant terms:
# Text: the lattice site and distance are observed and explained in depththrough symmetry and quantum mechanics electronic structure
# analysis. The dispersive dataset was created to span over as large
# as possi...
# Query terms: ['dataset', 'cite']
#
# Hybrid Query Results:
#  ***  * How to cite the dataset?
#
# Result 1 (Score: 0.1930):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: density, ﬁguration, information, con ﬁguration, used, learning, materials, machine, machine learning, phys, mater, structure, open, rev
# Relevant terms:
# Text: processing in the mineral world. Mineral. Mag. 77, 275 –326 (2013).
# 44. Ong, S. P. et al. Python Materials Genomics (pymatgen): A robust, open-source
# python library for materials analysis. Comput. Mat...
#
# Result 2 (Score: 0.1925):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, range, structures, band, available, defect, formation energy, energy, mos, vacancies, wse, levels, atomic, formation, properties
# Relevant terms: dataset
# Text: of 5933 defect con ﬁgurations for MoS 2and another 5933
# conﬁgurations for WSe 2. The compositions, numbers, atomic
# structures, and the variation range of properties of each type of
# defect for MoS 2are...
#
# Result 3 (Score: 0.1924):
# Document ID: s41699-023-00369-1.pdf
# Page: 8
# Keywords: high, crystals, prediction, networks, npj, database, dft, graph, materials, phys, neural networks, mater, open, rev
# Relevant terms:
# Text: accelerating materials innovation. APL Mater. 1, 011002 (2013).
# 7. Kirklin, S. et al. The open quantum materials database (OQMD): assessing the
# accuracy of DFT formation energies. npj Comput. Mater. 1...
# Query terms: ['quality', 'srgnn', 'procedure', 'evaluation', 'srgnn quality', 'quality evaluation']
#
# Hybrid Query Results:
#  ***  * What was the procedure for SRGNN quality evaluation?
#
# Result 1 (Score: 0.2013):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms:
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 (Score: 0.1933):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: model, information, used, sparse representation, representation, graph, material, sparse, based, state
# Relevant terms:
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
#
# Result 3 (Score: 0.1929):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: ﬁguration, con ﬁguration, function, band, defect, energy, fig, large, wave function, vacancies, wave, sites, con, levels, states
# Relevant terms:
# Text: vacancies is smaller than that of the third con ﬁguration, the two
# vacancies occupy lattice sites where there is a knot of their wavefunctions. The wave functions of the HOMO retain that of the
# isolat...
# Query terms: ['baselines', 'srgnn', 'srgnn different', 'different']
#
# Hybrid Query Results:
#  ***  * How is SRGNN different from the baselines?
#
# Result 1 (Score: 0.1961):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 2 (Score: 0.1960):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 3 (Score: 0.1958):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: defects, pristine, homo, lumo, defect, formation energy, number, energy, use, dft, sites, electronic, structure, formation, gap
# Relevant terms: different
# Text: We use two target variables for evaluating machine learning
# methods: defect formation energy per site and HOMO –LUMO gap.
# Formation energy, i.e., the energy required to create a defect is
# deﬁned as
# E
# ...
# Query terms: ['limitations', 'srgnn']
#
# Hybrid Query Results:
#  ***  * What are the limitations of SRGNN?
#
# Result 1 (Score: 0.2084):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: neural, nature, networks, singapore, published, university, graph, materials, graph neural, neural networks, properties, atomic, based, partnership
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.1951):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, prediction, quantum, full, sparse representation, con ﬁgurations, representation, ﬁgurations, dataset, megnet, wse, sparse, low, combined
# Relevant terms:
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
# Result 3 (Score: 0.1950):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: model, information, used, sparse representation, representation, graph, material, sparse, based, state
# Relevant terms:
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
# Query terms: ['idea', 'srgnn', 'core idea', 'core']
#
# Hybrid Query Results:
#  ***  * What is the core idea of SRGNN?
#
# Result 1 (Score: 0.3209):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 2 (Score: 0.2228):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: crystals, range, electrons, function, interaction, site, defect, lattice, number, formation energy, wave function, vacancies, sites, wave, structure
# Relevant terms:
# Text: S vacancies are at the 1st, 3rd, 6th, and 10th nearest S sites to theMo vacancy. These are exactly the triangular number series
# S
# n¼n/C1ðnþ1Þ=2. Interestingly, the sites which exhibit local
# minima of ...
#
# Result 3 (Score: 0.1949):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, supplementary, high, electrons, networks, available, electronic, single, graph, graph neural, neural networks, low, calculations, state, states
# Relevant terms:
# Text: structures with unpaired electrons, we utilize standard collinearspin-polarized calculations with magnetic ions in a high-spin
# ferromagnetic initialization (the ion moments can of course relax to
# a lo...
# Query terms: ['code', 'run']
#
# Hybrid Query Results:
#  ***  * How to run the code?
#
# Result 1 (Score: 0.2842):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: electrons, function, homo, atoms, site, lattice, mos, vacancies, wave, vacancy, wave function, sites, atomic, states
# Relevant terms:
# Text: MoS
# 2structure, the atomic charge of S gained from Mo atoms was
# calculated to be ~0.6 electrons. It is calculated to be less than 0.5
# electrons for S atoms nearest to the Mo vacancy due to thebreaking...
#
# Result 2 (Score: 0.1928):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 3 (Score: 0.1927):
# Document ID: s41699-023-00369-1.pdf
# Page: 4
# Keywords: supplementary, range, huang, npj, homo, published, lumo, defect, number, large, sites, atomic, vacancy, partnership
# Relevant terms: code
# Text: difference. The total spin of the carbon-impurity complexes in hBN
# is governed by the difference between the carbon substitutions atthe two sublattices according to Lieb ’s theorem
# 26,27.
# S¼NCNðÞ/C0NC...
# Query terms: ['used', 'frameworks', 'implementation', 'srgnn', 'srgnn implementation']
#
# Hybrid Query Results:
#  ***  * Which frameworks were used for SRGNN implementation?
#
# Result 1 (Score: 0.2090):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: high, used, electrons, interaction, structures, atoms, defect, energy, space, structure, electronic, calculations, atomic
# Relevant terms: used
# Text: only Monkhorst-Pack grid for structural relaxation and denser grids
# for further electronic structure calculations. A vacuum space of atleast 15 Åwas used to avoid interaction between neighboring
# layer...
#
# Result 2 (Score: 0.1938):
# Document ID: s41699-023-00369-1.pdf
# Page: 7
# Keywords: supplementary, used, electrons, interaction, structures, database, defect, space, large, materials, electronic, low, calculations, using, point
# Relevant terms: used
# Text: calculations. The initial crystal structures were obtained from
# the Material Project database and the supercell sizes and thecomputational parameters for each materials are listed in the
# supplemental ...
#
# Result 3 (Score: 0.1936):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, supplementary, high, electrons, networks, available, electronic, single, graph, graph neural, neural networks, low, calculations, state, states
# Relevant terms:
# Text: structures with unpaired electrons, we utilize standard collinearspin-polarized calculations with magnetic ions in a high-spin
# ferromagnetic initialization (the ion moments can of course relax to
# a lo...
# Query terms: ['cpu', 'srgnn', 'developed', 'gpu']
#
# Hybrid Query Results:
#  ***  * Can SRGNN be developed on a CPU, not a GPU?
#
# Result 1 (Score: 0.1943):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: high, used, structures, sparse representation, representation, singapore, eos, computational, megnet, sparse, using
# Relevant terms:
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
#
# Result 2 (Score: 0.1932):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: singapore, number, university, computational, materials
# Relevant terms:
# Text: ACKNOWLEDGEMENTS
# This research/project is supported by the Ministry of Education, Singapore, under its
# Research Centre of Excellence award to the Institute for Functional Intelligent Materials
# (I-FIM,...
#
# Result 3 (Score: 0.1932):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: model, information, used, sparse representation, representation, graph, material, sparse, based, state
# Relevant terms:
# Text: represented by a tuple ðvs
# k;vr
# k;ekÞ, where the superscripts s,r
# denote the sender and the receiver nodes respectively. The
# global state vector u2Rdurepresents the global state of the
# system. In the ...
# Query terms: ['license', 'code', 'code license']
#
# Hybrid Query Results:
#  ***  * What is the code license?
#
# Result 1 (Score: 0.1926):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: density, high, structures, using, sparse representation, representation, defect, dataset, number, use, megnet, sparse, low, combined
# Relevant terms:
# Text: class imbalance, we use weighted mean absolute error (MAE) as
# the quality metric during both training and evaluation:
# MAE ¼
# PN
# i¼1jyi/C0yijwiPN
# i¼1wi; (3)
# where wiis the weight assigned to each exampl...
#
# Result 2 (Score: 0.1917):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: defects, huang, interaction, datasets, published, defect, formation energy, space, learning, vacancies, materials, machine learning, machine, partnership
# Relevant terms:
# Text: edge about the amplitude of the interaction between the defects
# for each defect type. The formation energy for V3 defects
# composed of one Mo vacancy and two S vacancies span the
# Fig. 1 Machine learnin...
#
# Result 3 (Score: 0.1917):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: density, used, nature, structures, con ﬁgurations, data, lumo, defect, energy, formation energy, dft, dataset, use, formation, gap
# Relevant terms:
# Text: Fig. 3. We used pymatgen35toﬁnd the con ﬁgurations, taking
# into account symmetry. The high-density dataset contains asample of randomly generated substitution and vacancy defects
# for all the materials...
# Query terms: ['code', 'cite']
#
# Hybrid Query Results:
#  ***  * How to cite the code?
#
# Result 1 (Score: 0.3397):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1947):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: neural, huang, networks, npj, using, https, property, large, graph, graph neural, neural networks, phys, mater, rev
# Relevant terms:
# Text: graphs. Published at the International Conference on Learning Representations(ICLR) 2020. Preprint at https://arXiv.org/abs/2003.03123 (2020).
# 18. Shuaibi, M. et al. Rotation invariant graph neural ne...
#
# Result 3 (Score: 0.1942):
# Document ID: s41699-023-00369-1.pdf
# Page: 4
# Keywords: supplementary, range, huang, npj, homo, published, lumo, defect, number, large, sites, atomic, vacancy, partnership
# Relevant terms: code
# Text: difference. The total spin of the carbon-impurity complexes in hBN
# is governed by the difference between the carbon substitutions atthe two sublattices according to Lieb ’s theorem
# 26,27.
# S¼NCNðÞ/C0NC...
# Query terms: ['srgnn', 'trained', 'materials']
#
# Hybrid Query Results:
#  ***  * Which materials has the SRGNN been trained on?
#
# Result 1 (Score: 0.1957):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: model, prediction, full, npj, sparse representation, representation, lumo, defect, megnet, vacancies, wse, low, combined, partnership
# Relevant terms: materials
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 2 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, ﬁguration, con ﬁguration, function, npj, atoms, crystal, property, published, computational, dft, large, graph, partnership
# Relevant terms: trained, materials
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
# Result 3 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: defects, pristine, homo, lumo, defect, formation energy, number, energy, use, dft, sites, electronic, structure, formation, gap
# Relevant terms:
# Text: We use two target variables for evaluating machine learning
# methods: defect formation energy per site and HOMO –LUMO gap.
# Formation energy, i.e., the energy required to create a defect is
# deﬁned as
# E
# ...
# Query terms: ['srgnn', 'trained', 'materials']
#
# Hybrid Query Results:
#  ***  * Which materials can the SRGNN be trained on?
#
# Result 1 (Score: 0.1949):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, atoms, crystal, number, graph, structure, state, states
# Relevant terms:
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
#
# Result 2 (Score: 0.1949):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: neural, range, interaction, using, defect, energy, learning, wave, materials, phys, mater, calculations, open, rev
# Relevant terms: materials
# Text: (2018).
# 33. Banik, S. et al. Learning with delayed rewards –A case study on inverse defect
# design in 2d materials. ACS Appl. Mater. Interfaces 13, 36455 –36464 (2021).
# 34. Shytov, A. V., Abanin, D. A....
#
# Result 3 (Score: 0.1949):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: ﬁguration, con ﬁguration, function, band, defect, energy, fig, large, wave function, vacancies, wave, sites, con, levels, states
# Relevant terms:
# Text: vacancies is smaller than that of the third con ﬁguration, the two
# vacancies occupy lattice sites where there is a knot of their wavefunctions. The wave functions of the HOMO retain that of the
# isolat...
# Query terms: ['defect', 'srgnn', 'defect types', 'types', 'trained']
#
# Hybrid Query Results:
#  ***  * Which defect types can the SRGNN be trained on?
#
# Result 1 (Score: 0.1958):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms: defect
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 (Score: 0.1938):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: high, used, structures, sparse representation, representation, singapore, eos, computational, megnet, sparse, using
# Relevant terms: defect
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
#
# Result 3 (Score: 0.1936):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, atoms, crystal, number, graph, structure, state, states
# Relevant terms:
# Text: number, and an edge contains the Euclidean distance between
# the atoms it connects.
# A layer of a message-passing neural network transforms a
# graph into another graph with the same connectivity structur...
# Query terms: ['training', 'structures', 'many', 'srgnn', 'needed', 'many structures', 'srgnn training']
#
# Hybrid Query Results:
#  ***  * How many structures are needed for SRGNN training?
#
# Result 1 (Score: 0.2068):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms: structures
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, ﬁguration, con ﬁguration, function, npj, atoms, crystal, property, published, computational, dft, large, graph, partnership
# Relevant terms: training
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
#
# Result 3 (Score: 0.1954):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: high, used, electrons, interaction, structures, atoms, defect, energy, space, structure, electronic, calculations, atomic
# Relevant terms: structures
# Text: only Monkhorst-Pack grid for structural relaxation and denser grids
# for further electronic structure calculations. A vacuum space of atleast 15 Åwas used to avoid interaction between neighboring
# layer...
# Query terms: ['srgnn', 'handle', 'srgnn handle', 'materials']
#
# Hybrid Query Results:
#  ***  * Can SRGNN handle 3D materials?
#
# Result 1 (Score: 0.1968):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: model, prediction, full, npj, sparse representation, representation, lumo, defect, megnet, vacancies, wse, low, combined, partnership
# Relevant terms: materials
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 2 (Score: 0.1965):
# Document ID: s41524-023-01062-z.pdf
# Page: 5
# Keywords: defects, crystals, combined, full, sparse representation, representation, learning, megnet, vacancies, machine learning, sparse, graph neural, machine, using, properties
# Relevant terms:
# Text: possible con ﬁgurations is vast. Thus, the ability to predict the
# properties of such crystals ef ﬁciently becomes a vital task. In this
# paper, we focus on predicting the properties of such crystals
# bl...
#
# Result 3 (Score: 0.1965):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, ﬁguration, con ﬁguration, function, npj, atoms, crystal, property, published, computational, dft, large, graph, partnership
# Relevant terms: materials
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
# Query terms: ['much', 'srgnn require', 'training', 'resources', 'computational', 'srgnn', 'require', 'much computational', 'computational resources']
#
# Hybrid Query Results:
#  ***  * How much computational resources does SRGNN require for training?
#
# Result 1 (Score: 0.1955):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, prediction, quantum, full, sparse representation, con ﬁgurations, representation, ﬁgurations, dataset, megnet, wse, sparse, low, combined
# Relevant terms:
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
#
# Result 2 (Score: 0.1952):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms: training
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 3 (Score: 0.1951):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, used, quantum, prediction, sparse representation, con ﬁgurations, representation, data, ﬁgurations, dataset, use, sparse, low, vacancy
# Relevant terms: training
# Text: a GPU, and costs 7.5 CPU core-minutes per structure and 1860
# core-hours for the whole 2DMD dataset. Model con ﬁgurations are
# listed in Supplementary Discussion 1.
# Quantum oscillations prediction
# In ad...
# Query terms: ['inference speed', 'inference', 'srgnn', 'speed']
#
# Hybrid Query Results:
#  ***  * What is the inference speed of a SRGNN?
#
# Result 1 (Score: 0.2073):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: interaction, function, electron, pristine, electrons, atoms, lattice, energy, states, fig, wave function, wave, sites, atomic, vacancy
# Relevant terms:
# Text: resonance of the electron wave and the honeycomb lattice, the
# wave function of Mo vacancy has nodes at the Mo sites, where itchanges sign
# 36. This means that this wave function demonstrates
# oscillator...
#
# Result 2 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 3 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms:
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
# Query terms: ['srgnn', 'predicted', 'using srgnn', 'using', 'properties', 'predicted using']
#
# Hybrid Query Results:
#  ***  * Which properties can be predicted using SRGNN?
#
# Result 1 (Score: 0.1969):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: neural, nature, networks, singapore, published, university, graph, materials, graph neural, neural networks, properties, atomic, based, partnership
# Relevant terms: properties
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.1967):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, defects, pristine, structures, full, sparse representation, available, defect, dataset, space, number, fig, sparse, low
# Relevant terms:
# Text: For formation energy, just enabling the zcoordinate difference
# in sparse representation edges allows the Sparse-Z model to
# outperform the Full model everywhere except h-BN; adding
# pristine atom specie...
#
# Result 3 (Score: 0.1965):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: neural, ﬁguration, con ﬁguration, function, npj, atoms, crystal, property, published, computational, dft, large, graph, partnership
# Relevant terms: predicted
# Text: section, we outline the message-passing neural network proposedby Battaglia et al.
# 41. Those became rather popular for analyzing
# material structure11.
# To prepare a training sample, a graph is construc...
# Query terms: ['srgnn', 'material', 'quality', 'property']
#
# Hybrid Query Results:
#  ***  * What was the quality of SRGNN for each property and material?
#
# Result 1 (Score: 0.2035):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, defects, structures, npj, available, published, space, computational, fig, materials, partnership
# Relevant terms: material
# Text: on the defects to conserve space. Drawings of example structures with 8 × 8 supercells are available in Supplementary Fig. 1.N. Kazeev et al.
# 5
# Published in partnership with the Shanghai Institute of ...
#
# Result 2 (Score: 0.1953):
# Document ID: s41699-023-00369-1.pdf
# Page: 6
# Keywords: ﬁguration, con ﬁguration, function, band, defect, energy, fig, large, wave function, vacancies, wave, sites, con, levels, states
# Relevant terms:
# Text: vacancies is smaller than that of the third con ﬁguration, the two
# vacancies occupy lattice sites where there is a knot of their wavefunctions. The wave functions of the HOMO retain that of the
# isolat...
#
# Result 3 (Score: 0.1952):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: high, used, structures, sparse representation, representation, singapore, eos, computational, megnet, sparse, using
# Relevant terms:
# Text: Government of the Russian Federation (Agreement No. 70-2021-00143 dd. 01.11.2021,
# IGK 000000D730321P5Q0002). P.H. acknowledges the the supports of the National Key
# Research and Development Program (20...
# Query terms: ['used', 'pre trained', 'box', 'pre', 'srgnn', 'trained', 'trained srgnn']
#
# Hybrid Query Results:
#  ***  * Can pre-trained SRGNN be used out-of-the-box?
#
# Result 1 (Score: 0.2118):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: neural, nature, networks, singapore, published, university, graph, materials, graph neural, neural networks, properties, atomic, based, partnership
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.1957):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms: pre, trained
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
#
# Result 3 (Score: 0.1950):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, prediction, quantum, full, sparse representation, con ﬁgurations, representation, ﬁgurations, dataset, megnet, wse, sparse, low, combined
# Relevant terms: pre, trained
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
# Query terms: ['experiment', 'correspond', 'srgnn', 'srgnn results', 'results correspond', 'results']
#
# Hybrid Query Results:
#  ***  * How well do SRGNN results correspond to experiment?
#
# Result 1 (Score: 0.2060):
# Document ID: s41524-023-01062-z.pdf
# Page: 0
# Keywords: neural, nature, networks, singapore, published, university, graph, materials, graph neural, neural networks, properties, atomic, based, partnership
# Relevant terms:
# Text: based descriptors. Graph neural networks have several valuable
# properties that make them uniquely suitable for modeling atomic
# systems: invariance to permutations, rotations, and translation;
# 1Institu...
#
# Result 2 (Score: 0.1958):
# Document ID: s41524-023-01062-z.pdf
# Page: 8
# Keywords: neural, range, interaction, using, defect, energy, learning, wave, materials, phys, mater, calculations, open, rev
# Relevant terms:
# Text: (2018).
# 33. Banik, S. et al. Learning with delayed rewards –A case study on inverse defect
# design in 2d materials. ACS Appl. Mater. Interfaces 13, 36455 –36464 (2021).
# 34. Shytov, A. V., Abanin, D. A....
#
# Result 3 (Score: 0.1957):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, prediction, quantum, full, sparse representation, con ﬁgurations, representation, ﬁgurations, dataset, megnet, wse, sparse, low, combined
# Relevant terms:
# Text: prediction quality. The prediction quality for MoS 2and WSe 2is
# improved by a factor of 1.3 –4.8, but this is outweighted by a factor
# of 1.06 –1.15 increase in MAE for the other materials. Coinciden-
# ...
# Query terms: ['use srgnn', 'use', 'srgnn', 'place', 'dft']
#
# Hybrid Query Results:
#  ***  * Can I use SRGNN in place of DFT?
#
# Result 1 (Score: 0.2066):
# Document ID: s41524-023-01062-z.pdf
# Page: 6
# Keywords: high, used, electrons, interaction, structures, atoms, defect, energy, space, structure, electronic, calculations, atomic
# Relevant terms: use
# Text: only Monkhorst-Pack grid for structural relaxation and denser grids
# for further electronic structure calculations. A vacuum space of atleast 15 Åwas used to avoid interaction between neighboring
# layer...
#
# Result 2 (Score: 0.1956):
# Document ID: s41524-023-01062-z.pdf
# Page: 9
# Keywords: supplementary, density, information, nature, huang, structures, https, available, data, computational, dft, megnet, material, low, using
# Relevant terms: dft
# Text: ﬁrst author ’. I.R. implemented MEGNet in pytorch, and conducted computational
# experiments with it. MF&RL jointly generated the low-density structures with defects andperformed initial computational e...
#
# Result 3 (Score: 0.1953):
# Document ID: s41524-023-01062-z.pdf
# Page: 7
# Keywords: neural, model, networks, combined, data, dataset, learning, graph, neural networks, based, state
# Relevant terms:
# Text: e0
# k¼ϕevs
# i;vr
# i;ek;u/C0/C1
# : (5)
# Node update rule aggregates the information from all the edges
# Evi¼fe0
# kje0
# k2neighbors ðviÞgconnected to the node vi, the
# node itself viand the global state u. We ca...
# Query terms: ['computers', 'use srgnn', 'srgnn', 'single', 'photodetectors single', 'panels', 'solar', 'emitters', 'find', 'emitters quantum', 'quantum', 'use', 'photon emitters', 'single photon', 'transistors photodetectors', 'materials', 'quantum computers', 'transistors', 'photon', 'find materials', 'solar panels', 'photodetectors', 'panels transistors']
#
# Hybrid Query Results:
#  ***  * How can I use SRGNN to find materials for solar panels/transistors/photodetectors/single photon emitters/quantum computers?
#
# Result 1 (Score: 0.1971):
# Document ID: s41524-023-01062-z.pdf
# Page: 1
# Keywords: defects, used, structures, pristine, use, dft, point defects, megnet, large, materials, single, based, properties, point
# Relevant terms: use, materials, single
# Text: different materials, but the authors didn ’t consider con ﬁgurations
# with multiple interacting defects. In a recent preprint27, the
# authors use a model based on CGCNN12to conduct a large scale
# screeni...
#
# Result 2 (Score: 0.1970):
# Document ID: s41699-023-00369-1.pdf
# Page: 1
# Keywords: range, datasets, con ﬁgurations, ﬁgurations, data, defect, space, learning, mos, large, dft, wse, materials, atomic, properties
# Relevant terms: materials
# Text: small subspace of the whole defect space. The other group of
# dispersive datasets aims to spread data in the large defect space.This is done here by calculating the properties of a wide
# concentration r...
#
# Result 3 (Score: 0.1970):
# Document ID: s41699-023-00369-1.pdf
# Page: 8
# Keywords: high, crystals, prediction, networks, npj, database, dft, graph, materials, phys, neural networks, mater, open, rev
# Relevant terms: materials, quantum
# Text: accelerating materials innovation. APL Mater. 1, 011002 (2013).
# 7. Kirklin, S. et al. The open quantum materials database (OQMD): assessing the
# accuracy of DFT formation energies. npj Comput. Mater. 1...
# Query terms: ['srgnn', 'srgnn patented', 'patented']
#
# Hybrid Query Results:
#  ***  * Is SRGNN patented?
#
# Result 1 (Score: 0.1939):
# Document ID: s41524-023-01062-z.pdf
# Page: 4
# Keywords: supplementary, model, defects, pristine, structures, full, sparse representation, available, defect, dataset, space, number, fig, sparse, low
# Relevant terms:
# Text: For formation energy, just enabling the zcoordinate difference
# in sparse representation edges allows the Sparse-Z model to
# outperform the Full model everywhere except h-BN; adding
# pristine atom specie...
#
# Result 2 (Score: 0.1938):
# Document ID: s41524-023-01062-z.pdf
# Page: 3
# Keywords: model, prediction, full, npj, sparse representation, representation, lumo, defect, megnet, vacancies, wse, low, combined, partnership
# Relevant terms:
# Text: part (500 for low defect density parts, 5933 for the high defectdensity parts).
# We compare the performance of our sparse representation
# combined with MEGNet
# 11to several baseline methods: MEGNet,
# SchN...
#
# Result 3 (Score: 0.1938):
# Document ID: s41699-023-00369-1.pdf
# Page: 5
# Keywords: defects, interaction, quantum, function, con ﬁgurations, ﬁgurations, lumo, defect, energy, number, single, vacancies, sites, vacancy, properties
# Relevant terms:
# Text: single-photon emitters aiming at the identi ﬁcation and engineer-
# ing of candidate emitting centers in 2D hosts instead of that in
# bulk materials such as the NV center in diamond27,28.
# The quantum ﬂuc...
